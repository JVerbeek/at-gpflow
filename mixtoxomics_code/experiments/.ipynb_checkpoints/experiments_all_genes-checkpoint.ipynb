# %%
import numpy as np
import tensorflow_probability as tfp
import pandas as pd
from bisect import bisect_left
from scipy import special
from scipy.special import erf
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from numpy.linalg import inv
import tensorflow as tf
import scipy.linalg
import gpflow
from scipy.stats.distributions import chi2
import pandas as pd
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from gpflow.utilities import print_summary, positive
np.set_printoptions(suppress=True)
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from gpflow import set_trainable
import seaborn as sns
import tensorflow_probability as tfp
from tensorflow_probability import distributions as tfd
f64 = gpflow.utilities.to_default_float

# %%
def likelihood_ratio(llmin, llmax):
    return(2*(llmax-llmin))

# %%
from mpl_toolkits.mplot3d import Axes3D  
# Axes3D import has side effects, it enables using projection='3d' in add_subplot
import random
from scipy.stats.distributions import chi2

# %%
from block_cov_utils_matern_2d import (K_full_model_1, K_full_model_2, K_full_model_3, K_full_model_4, K_full_model_5, K_full_model_6, 
                            K_full_model_7, K_full_model_8, K_full_model_9, K_full_model_10, K_full_model_11)

# %%
from block_cov_utils_rbf_2d import (K_full_model_1, K_full_model_2, K_full_model_3, K_full_model_4, K_full_model_5, K_full_model_6, 
                            K_full_model_7, K_full_model_8, K_full_model_9, K_full_model_10, K_full_model_11)

# %%
def load_data(data, gene_id, samples_exp1, samples_exp2):
    
    y_exp1 = data[data['Unnamed: 0'] == gene_id][samples_exp1].to_numpy().reshape(-1,1)
    y_exp2 = data[data['Unnamed: 0'] == gene_id][samples_exp2].to_numpy().reshape(-1,1)
    
    TU_IMI_exp1 = metadata[metadata['experiment']==1]['conc_IMI'].to_numpy().reshape(-1,1)
    TU_IMI_exp2 = metadata[metadata['experiment']==2]['conc_IMI'].to_numpy().reshape(-1,1)

    TU_CLO_exp1 = metadata[metadata['experiment']==1]['conc_CLO'].to_numpy().reshape(-1,1)
    TU_CLO_exp2 = metadata[metadata['experiment']==2]['conc_CLO'].to_numpy().reshape(-1,1)

    TU_CYPRO_exp1 = metadata[metadata['experiment']==1]['conc_CYPRO'].to_numpy().reshape(-1,1)
    TU_CYPRO_exp2 = metadata[metadata['experiment']==2]['conc_CYPRO'].to_numpy().reshape(-1,1)
    
    df_exp1 = pd.concat([pd.DataFrame(TU_IMI_exp1), pd.DataFrame(TU_CLO_exp1), pd.DataFrame(y_exp1)], axis=1)
    df_exp2 = pd.concat([pd.DataFrame(TU_IMI_exp2), pd.DataFrame(TU_CYPRO_exp2), pd.DataFrame(y_exp2)], axis=1)
    
    df_exp1.columns = ['conc_IMI', 'conc_CLO', 'y_exp1']
    df_exp2.columns = ['conc_IMI', 'conc_CYPRO', 'y_exp2']
    df_exp1.columns = ['', '', '']
    df_exp2.columns = ['', '', '']
    
    df = pd.concat([df_exp1, df_exp2], axis=0)
    df.columns = ['conc_drug1', 'conc_drug2', 'y']
    df['conc_drug12'] = df['conc_drug1']*df['conc_drug2']
    df_X = pd.concat([df['conc_drug1'], df['conc_drug2'], df['conc_drug12']], axis=1)
    df_X.columns = ['','','']
    X_full = df_X.to_numpy()
    Y_full = df['y'].to_numpy().reshape(-1,1)
    Y_full = (Y_full - np.min(Y_full))/(np.max(Y_full)-np.min(Y_full))
    
    return (X_full, Y_full)

# %%
def load_data1(data, gene_id, samples_exp1, samples_exp2):
    
    y_exp1 = data[data['Unnamed: 0'] == gene_id][samples_exp1].to_numpy().reshape(-1,1)
    y_exp2 = data[data['Unnamed: 0'] == gene_id][samples_exp2].to_numpy().reshape(-1,1)
    
    TU_IMI_exp1 = metadata[metadata['experiment']==1]['conc_IMI'].to_numpy().reshape(-1,1)
    TU_IMI_exp2 = metadata[metadata['experiment']==2]['conc_IMI'].to_numpy().reshape(-1,1)

    TU_CLO_exp1 = metadata[metadata['experiment']==1]['conc_CLO'].to_numpy().reshape(-1,1)
    TU_CLO_exp2 = metadata[metadata['experiment']==2]['conc_CLO'].to_numpy().reshape(-1,1)

    TU_CYPRO_exp1 = metadata[metadata['experiment']==1]['conc_CYPRO'].to_numpy().reshape(-1,1)
    TU_CYPRO_exp2 = metadata[metadata['experiment']==2]['conc_CYPRO'].to_numpy().reshape(-1,1)
    
    df_exp1 = pd.concat([pd.DataFrame(TU_IMI_exp1), pd.DataFrame(TU_CLO_exp1), pd.DataFrame(y_exp1)], axis=1)
    df_exp2 = pd.concat([pd.DataFrame(TU_IMI_exp2), pd.DataFrame(TU_CYPRO_exp2), pd.DataFrame(y_exp2)], axis=1)
    
    df_exp1.columns = ['conc_IMI', 'conc_CLO', 'y_exp1']
    df_exp2.columns = ['conc_IMI', 'conc_CYPRO', 'y_exp2']
    df_exp1['exp'] = 'exp1'
    df_exp2['exp'] = 'exp2'
    df_exp1.columns = ['', '', '', '']
    df_exp2.columns = ['', '', '', '']
    
    df = pd.concat([df_exp1, df_exp2], axis=0)
    df.columns = ['X1', 'X2', 'Y', 'exp']
    df['Y'] = (df['Y'] - np.min(df['Y']))/(np.max(df['Y'])-np.min(df['Y']))
    #df.columns = ['conc_drug1', 'conc_drug2', 'y']
    #df['conc_drug12'] = df['conc_drug1']*df['conc_drug2']
    #df_X = pd.concat([df['conc_drug1'], df['conc_drug2'], df['conc_drug12']], axis=1)
    #df_X.columns = ['','','']
    #X_full = df[[]].to_numpy()
    #Y_full = df['y'].to_numpy().reshape(-1,1)
    #Y_full = (Y_full - np.min(Y_full))/(np.max(Y_full)-np.min(Y_full))
    
    return df

# %% [markdown]
# ## Load the data set

# %%
data_full_exp1 = pd.read_csv('data/raw_exp1.csv') 
data_full_exp2 = pd.read_csv('data/raw_exp2.csv') 
data_full_exp2 = data_full_exp2.drop(columns=['Unnamed: 0'])
metadata = pd.read_csv('data/metadata.csv')

# %%
data_full = pd.concat([data_full_exp1, data_full_exp2], axis=1)

# %%
#genes = pd.read_csv('top100CYPRO.txt', sep = ' ')
#genes = genes['x'].to_numpy()

genes = data_full['Unnamed: 0'].to_numpy()
subset = data_full[data_full['Unnamed: 0'].isin(genes)]

# %%
samples_exp1 = metadata[metadata['experiment']==1]['sample']
samples_exp1 = samples_exp1.to_numpy().astype(str).tolist()

# %%
samples_exp2 = metadata[metadata['experiment']==2]['sample']
samples_exp2 = samples_exp2.to_numpy().astype(str).tolist()

# %%
string = 'Sample_'
samples_exp1 = [string + x for x in samples_exp1]
samples_exp2 = [string + x for x in samples_exp2]

# %%
loglik_model_1_list = []
loglik_model_2_list = []
loglik_model_3_list = []
loglik_model_4_list = []
loglik_model_5_list = []
loglik_model_6_list = []
loglik_model_7_list = []
loglik_model_8_list = []
loglik_model_9_list = []
loglik_model_10_list = []
loglik_model_11_list = []
genes_list = []

# %%
#for i in range(0,28617):
for i in range(0,10):    
    gene_id = genes[i]
    
    genes_list.append(gene_id)
    
    data = load_data1(data_full, gene_id, samples_exp1, samples_exp2)
    data = (data[['X1', 'X2']].to_numpy(), data['Y'].to_numpy().reshape(-1,1))
    
    # model 1
    try:
        k = K_full_model_1()

        m = gpflow.models.GPR(data, kernel=k, mean_function=None)
        m.kernel.lengthscale_11.assign(1.0)
        m.kernel.variance_11.assign(1.0)
        opt = gpflow.optimizers.Scipy()
        opt_logs = opt.minimize(m.training_loss, m.trainable_variables, options=dict(maxiter=100))

        loglik_model_1 = np.asarray(m.training_loss())

        loglik_model_1_list.append(loglik_model_1)
    except: 
        loglik_model_1_list.append(np.nan)
    
    # model 2
    try:
        k = K_full_model_2()
        m = gpflow.models.GPR(data, kernel=k, mean_function=None)

        opt = gpflow.optimizers.Scipy()
        opt_logs = opt.minimize(m.training_loss, m.trainable_variables, options=dict(maxiter=100))

        loglik_model_2 = np.asarray(m.training_loss())

        loglik_model_2_list.append(loglik_model_2)
    except:
        loglik_model_2_list.append(np.nan)
    
    # model 3
    try:
        k = K_full_model_3()
        m = gpflow.models.GPR(data, kernel=k, mean_function=None)

        opt = gpflow.optimizers.Scipy()
        opt_logs = opt.minimize(m.training_loss, m.trainable_variables, options=dict(maxiter=100))

        loglik_model_3 = np.asarray(m.training_loss())

        loglik_model_3_list.append(loglik_model_3)
    except:
        loglik_model_3_list.append(np.nan)
    
    # model 4
    try:
        k = K_full_model_4()
        m = gpflow.models.GPR(data, kernel=k, mean_function=None)

        opt = gpflow.optimizers.Scipy()
        opt_logs = opt.minimize(m.training_loss, m.trainable_variables, options=dict(maxiter=100))

        loglik_model_4 = np.asarray(m.training_loss())

        loglik_model_4_list.append(loglik_model_4)
    except:
        loglik_model_4_list.append(np.nan)
    
    # model 5
    try:
        k = K_full_model_5()
        m = gpflow.models.GPR(data, kernel=k, mean_function=None)

        opt = gpflow.optimizers.Scipy()
        opt_logs = opt.minimize(m.training_loss, m.trainable_variables, options=dict(maxiter=100))

        loglik_model_5 = np.asarray(m.training_loss())

        loglik_model_5_list.append(loglik_model_5)
    except:
        loglik_model_5_list.append(np.nan)
    
    
    # model 6
    try:
        k = K_full_model_6()
        m = gpflow.models.GPR(data, kernel=k, mean_function=None)

        opt = gpflow.optimizers.Scipy()
        opt_logs = opt.minimize(m.training_loss, m.trainable_variables, options=dict(maxiter=100))

        loglik_model_6 = np.asarray(m.training_loss())

        loglik_model_6_list.append(loglik_model_6)
    except:
        loglik_model_6_list.append(np.nan)
    
    # model 7
    try:
        k = K_full_model_7()
        m = gpflow.models.GPR(data, kernel=k, mean_function=None)

        opt = gpflow.optimizers.Scipy()
        opt_logs = opt.minimize(m.training_loss, m.trainable_variables, options=dict(maxiter=100))

        loglik_model_7 = np.asarray(m.training_loss())

        loglik_model_7_list.append(loglik_model_7)
    except:
        loglik_model_7_list.append(np.nan)

    
    # model 8
    try:
        k = K_full_model_8()
        m = gpflow.models.GPR(data, kernel=k, mean_function=None)

        opt = gpflow.optimizers.Scipy()
        opt_logs = opt.minimize(m.training_loss, m.trainable_variables, options=dict(maxiter=100))

        loglik_model_8 = np.asarray(m.training_loss())

        loglik_model_8_list.append(loglik_model_8)
    except:
        loglik_model_8_list.append(np.nan)
    
    # model 9
    try:
        k = K_full_model_9()
        m = gpflow.models.GPR(data, kernel=k, mean_function=None)

        opt = gpflow.optimizers.Scipy()
        opt_logs = opt.minimize(m.training_loss, m.trainable_variables, options=dict(maxiter=100))

        loglik_model_9 = np.asarray(m.training_loss())

        loglik_model_9_list.append(loglik_model_9)
    except:
        loglik_model_9_list.append(np.nan)
        
    # model 10
    try:
        k = K_full_model_10()
        m = gpflow.models.GPR(data, kernel=k, mean_function=None)

        opt = gpflow.optimizers.Scipy()
        opt_logs = opt.minimize(m.training_loss, m.trainable_variables, options=dict(maxiter=100))

        loglik_model_10 = np.asarray(m.training_loss())

        loglik_model_10_list.append(loglik_model_10)
    except:
        loglik_model_10_list.append(np.nan)    

        
    # model 11
    try:
        k = K_full_model_11()
        m = gpflow.models.GPR(data, kernel=k, mean_function=None)

        opt = gpflow.optimizers.Scipy()
        opt_logs = opt.minimize(m.training_loss, m.trainable_variables, options=dict(maxiter=100))

        loglik_model_11 = np.asarray(m.training_loss())

        loglik_model_11_list.append(loglik_model_11)
    except:
        loglik_model_11_list.append(np.nan)
# Out:
# 2023-03-10 14:15:35.714969: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-03-10 14:15:35.714999: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Metal device set to: Apple M1 Pro
# WARNING:tensorflow:From /Users/yuliya/opt/anaconda3/envs/gpflow/lib/python3.10/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# 2023-03-10 14:15:36.812947: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-03-10 14:15:36.813416: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:15:37.464682: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:15:38.186110: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:15:39.211201: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:15:40.530805: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:15:41.593032: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:15:42.443784: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:15:43.107886: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:15:43.897768: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:15:45.112568: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:15:46.279129: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:15:47.302195: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:15:47.755012: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:15:48.299167: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:15:49.121651: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:15:49.743279: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:15:50.343754: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:15:51.094510: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:15:51.644921: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:15:52.406861: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:15:53.129470: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:15:53.946371: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:15:54.614503: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:15:55.112915: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:15:55.654012: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:15:56.299280: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:15:57.010115: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:15:57.686502: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:15:58.440232: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:15:59.190562: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:15:59.988412: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:00.849453: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:01.866483: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:02.585117: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:03.296938: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:04.026942: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:04.699511: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:05.531647: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:06.115524: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:06.841019: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:07.384533: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:08.098087: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:08.878016: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:09.623920: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:10.255163: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:10.725389: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:11.354138: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:11.987758: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:12.741700: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:13.514021: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:14.092183: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:14.848635: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:15.593665: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:16.548200: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:17.501612: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:18.191967: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:18.856015: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:19.656217: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:20.320652: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:21.199598: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:21.986025: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:22.787273: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:23.366305: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:24.163906: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:25.168140: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:26.352577: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:27.148738: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:27.775591: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:28.460726: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:29.107864: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:29.890101: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:30.483457: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:31.051329: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:31.776412: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:32.586678: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:33.474166: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:34.379117: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:35.139484: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:35.743775: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:36.412000: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:37.117347: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:37.810023: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:38.871702: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:39.436333: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:40.150435: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:40.911218: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:41.638500: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:42.365949: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:43.012452: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:43.568420: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:44.244249: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:44.884635: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:45.532259: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:46.105697: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:46.822574: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:47.412790: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:48.185157: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:49.047714: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:49.809056: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:50.582055: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:51.039248: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:52.083609: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:52.808561: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:53.361248: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:53.980170: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:54.698956: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:55.259166: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:55.961010: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:56.686813: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:57.545865: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:58.254975: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:58.689991: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:16:59.412661: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:00.156340: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:00.700048: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:01.360383: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:02.756286: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:03.336160: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:04.020680: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:04.741170: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:05.773444: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:06.271675: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:06.779827: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:07.314927: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:07.961406: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:08.550137: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:09.115255: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:09.676248: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:10.260608: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:10.911318: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:11.608469: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:12.336701: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:12.898985: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:13.360005: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:13.863060: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:14.650479: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:15.313208: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:15.926950: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:16.580592: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:17.099676: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:18.083757: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:18.756247: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:19.453642: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:20.103142: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:20.659063: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:21.279951: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:21.955727: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:22.684168: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:23.346553: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:24.060218: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:24.572859: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:25.294719: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:26.077738: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:26.901081: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:27.557875: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:28.017584: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:28.658412: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:29.428272: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:30.322062: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:30.923635: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:31.625402: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:32.190776: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:33.144473: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:33.975541: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:34.693480: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:35.464686: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:36.064909: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:36.639265: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:37.225061: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:37.771396: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:38.417998: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:39.351368: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:40.101224: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:40.995768: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:41.699130: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:42.592668: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:43.115685: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:43.604397: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:44.255465: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:45.308829: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:46.282735: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:47.147021: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:47.998803: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:48.645224: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:49.815903: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:50.803375: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:51.805704: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:52.860066: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:53.443143: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:53.903480: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:54.522031: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:55.158102: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:55.723467: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:56.441881: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:56.966858: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:57.652669: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:58.398242: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:17:59.155293: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:00.024935: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:00.469920: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:01.057983: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:01.617778: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:02.360849: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:03.032608: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:03.914945: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:04.607620: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:05.246770: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:06.237061: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:07.050609: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:07.768040: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:08.406341: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:09.050851: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:09.929770: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:10.787265: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:11.645003: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:12.462271: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:13.188229: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:13.909736: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:14.772998: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:15.788789: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:16.541028: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:16.999785: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:17.653768: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:18.524073: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:19.194848: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:19.774060: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:20.656694: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:21.180946: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:21.868938: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:22.610018: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:23.433358: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:24.505615: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:25.346480: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:25.967821: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:26.657910: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:27.442788: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:28.075684: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:28.708586: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:29.287597: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:30.022301: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:30.989529: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:31.796133: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:32.605383: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:33.183526: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:33.815488: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:34.568491: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:35.253718: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:35.951184: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:36.632704: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:37.256933: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:38.020921: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:38.962010: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:39.679120: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:40.501800: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:41.097564: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:41.798422: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:42.553737: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:43.645434: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:44.358918: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:45.061207: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:45.781542: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:46.498791: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:47.255876: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:47.998875: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:48.678022: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:49.167375: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:49.723890: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:50.401192: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:51.116473: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:51.749583: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:52.388051: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:53.041455: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:53.704930: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:54.541274: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:55.334179: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:55.949383: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:56.596168: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:57.190877: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:57.938064: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:58.611517: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:59.298813: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:18:59.957597: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:19:00.677228: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:19:01.348450: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:19:02.547709: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:19:03.271608: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:19:03.936429: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:19:04.453372: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:19:05.005036: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:19:05.644482: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:19:06.260370: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:19:06.832626: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:19:07.419150: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:19:08.064777: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:19:08.799752: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:19:09.553840: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:19:10.261190: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:19:10.904518: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:19:11.478189: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:19:12.103920: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:19:12.811955: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 14:19:13.492521: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# ...
# 2023-03-10 18:14:52.252366: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:14:53.036808: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:14:53.970672: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:14:54.799746: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:14:55.520135: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:14:56.211112: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:14:56.991173: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:14:57.799616: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:14:58.694737: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:14:59.758865: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:00.569794: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:01.030571: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:01.750086: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:02.428242: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:03.278249: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:03.914195: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:04.523600: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:05.038960: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:05.923559: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:06.754548: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:07.692001: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:08.568919: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:09.139768: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:09.823675: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:10.645029: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:11.566723: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:12.233125: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:12.939662: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:13.637249: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:14.438445: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:15.085811: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:15.863421: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:16.511742: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:17.082516: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:17.861128: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:18.953297: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:19.796230: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:20.483325: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:21.328542: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:22.063085: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:22.952111: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:23.882314: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:24.743568: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:25.600523: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:26.061174: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:26.668828: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:27.258198: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:27.984841: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:28.635406: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:29.596795: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:30.250369: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:30.949811: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:31.603325: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:32.394229: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:33.111400: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:33.592924: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:34.139625: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:34.911682: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:35.806847: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:36.582762: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:37.182662: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:37.849306: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:38.534578: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:39.354259: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:40.177670: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:40.850182: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:41.448423: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:42.096926: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:42.875935: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:43.601597: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:44.249635: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:44.914972: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:45.589639: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:46.364014: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:47.150269: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:47.990746: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:48.618724: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:49.200581: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:49.845460: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:50.576895: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:51.302687: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:51.982854: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:52.650371: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:53.295202: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:54.022885: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:54.833922: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:55.622505: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:56.327172: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:56.943170: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:57.738150: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:58.679769: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:15:59.676120: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:16:00.607696: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:16:01.497402: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:16:02.276765: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:16:03.133042: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:16:04.222966: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:16:05.278207: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:16:06.158616: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:16:06.765692: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:16:07.435921: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:16:08.184048: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-10 18:16:08.903132: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.

# %%
loglik_results = pd.DataFrame([np.asarray(loglik_model_1_list), np.asarray(loglik_model_2_list),
             np.asarray(loglik_model_3_list), np.asarray(loglik_model_4_list), 
             np.asarray(loglik_model_5_list), np.asarray(loglik_model_6_list), 
             np.asarray(loglik_model_7_list), np.asarray(loglik_model_8_list), 
             np.asarray(loglik_model_9_list), np.asarray(loglik_model_10_list),
                              np.asarray(loglik_model_11_list)])

# %%
loglik_results.index = ['model_1', 'model_2', 'model_3',
                         'model_4', 'model_5', 'model_6',
                         'model_7', 'model_8', 'model_9', 'model_10', 'model_11']

# %%
loglik_results = loglik_results.T

# %%
loglik_results['p_val_21'] = chi2.sf(likelihood_ratio(loglik_results['model_1'], loglik_results['model_2']), 2) 
loglik_results['p_val_31'] = chi2.sf(likelihood_ratio(loglik_results['model_1'], loglik_results['model_3']), 2) 
loglik_results['p_val_41'] = chi2.sf(likelihood_ratio(loglik_results['model_1'], loglik_results['model_4']), 4) 
loglik_results['p_val_42'] = chi2.sf(likelihood_ratio(loglik_results['model_2'], loglik_results['model_4']), 2) 
loglik_results['p_val_43'] = chi2.sf(likelihood_ratio(loglik_results['model_3'], loglik_results['model_3']), 2) 
loglik_results['p_val_51'] = chi2.sf(likelihood_ratio(loglik_results['model_1'], loglik_results['model_5']), 2) 
loglik_results['p_val_52'] = chi2.sf(likelihood_ratio(loglik_results['model_2'], loglik_results['model_5']), 2) 
loglik_results['p_val_61'] = chi2.sf(likelihood_ratio(loglik_results['model_1'], loglik_results['model_6']), 2)
loglik_results['p_val_62'] = chi2.sf(likelihood_ratio(loglik_results['model_2'], loglik_results['model_6']), 2)
loglik_results['p_val_63'] = chi2.sf(likelihood_ratio(loglik_results['model_3'], loglik_results['model_6']), 2)
loglik_results['p_val_64'] = chi2.sf(likelihood_ratio(loglik_results['model_4'], loglik_results['model_6']), 2) 
loglik_results['p_val_71'] = chi2.sf(likelihood_ratio(loglik_results['model_1'], loglik_results['model_7']), 2) #???
loglik_results['p_val_73'] = chi2.sf(likelihood_ratio(loglik_results['model_3'], loglik_results['model_7']), 2) #???
loglik_results['p_val_87'] = chi2.sf(likelihood_ratio(loglik_results['model_7'], loglik_results['model_8']), 2) #???
loglik_results['p_val_97'] = chi2.sf(likelihood_ratio(loglik_results['model_7'], loglik_results['model_9']), 2) #???
loglik_results['p_val_98'] = chi2.sf(likelihood_ratio(loglik_results['model_8'], loglik_results['model_9']), 2) #???
loglik_results['p_val_82'] = chi2.sf(likelihood_ratio(loglik_results['model_2'], loglik_results['model_8']), 2) #???
loglik_results['p_val_53'] = chi2.sf(likelihood_ratio(loglik_results['model_3'], loglik_results['model_5']), 2) #???
loglik_results['p_val_31'] = chi2.sf(likelihood_ratio(loglik_results['model_1'], loglik_results['model_3']), 2) #???
loglik_results['p_val_21'] = chi2.sf(likelihood_ratio(loglik_results['model_1'], loglik_results['model_2']), 2) #???
loglik_results['p_val_41'] = chi2.sf(likelihood_ratio(loglik_results['model_1'], loglik_results['model_4']), 2) #???
loglik_results['p_val_87'] = chi2.sf(likelihood_ratio(loglik_results['model_7'], loglik_results['model_8']), 2) #???
loglik_results['p_val_95'] = chi2.sf(likelihood_ratio(loglik_results['model_5'], loglik_results['model_9']), 2) #???

loglik_results['gene_id'] = genes_list

# %%
loglik_results
# Out:
#         model_1    model_2    model_3    model_4    model_5    model_6  \
# 0    -30.486889 -30.482827 -31.897947 -31.893917 -31.898488 -31.905562
# 1    -29.913863 -29.936269 -29.913169 -29.914437 -29.913137 -29.913982
# 2    -62.387795 -62.378006 -69.030848 -69.020277 -69.093160 -71.933033
# 3    -44.262695 -44.393331 -73.897124 -75.764938 -74.088813 -75.545744
# 4    -47.464813 -47.682470 -47.803527 -49.158245 -47.785947 -47.732288
# ...         ...        ...        ...        ...        ...        ...
# 1995 -34.644161 -35.215737 -47.583835 -48.555100 -47.996021 -48.522970
# 1996 -22.048650 -22.046854 -22.250149 -22.248390 -22.250149 -22.250149
# 1997 -59.977160 -59.977988 -60.503405 -60.504483 -60.503405 -60.503401
# 1998 -39.205068 -39.300056 -39.238630 -39.334019 -39.239209 -39.238118
# 1999 -52.537945 -52.780753 -52.965468 -53.229082 -52.965389 -52.964865
#
#         model_7    model_8    model_9   model_10  ...  p_val_64  p_val_71  \
# 0    -22.145220 -30.482472 -31.485465 -30.379019  ...  1.000000  0.000238
# 1    -29.423561 -29.936273 -29.896398 -29.812256  ...  0.999546  0.612441
# 2    -64.737505 -62.377569 -68.112911 -69.722920  ...  1.000000  1.000000
# 3    -40.261077 -44.392897 -74.872039 -74.965619  ...  0.803166  0.018286
# 4    -38.533069 -47.683448 -48.012652 -48.904466  ...  0.240278  0.000132
# ...         ...        ...        ...        ...  ...       ...       ...
# 1995 -26.456946 -35.217156 -48.900140 -48.485533  ...  0.968380  0.000278
# 1996 -10.683298 -22.046401 -21.958335 -21.889117  ...  1.000000  0.000012
# 1997 -48.824883 -59.977814 -60.322293 -60.285072  ...  0.998919  0.000014
# 1998 -31.893245 -39.300011 -39.321180 -39.327180  ...  0.908553  0.000668
# 1999 -42.825496 -52.781776 -53.229223 -52.912655  ...  0.767807  0.000061
#
#           p_val_73  p_val_87  p_val_97  p_val_98  p_val_82  p_val_53  \
# 0     5.813596e-05  1.000000       1.0  1.000000  0.999646  1.000000
# 1     6.128662e-01  1.000000       1.0  0.960909  1.000000  0.999967
# 2     1.365919e-02  0.094426       1.0  1.000000  0.999563  1.000000
# 3     2.466324e-15  1.000000       1.0  1.000000  0.999566  1.000000
# 4     9.416546e-05  1.000000       1.0  1.000000  1.000000  0.982574
# ...            ...       ...       ...       ...       ...       ...
# 1995  6.678963e-10  1.000000       1.0  1.000000  1.000000  1.000000
# 1996  9.475027e-06  1.000000       1.0  0.915701  0.999547  1.000000
# 1997  8.473886e-06  1.000000       1.0  1.000000  0.999827  1.000000
# 1998  6.455649e-04  1.000000       1.0  1.000000  0.999955  1.000000
# 1999  3.946991e-05  1.000000       1.0  1.000000  1.000000  0.999921
#
#       p_val_95       gene_id
# 0     0.661647  Fcan01_00001
# 1     0.983401  Fcan01_00002
# 2     0.375217  Fcan01_00003
# 3     1.000000  Fcan01_00004
# 4     1.000000  Fcan01_00005
# ...        ...           ...
# 1995  1.000000  Fcan01_01997
# 1996  0.746908  Fcan01_01998
# 1997  0.834342  Fcan01_01999
# 1998  1.000000  Fcan01_02000
# 1999  1.000000  Fcan01_02001
#
# [2000 rows x 31 columns]

# %%
#loglik_results.to_csv('10000_first_genes_result.csv')

# %%
#loglik_results.to_csv('top100_genes_result.csv')

# %%
#loglik_results.to_csv('all_genes_result.csv')

# %%
#loglik_results.to_csv('20000_to_28617_first_genes_result.csv')

# %%
#df1 = pd.read_csv('10000_first_genes_result.csv') 
#df2 = pd.read_csv('10000_to_20000_first_genes_result.csv') 
#df3 = pd.read_csv('20000_to_28617_first_genes_result.csv')

# %%
loglik_results[loglik_results['p_val_82']<0.1]
# Out:
# Empty DataFrame
# Columns: [model_1, model_2, model_3, model_4, model_5, model_6, model_7, model_8, model_9, model_10, model_11, p_val_21, p_val_31, p_val_41, p_val_42, p_val_43, p_val_51, p_val_52, p_val_61, p_val_62, p_val_63, p_val_64, p_val_71, p_val_73, p_val_87, p_val_97, p_val_98, p_val_82, p_val_53, p_val_95, gene_id]
# Index: []
#
# [0 rows x 31 columns]

# %% [markdown]
# ## Vizualization

# %%
df_full = loglik_results

# %%
genes= ['Fcan01_00710',
 'Fcan01_01431',
 'Fcan01_08638',
 'Fcan01_10767',
 'Fcan01_11559',
 'Fcan01_13564',
 'Fcan01_16176',
 'Fcan01_17452',
 'Fcan01_17957',
 'Fcan01_20354',
 'Fcan01_20721',
 'Fcan01_23065',
 'Fcan01_27203']

genes = ['Fcan01_08638', 'Fcan01_01431', 'Fcan01_13564', 'Fcan01_04947', 'Fcan01_20262', 'Fcan01_04429',
         'Fcan01_17454', 'Fcan01_18435']

# %%
from gpflow.models import GPModel
from gpflow.models.training_mixins import InternalDataTrainingLossMixin, InputData
from check_shapes import check_shapes, inherit_check_shapes
from gpflow.base import InputData, MeanAndVariance, RegressionData, TensorData
from gpflow.kernels import Kernel
from gpflow.likelihoods import Gaussian
from gpflow.logdensities import multivariate_normal
from gpflow.mean_functions import MeanFunction
from gpflow.utilities import add_likelihood_noise_cov, assert_params_false
from typing import Optional
from gpflow.models.util import data_input_to_tensor

# %%
class GPR_deprecated(GPModel, InternalDataTrainingLossMixin):
    r"""
    Gaussian Process Regression.

    This is a vanilla implementation of GP regression with a Gaussian
    likelihood.  Multiple columns of Y are treated independently.

    The log likelihood of this model is given by

    .. math::
       \log p(Y \,|\, \mathbf f) =
            \mathcal N(Y \,|\, 0, \sigma_n^2 \mathbf{I})

    To train the model, we maximise the log _marginal_ likelihood
    w.r.t. the likelihood variance and kernel hyperparameters theta.
    The marginal likelihood is found by integrating the likelihood
    over the prior, and has the form

    .. math::
       \log p(Y \,|\, \sigma_n, \theta) =
            \mathcal N(Y \,|\, 0, \mathbf{K} + \sigma_n^2 \mathbf{I})

    For a use example see :doc:`../../../../notebooks/getting_started/basic_usage`.
    """

    #@check_shapes(
    #    "data[0]: [N, D]",
    #    "data[1]: [N, P]",
    #    "noise_variance: []",
    #)
    def __init__(
        self,
        data: RegressionData,
        kernel: Kernel,
        mean_function: Optional[MeanFunction] = None,
        noise_variance: Optional[TensorData] = None,
        likelihood: Optional[Gaussian] = None,
    ):
        assert (noise_variance is None) or (
            likelihood is None
        ), "Cannot set both `noise_variance` and `likelihood`."
        if likelihood is None:
            if noise_variance is None:
                noise_variance = 1.0
            likelihood = gpflow.likelihoods.Gaussian(noise_variance)
        _, Y_data = data
        super().__init__(kernel, likelihood, mean_function, num_latent_gps=Y_data.shape[-1])
        self.data = data_input_to_tensor(data)

    # type-ignore is because of changed method signature:
    #@inherit_check_shapes
    def maximum_log_likelihood_objective(self) -> tf.Tensor:  # type: ignore[override]
        return self.log_marginal_likelihood()


    #@check_shapes(
    #    "return: []",
    #)
    def log_marginal_likelihood(self) -> tf.Tensor:
        r"""
        Computes the log marginal likelihood.

        .. math::
            \log p(Y | \theta).

        """
        X, Y = self.data
        K = self.kernel(X)
        ks = add_likelihood_noise_cov(K, self.likelihood, X)
        L = tf.linalg.cholesky(ks)
        m = self.mean_function(X)

        # [R,] log-likelihoods for each independent dimension of Y
        log_prob = multivariate_normal(Y, m, L)
        return tf.reduce_sum(log_prob)


    #@inherit_check_shapes
    def predict_f(
        self, Xnew: InputData, full_cov: bool = False, full_output_cov: bool = False
    ) -> MeanAndVariance:
        r"""
        This method computes predictions at X \in R^{N \x D} input points

        .. math::
            p(F* | Y)

        where F* are points on the GP at new data points, Y are noisy observations at training data
        points.
        """
        assert_params_false(self.predict_f, full_output_cov=full_output_cov)

        X, Y = self.data
        err = Y - self.mean_function(X)

        kmm = self.kernel(X)
        knn = self.kernel(Xnew, full_cov=full_cov)
        kmn = self.kernel(X, Xnew)
        kmm_plus_s = add_likelihood_noise_cov(kmm, self.likelihood, X)

        conditional = gpflow.conditionals.base_conditional
        f_mean_zero, f_var = conditional(
            kmn, kmm_plus_s, knn, err, full_cov=full_cov, white=False
        )  # [N, P], [N, P] or [P, N, N]
        f_mean = f_mean_zero + self.mean_function(Xnew)
        return f_mean, f_var

# %%
#from block_cov_utils_matern_2d import (K_full_model_1, K_full_model_2, K_full_model_3, K_full_model_4, K_full_model_5, K_full_model_6, 
#                            K_full_model_7, K_full_model_8, K_full_model_9, K_full_model_10, K_full_model_11)

# %%
from gpflow.config import default_float
#f64 = gpflow.utilities.to_default_float
def dfloat(value):  # default float
    return tf.cast(value, default_float())

def dint(value):  # default float
    return tf.cast(value, gpflow.default_int())

# %%
# k = K_full_model_1()

# m = gpflow.models.GPR(data, kernel=k, mean_function=None)
# m.kernel.lengthscale_11.assign(1.0)
# m.kernel.variance_11.assign(1.0)
# opt = gpflow.optimizers.Scipy()
# opt_logs = opt.minimize(m.training_loss, m.trainable_variables, options=dict(maxiter=100))

# %%
# m.predict_f(Xnew2)

# %%
i=5
gene_id = genes[i]
gene_id = 'Fcan01_09231'

# load the data for this gene 

data = load_data1(data_full, gene_id, samples_exp1, samples_exp2)
data = (dfloat(data[['X1', 'X2']].to_numpy()), dfloat(data['Y'].to_numpy().reshape(-1,1)))

## Pick which model to fit 
best_model = 11

# model 1
if(best_model == 1):
    k = K_full_model_1()

    m = gpflow.models.GPR(data, kernel=k, mean_function=None)
    m.kernel.lengthscale_11.assign(1.0)
    m.kernel.variance_11.assign(1.0)
    opt = gpflow.optimizers.Scipy()
    opt_logs = opt.minimize(m.training_loss, m.trainable_variables, options=dict(maxiter=100))

# model 2
if(best_model == 2):

    k = K_full_model_2()
    m = gpflow.models.GPR(data, kernel=k, mean_function=None)

    opt = gpflow.optimizers.Scipy()
    opt_logs = opt.minimize(m.training_loss, m.trainable_variables, options=dict(maxiter=100))

# model 3
if(best_model == 3):
    k = K_full_model_3()
    m = gpflow.models.GPR(data, kernel=k, mean_function=None)

    opt = gpflow.optimizers.Scipy()
    opt_logs = opt.minimize(m.training_loss, m.trainable_variables, options=dict(maxiter=100))

# model 4
if(best_model == 4):
    k = K_full_model_4()
    m = gpflow.models.GPR(data, kernel=k, mean_function=None)

    print_summary(m)

    opt = gpflow.optimizers.Scipy()
    opt_logs = opt.minimize(m.training_loss, m.trainable_variables, options=dict(maxiter=100))

# model 5
if(best_model == 5):
    k = K_full_model_5()
    m = gpflow.models.GPR(data, kernel=k, mean_function=None)

    opt = gpflow.optimizers.Scipy()
    opt_logs = opt.minimize(m.training_loss, m.trainable_variables, options=dict(maxiter=100))


# model 6
if(best_model == 6):
    k = K_full_model_6()
    m = gpflow.models.GPR(data, kernel=k, mean_function=None)

    opt = gpflow.optimizers.Scipy()
    opt_logs = opt.minimize(m.training_loss, m.trainable_variables, options=dict(maxiter=100))


# model 7
if(best_model == 7):
    k = K_full_model_7()
    m = gpflow.models.GPR(data, kernel=k, mean_function=None)

    opt = gpflow.optimizers.Scipy()
    opt_logs = opt.minimize(m.training_loss, m.trainable_variables, options=dict(maxiter=100))

# model 8
if(best_model == 8):
    k = K_full_model_8()
    m = GPR_deprecated(data, kernel=k, mean_function=None)

    opt = gpflow.optimizers.Scipy()
    opt_logs = opt.minimize(m.training_loss, m.trainable_variables, options=dict(maxiter=100))

# model 9
if(best_model == 9):
    k = K_full_model_9()
    m = gpflow.models.GPR(data, kernel=k, mean_function=None)

    print_summary(m)

    opt = gpflow.optimizers.Scipy()
    opt_logs = opt.minimize(m.training_loss, m.trainable_variables, options=dict(maxiter=100))
    
# model 10
if(best_model == 10):
    k = K_full_model_10()
    m = gpflow.models.GPR(data, kernel=k, mean_function=None)

    print_summary(m)

    opt = gpflow.optimizers.Scipy()
    opt_logs = opt.minimize(m.training_loss, m.trainable_variables, options=dict(maxiter=100))   

# model 11
if(best_model == 11):
    k = K_full_model_11()
    m = gpflow.models.GPR(data, kernel=k, mean_function=None)

    print_summary(m)

    opt = gpflow.optimizers.Scipy()
    opt_logs = opt.minimize(m.training_loss, m.trainable_variables, options=dict(maxiter=100))     

num_predict = 100

X = data[0]
Y = data[1]

n_shape = X.shape[0]
n_half_shape = int(X.shape[0]/2)

# [Xi, Xj] = np.meshgrid(np.linspace(np.min(X[:,0]), np.max(X[:,0]), num_predict), np.linspace(np.min(X[:,1]), np.max(X[:,1]), num_predict))
# X2 = X[:,0:1].copy()

# # We need to augument our test space to be a list of coordinates for input to the GP
# Xnew2 = np.vstack((Xi.ravel(), Xj.ravel())).T # Change our input grid to list of coordinates

[exp1_mesh1, exp1_mesh2] = np.meshgrid(np.linspace(np.min(X[0:n_half_shape,0]), np.max(X[0:n_half_shape,0]), num_predict), np.linspace(np.min(X[0:n_half_shape,1]), np.max(X[0:n_half_shape,1]), num_predict))
[exp2_mesh1, exp2_mesh2] = np.meshgrid(np.linspace(np.min(X[n_half_shape:n_shape,0]), np.max(X[n_half_shape:n_shape,0]), num_predict), np.linspace(np.min(X[n_half_shape:n_shape,1]), np.max(X[n_half_shape:n_shape,1]), num_predict))
Xnew2 = np.concatenate([np.vstack((exp1_mesh1.ravel(), exp1_mesh2.ravel())).T, np.vstack((exp2_mesh1.ravel(), exp2_mesh2.ravel())).T], axis=0)

# Predict the mean and covariance of the GP fit at the test locations
mean2, Cov2 = m.predict_f(Xnew2)

mean2 = np.asarray(mean2)
Cov2 = np.asarray(Cov2)

mean_shape = mean2.shape[0]
half_mean_shape = int(mean2.shape[0]/2)

mean_est1 = pd.DataFrame(mean2[0:half_mean_shape].reshape(exp1_mesh1.shape))
Cov_est1 = pd.DataFrame(Cov2[0:half_mean_shape].reshape(exp1_mesh1.shape))

mean_est2 = pd.DataFrame(mean2[half_mean_shape:mean_shape].reshape(exp2_mesh1.shape))
Cov_est2 = pd.DataFrame(Cov2[half_mean_shape:mean_shape].reshape(exp2_mesh1.shape))

# set up a figure twice as wide as it is tall
#fig = plt.figure(figsize=plt.figaspect(0.5))
fig = plt.figure(figsize=(25,10))

Z1 = mean2[0:half_mean_shape].reshape(exp1_mesh1.shape)
Z2 = mean2[half_mean_shape:mean_shape].reshape(exp2_mesh2.shape)

#===============
#  First subplot
#===============
# set up the axes for the first plot
ax = fig.add_subplot(1, 2, 1, projection='3d')

# plot a 3D surface like in the example mplot3d/surface3d_demo
surf = ax.plot_surface(exp1_mesh1, exp1_mesh2, Z1, rstride=1, cstride=1, cmap=cm.viridis,
                       linewidth=0, antialiased=False)
cbar = fig.colorbar(surf, shrink=0.5, aspect=10)
for t in cbar.ax.get_yticklabels():
             t.set_fontsize(15)

ax.scatter(X[0:n_half_shape,0], X[0:n_half_shape,1], Y[0:n_half_shape])

ax.set_xticks(np.linspace(0.0,0.4,6))
ax.set_yticks(np.linspace(0.0,0.25,6))
plt.tick_params(axis='x', labelsize=15)
plt.tick_params(axis='y', labelsize=15)
plt.tick_params(axis='z', labelsize=15)

ax.set_xlabel('IMI', fontsize=20, labelpad=15)
ax.set_ylabel('CLO', fontsize=20, labelpad=15)
ax.set_zlabel('Expression', fontsize=20, labelpad=15)

#ax.set_zlim(np.min(Y),np.max(Y))

ax.set_title(str(gene_id), fontsize=20)

#ax.view_init(15)
ax.view_init(-140, 30)
ax.view_init( 20, -120)


#===============
# Second subplot
#===============
# set up the axes for the second plot
ax = fig.add_subplot(1, 2, 2, projection='3d')

ax.plot_surface(exp2_mesh1, exp2_mesh2, Z2, rstride=10, cstride=10, cmap=cm.viridis,
                       linewidth=0, antialiased=False)
cbar = fig.colorbar(surf, shrink=0.5, aspect=10)
for t in cbar.ax.get_yticklabels():
             t.set_fontsize(15)

ax.scatter(X[n_half_shape:n_shape,0], X[n_half_shape:n_shape,1], Y[n_half_shape:n_shape])


plt.tick_params(axis='x', labelsize=15)
plt.tick_params(axis='y', labelsize=15)
plt.tick_params(axis='z', labelsize=15)

ax.set_xticks(np.linspace(0.0,0.4,6))
ax.set_yticks(np.linspace(0.0,250,6))
ax.set_xlabel('IMI', fontsize=20, labelpad=15)
ax.set_ylabel('CYPRO', fontsize=20, labelpad=15)
ax.set_zlabel('Expression', fontsize=20, labelpad=15)

#ax.set_zlim(np.min(Y),np.max(Y))

ax.set_title(str(gene_id), fontsize=20)

ax.dist = 10
#ax.view_init(15)
ax.view_init(-140, 30)
ax.view_init( 20, -120)
plt.savefig(str(gene_id)+'_model_'+str(best_model)+'_3d.png', bbox_inches = 'tight',
    pad_inches = 0)
plt.show()
# Out:
# ╒═══════════════════════════╤═══════════╤══════════════════╤═════════╤═════════════╤═════════╤═════════╤═════════╕
# │ name                      │ class     │ transform        │ prior   │ trainable   │ shape   │ dtype   │   value │
# ╞═══════════════════════════╪═══════════╪══════════════════╪═════════╪═════════════╪═════════╪═════════╪═════════╡
# │ GPR.kernel.variance_11    │ Parameter │ SoftClip         │         │ True        │ ()      │ float64 │     1   │
# ├───────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼─────────┤
# │ GPR.kernel.lengthscale_11 │ Parameter │ SoftClip         │         │ True        │ ()      │ float64 │     0.2 │
# ├───────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼─────────┤
# │ GPR.kernel.variance_12    │ Parameter │ SoftClip         │         │ True        │ ()      │ float64 │     1   │
# ├───────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼─────────┤
# │ GPR.kernel.lengthscale_12 │ Parameter │ SoftClip         │         │ True        │ ()      │ float64 │     1   │
# ├───────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼─────────┤
# │ GPR.kernel.variance_22    │ Parameter │ SoftClip         │         │ True        │ ()      │ float64 │     1   │
# ├───────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼─────────┤
# │ GPR.kernel.lengthscale_22 │ Parameter │ SoftClip         │         │ True        │ ()      │ float64 │     1   │
# ├───────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼─────────┤
# │ GPR.likelihood.variance   │ Parameter │ Softplus + Shift │         │ True        │ ()      │ float64 │     1   │
# ╘═══════════════════════════╧═══════════╧══════════════════╧═════════╧═════════════╧═════════╧═════════╧═════════╛
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[58], line 112
#     109     print_summary(m)
#     111     opt = gpflow.optimizers.Scipy()
# --> 112     opt_logs = opt.minimize(m.training_loss, m.trainable_variables, options=dict(maxiter=100))
#     114 num_predict = 100
#     116 X = data[0]
#
# File ~/opt/anaconda3/envs/gpflow/lib/python3.10/site-packages/gpflow/optimizers/scipy.py:94, in Scipy.minimize(self, closure, variables, method, step_callback, compile, allow_unused_variables, **scipy_kwargs)
#      91     callback = self.callback_func(variables, step_callback)
#      92     scipy_kwargs.update(dict(callback=callback))
# ---> 94 return scipy.optimize.minimize(
#      95     func, initial_params, jac=True, method=method, **scipy_kwargs
#      96 )
#
# File ~/opt/anaconda3/envs/gpflow/lib/python3.10/site-packages/scipy/optimize/_minimize.py:696, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     693     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     694                              **options)
#     695 elif meth == 'l-bfgs-b':
# --> 696     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     697                            callback=callback, **options)
#     698 elif meth == 'tnc':
#     699     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     700                         **options)
#
# File ~/opt/anaconda3/envs/gpflow/lib/python3.10/site-packages/scipy/optimize/_lbfgsb_py.py:305, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     302     else:
#     303         iprint = disp
# --> 305 sf = _prepare_scalar_function(fun, x0, jac=jac, args=args, epsilon=eps,
#     306                               bounds=new_bounds,
#     307                               finite_diff_rel_step=finite_diff_rel_step)
#     309 func_and_grad = sf.fun_and_grad
#     311 fortran_int = _lbfgsb.types.intvar.dtype
#
# File ~/opt/anaconda3/envs/gpflow/lib/python3.10/site-packages/scipy/optimize/_optimize.py:332, in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     328     bounds = (-np.inf, np.inf)
#     330 # ScalarFunction caches. Reuse of fun(x) during grad
#     331 # calculation reduces overall function evaluations.
# --> 332 sf = ScalarFunction(fun, x0, args, grad, hess,
#     333                     finite_diff_rel_step, bounds, epsilon=epsilon)
#     335 return sf
#
# File ~/opt/anaconda3/envs/gpflow/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:158, in ScalarFunction.__init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#     155     self.f = fun_wrapped(self.x)
#     157 self._update_fun_impl = update_fun
# --> 158 self._update_fun()
#     160 # Gradient evaluation
#     161 if callable(grad):
#
# File ~/opt/anaconda3/envs/gpflow/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:251, in ScalarFunction._update_fun(self)
#     249 def _update_fun(self):
#     250     if not self.f_updated:
# --> 251         self._update_fun_impl()
#     252         self.f_updated = True
#
# File ~/opt/anaconda3/envs/gpflow/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:155, in ScalarFunction.__init__.<locals>.update_fun()
#     154 def update_fun():
# --> 155     self.f = fun_wrapped(self.x)
#
# File ~/opt/anaconda3/envs/gpflow/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:137, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     133 self.nfev += 1
#     134 # Send a copy because the user may overwrite it.
#     135 # Overwriting results in undefined behaviour because
#     136 # fun(self.x) will change self.x, with the two no longer linked.
# --> 137 fx = fun(np.copy(x), *args)
#     138 # Make sure the function returns a true scalar
#     139 if not np.isscalar(fx):
#
# File ~/opt/anaconda3/envs/gpflow/lib/python3.10/site-packages/scipy/optimize/_optimize.py:76, in MemoizeJac.__call__(self, x, *args)
#      74 def __call__(self, x, *args):
#      75     """ returns the function value """
# ---> 76     self._compute_if_needed(x, *args)
#      77     return self._value
#
# File ~/opt/anaconda3/envs/gpflow/lib/python3.10/site-packages/scipy/optimize/_optimize.py:70, in MemoizeJac._compute_if_needed(self, x, *args)
#      68 if not np.all(x == self.x) or self._value is None or self.jac is None:
#      69     self.x = np.asarray(x).copy()
# ---> 70     fg = self.fun(x, *args)
#      71     self.jac = fg[1]
#      72     self._value = fg[0]
#
# File ~/opt/anaconda3/envs/gpflow/lib/python3.10/site-packages/gpflow/optimizers/scipy.py:136, in Scipy.eval_func.<locals>._eval(x)
#     135 def _eval(x: AnyNDArray) -> Tuple[AnyNDArray, AnyNDArray]:
# --> 136     loss, grad = _tf_eval(tf.convert_to_tensor(x))
#     137     return loss.numpy().astype(np.float64), grad.numpy().astype(np.float64)
#
# File ~/opt/anaconda3/envs/gpflow/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/__autograph_generated_file01lw0mnu.py:37, in outer_factory.<locals>.inner_factory.<locals>.tf___tf_eval(x)
#      35 loss = ag__.Undefined('loss')
#      36 grads = ag__.Undefined('grads')
# ---> 37 ag__.if_stmt(ag__.ld(first_call), if_body, else_body, get_state, set_state, ('grads', 'loss', 'first_call'), 2)
#      38 try:
#      39     do_return = True
#
# File /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/__autograph_generated_file01lw0mnu.py:28, in outer_factory.<locals>.inner_factory.<locals>.tf___tf_eval.<locals>.if_body()
#      26 def if_body():
#      27     nonlocal grads, first_call, loss
# ---> 28     (loss, grads) = ag__.converted_call(ag__.ld(_compute_loss_and_gradients), (ag__.ld(closure), ag__.ld(variables), ag__.ld(tf).UnconnectedGradients.NONE), None, fscope)
#      29     grads = ag__.converted_call(ag__.ld(cls)._filter_unused_variables, (ag__.ld(variables), ag__.ld(grads), ag__.ld(allow_unused_variables)), None, fscope)
#      30     first_call = False
#
# File /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/__autograph_generated_file20d5wz2z.py:12, in outer_factory.<locals>.inner_factory.<locals>.tf___compute_loss_and_gradients(loss_closure, variables, unconnected_gradients)
#      10 with ag__.ld(tf).GradientTape(watch_accessed_variables=False) as tape:
#      11     ag__.converted_call(ag__.ld(tape).watch, (ag__.ld(variables),), None, fscope)
# ---> 12     loss = ag__.converted_call(ag__.ld(loss_closure), (), None, fscope)
#      13 grads = ag__.converted_call(ag__.ld(tape).gradient, (ag__.ld(loss), ag__.ld(variables)), dict(unconnected_gradients=ag__.ld(unconnected_gradients)), fscope)
#      14 try:
#
# File /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/__autograph_generated_file432a6ycc.py:13, in outer_factory.<locals>.inner_factory.<locals>.tf__wrapped_method(self, *args, **kwargs)
#      11 try:
#      12     do_return = True
# ---> 13     retval_ = ag__.converted_call(ag__.ld(wrapped_function), (ag__.ld(self),) + tuple(ag__.ld(args)), dict(**ag__.ld(kwargs)), fscope)
#      14 except:
#      15     do_return = False
#
# File /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/__autograph_generated_filemlez42g6.py:171, in outer_factory.<locals>.inner_factory.<locals>.tf__wrapped_function(*args, **kwargs)
#     169 arg_map = ag__.Undefined('arg_map')
#     170 bound_arguments = ag__.Undefined('bound_arguments')
# --> 171 ag__.if_stmt(ag__.not_(ag__.converted_call(ag__.ld(get_enable_check_shapes), (), None, fscope)), if_body_4, else_body_4, get_state_7, set_state_7, ('arg_map', 'arg_map[RESULT_TOKEN]', 'checker', 'do_return', 'retval_'), 5)
#     172 return fscope.ret(retval_, do_return)
#
# File /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/__autograph_generated_filemlez42g6.py:28, in outer_factory.<locals>.inner_factory.<locals>.tf__wrapped_function.<locals>.if_body_4()
#      26 try:
#      27     do_return = True
# ---> 28     retval_ = ag__.converted_call(ag__.ld(func), tuple(ag__.ld(args)), dict(**ag__.ld(kwargs)), fscope)
#      29 except:
#      30     do_return = False
#
# File /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/__autograph_generated_filebcw1edq5.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__training_loss(self)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(self)._training_loss, (), None, fscope)
#      16 except:
#      17     do_return = False
#
# File /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/__autograph_generated_file432a6ycc.py:13, in outer_factory.<locals>.inner_factory.<locals>.tf__wrapped_method(self, *args, **kwargs)
#      11 try:
#      12     do_return = True
# ---> 13     retval_ = ag__.converted_call(ag__.ld(wrapped_function), (ag__.ld(self),) + tuple(ag__.ld(args)), dict(**ag__.ld(kwargs)), fscope)
#      14 except:
#      15     do_return = False
#
# File /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/__autograph_generated_filemlez42g6.py:171, in outer_factory.<locals>.inner_factory.<locals>.tf__wrapped_function(*args, **kwargs)
#     169 arg_map = ag__.Undefined('arg_map')
#     170 bound_arguments = ag__.Undefined('bound_arguments')
# --> 171 ag__.if_stmt(ag__.not_(ag__.converted_call(ag__.ld(get_enable_check_shapes), (), None, fscope)), if_body_4, else_body_4, get_state_7, set_state_7, ('arg_map', 'arg_map[RESULT_TOKEN]', 'checker', 'do_return', 'retval_'), 5)
#     172 return fscope.ret(retval_, do_return)
#
# File /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/__autograph_generated_filemlez42g6.py:28, in outer_factory.<locals>.inner_factory.<locals>.tf__wrapped_function.<locals>.if_body_4()
#      26 try:
#      27     do_return = True
# ---> 28     retval_ = ag__.converted_call(ag__.ld(func), tuple(ag__.ld(args)), dict(**ag__.ld(kwargs)), fscope)
#      29 except:
#      30     do_return = False
#
# File /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/__autograph_generated_file4066tqh1.py:16, in outer_factory.<locals>.inner_factory.<locals>.tf___training_loss(self, *args, **kwargs)
#      14 try:
#      15     do_return = True
# ---> 16     retval_ = -(ag__.converted_call(ag__.ld(self).maximum_log_likelihood_objective, tuple(ag__.ld(args)), dict(**ag__.ld(kwargs)), fscope) + ag__.converted_call(ag__.ld(self).log_prior_density, (), None, fscope))
#      17 except:
#      18     do_return = False
#
# File /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/__autograph_generated_file432a6ycc.py:13, in outer_factory.<locals>.inner_factory.<locals>.tf__wrapped_method(self, *args, **kwargs)
#      11 try:
#      12     do_return = True
# ---> 13     retval_ = ag__.converted_call(ag__.ld(wrapped_function), (ag__.ld(self),) + tuple(ag__.ld(args)), dict(**ag__.ld(kwargs)), fscope)
#      14 except:
#      15     do_return = False
#
# File /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/__autograph_generated_filemlez42g6.py:171, in outer_factory.<locals>.inner_factory.<locals>.tf__wrapped_function(*args, **kwargs)
#     169 arg_map = ag__.Undefined('arg_map')
#     170 bound_arguments = ag__.Undefined('bound_arguments')
# --> 171 ag__.if_stmt(ag__.not_(ag__.converted_call(ag__.ld(get_enable_check_shapes), (), None, fscope)), if_body_4, else_body_4, get_state_7, set_state_7, ('arg_map', 'arg_map[RESULT_TOKEN]', 'checker', 'do_return', 'retval_'), 5)
#     172 return fscope.ret(retval_, do_return)
#
# File /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/__autograph_generated_filemlez42g6.py:28, in outer_factory.<locals>.inner_factory.<locals>.tf__wrapped_function.<locals>.if_body_4()
#      26 try:
#      27     do_return = True
# ---> 28     retval_ = ag__.converted_call(ag__.ld(func), tuple(ag__.ld(args)), dict(**ag__.ld(kwargs)), fscope)
#      29 except:
#      30     do_return = False
#
# File /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/__autograph_generated_file2v68565w.py:12, in outer_factory.<locals>.inner_factory.<locals>.tf__maximum_log_likelihood_objective(self)
#      10 try:
#      11     do_return = True
# ---> 12     retval_ = ag__.converted_call(ag__.ld(self).log_marginal_likelihood, (), None, fscope)
#      13 except:
#      14     do_return = False
#
# File /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/__autograph_generated_file432a6ycc.py:13, in outer_factory.<locals>.inner_factory.<locals>.tf__wrapped_method(self, *args, **kwargs)
#      11 try:
#      12     do_return = True
# ---> 13     retval_ = ag__.converted_call(ag__.ld(wrapped_function), (ag__.ld(self),) + tuple(ag__.ld(args)), dict(**ag__.ld(kwargs)), fscope)
#      14 except:
#      15     do_return = False
#
# File /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/__autograph_generated_filemlez42g6.py:171, in outer_factory.<locals>.inner_factory.<locals>.tf__wrapped_function(*args, **kwargs)
#     169 arg_map = ag__.Undefined('arg_map')
#     170 bound_arguments = ag__.Undefined('bound_arguments')
# --> 171 ag__.if_stmt(ag__.not_(ag__.converted_call(ag__.ld(get_enable_check_shapes), (), None, fscope)), if_body_4, else_body_4, get_state_7, set_state_7, ('arg_map', 'arg_map[RESULT_TOKEN]', 'checker', 'do_return', 'retval_'), 5)
#     172 return fscope.ret(retval_, do_return)
#
# File /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/__autograph_generated_filemlez42g6.py:28, in outer_factory.<locals>.inner_factory.<locals>.tf__wrapped_function.<locals>.if_body_4()
#      26 try:
#      27     do_return = True
# ---> 28     retval_ = ag__.converted_call(ag__.ld(func), tuple(ag__.ld(args)), dict(**ag__.ld(kwargs)), fscope)
#      29 except:
#      30     do_return = False
#
# File /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/__autograph_generated_fileii2klvo2.py:18, in outer_factory.<locals>.inner_factory.<locals>.tf__log_marginal_likelihood(self)
#      16 retval_ = ag__.UndefinedReturnValue()
#      17 (X, Y) = ag__.ld(self).data
# ---> 18 K = ag__.converted_call(ag__.ld(self).kernel, (ag__.ld(X),), None, fscope)
#      19 ks = ag__.converted_call(ag__.ld(add_likelihood_noise_cov), (ag__.ld(K), ag__.ld(self).likelihood, ag__.ld(X)), None, fscope)
#      20 L = ag__.converted_call(ag__.ld(tf).linalg.cholesky, (ag__.ld(ks),), None, fscope)
#
# File /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/__autograph_generated_file432a6ycc.py:13, in outer_factory.<locals>.inner_factory.<locals>.tf__wrapped_method(self, *args, **kwargs)
#      11 try:
#      12     do_return = True
# ---> 13     retval_ = ag__.converted_call(ag__.ld(wrapped_function), (ag__.ld(self),) + tuple(ag__.ld(args)), dict(**ag__.ld(kwargs)), fscope)
#      14 except:
#      15     do_return = False
#
# File /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/__autograph_generated_filemlez42g6.py:171, in outer_factory.<locals>.inner_factory.<locals>.tf__wrapped_function(*args, **kwargs)
#     169 arg_map = ag__.Undefined('arg_map')
#     170 bound_arguments = ag__.Undefined('bound_arguments')
# --> 171 ag__.if_stmt(ag__.not_(ag__.converted_call(ag__.ld(get_enable_check_shapes), (), None, fscope)), if_body_4, else_body_4, get_state_7, set_state_7, ('arg_map', 'arg_map[RESULT_TOKEN]', 'checker', 'do_return', 'retval_'), 5)
#     172 return fscope.ret(retval_, do_return)
#
# File /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/__autograph_generated_filemlez42g6.py:28, in outer_factory.<locals>.inner_factory.<locals>.tf__wrapped_function.<locals>.if_body_4()
#      26 try:
#      27     do_return = True
# ---> 28     retval_ = ag__.converted_call(ag__.ld(func), tuple(ag__.ld(args)), dict(**ag__.ld(kwargs)), fscope)
#      29 except:
#      30     do_return = False
#
# File /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/__autograph_generated_fileufvgwut3.py:65, in outer_factory.<locals>.inner_factory.<locals>.tf____call__(self, X, X2, full_cov, presliced)
#      63         do_return = False
#      64         raise
# ---> 65 ag__.if_stmt(ag__.not_(ag__.ld(full_cov)), if_body_2, else_body_2, get_state_2, set_state_2, ('do_return', 'retval_'), 2)
#      66 return fscope.ret(retval_, do_return)
#
# File /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/__autograph_generated_fileufvgwut3.py:61, in outer_factory.<locals>.inner_factory.<locals>.tf____call__.<locals>.else_body_2()
#      59 try:
#      60     do_return = True
# ---> 61     retval_ = ag__.converted_call(ag__.ld(self).K, (ag__.ld(X), ag__.ld(X2)), None, fscope)
#      62 except:
#      63     do_return = False
#
# File /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/__autograph_generated_filep3bzsr73.py:48, in outer_factory.<locals>.inner_factory.<locals>.tf__K(self, X, X2)
#      46 K_dada_exp2 = ag__.ld(self).variance_11 * ag__.converted_call(ag__.ld(tf).exp, (-0.5 * (ag__.ld(diff_X_da_exp2) / ag__.ld(self).lengthscale_11) ** 2,), None, fscope)
#      47 diff_X_dc_exp2 = ag__.ld(X_matrix_dc_exp2) - ag__.ld(X_matrix_tr_dc_exp2)
# ---> 48 K_dcdc_exp2 = ag__.ld(self).variance_23 * ag__.converted_call(ag__.ld(tf).exp, (-0.5 * (ag__.ld(diff_X_dc_exp2) / ag__.ld(self).lengthscale_23) ** 2,), None, fscope)
#      49 K_xx = ag__.ld(K_dada_exp1) + ag__.ld(K_dbdb_exp1)
#      50 K_ff = ag__.ld(K_dada_exp2) + ag__.ld(K_dcdc_exp2) + ag__.ld(K_dada_exp2) * ag__.ld(K_dcdc_exp2)
#
# AttributeError: in user code:
#
#     File "/Users/yuliya/opt/anaconda3/envs/gpflow/lib/python3.10/site-packages/gpflow/optimizers/scipy.py", line 120, in _tf_eval  *
#         loss, grads = _compute_loss_and_gradients(
#     File "/Users/yuliya/opt/anaconda3/envs/gpflow/lib/python3.10/site-packages/gpflow/optimizers/scipy.py", line 223, in _compute_loss_and_gradients  *
#         loss = loss_closure()
#     File "/Users/yuliya/opt/anaconda3/envs/gpflow/lib/python3.10/site-packages/check_shapes/integration/tf.py", line 57, in wrapped_method  *
#         return wrapped_function(self, *args, **kwargs)
#     File "/Users/yuliya/opt/anaconda3/envs/gpflow/lib/python3.10/site-packages/check_shapes/decorator.py", line 120, in wrapped_function  *
#         return func(*args, **kwargs)
#     File "/Users/yuliya/opt/anaconda3/envs/gpflow/lib/python3.10/site-packages/gpflow/models/training_mixins.py", line 64, in training_loss  *
#         return self._training_loss()  # type: ignore[attr-defined]
#     File "/Users/yuliya/opt/anaconda3/envs/gpflow/lib/python3.10/site-packages/check_shapes/integration/tf.py", line 57, in wrapped_method  *
#         return wrapped_function(self, *args, **kwargs)
#     File "/Users/yuliya/opt/anaconda3/envs/gpflow/lib/python3.10/site-packages/check_shapes/decorator.py", line 120, in wrapped_function  *
#         return func(*args, **kwargs)
#     File "/Users/yuliya/opt/anaconda3/envs/gpflow/lib/python3.10/site-packages/gpflow/models/model.py", line 76, in _training_loss  *
#         return -(self.maximum_log_likelihood_objective(*args, **kwargs) + self.log_prior_density())
#     File "/Users/yuliya/opt/anaconda3/envs/gpflow/lib/python3.10/site-packages/check_shapes/integration/tf.py", line 57, in wrapped_method  *
#         return wrapped_function(self, *args, **kwargs)
#     File "/Users/yuliya/opt/anaconda3/envs/gpflow/lib/python3.10/site-packages/check_shapes/decorator.py", line 120, in wrapped_function  *
#         return func(*args, **kwargs)
#     File "/Users/yuliya/opt/anaconda3/envs/gpflow/lib/python3.10/site-packages/gpflow/models/gpr.py", line 86, in maximum_log_likelihood_objective  *
#         return self.log_marginal_likelihood()
#     File "/Users/yuliya/opt/anaconda3/envs/gpflow/lib/python3.10/site-packages/check_shapes/integration/tf.py", line 57, in wrapped_method  *
#         return wrapped_function(self, *args, **kwargs)
#     File "/Users/yuliya/opt/anaconda3/envs/gpflow/lib/python3.10/site-packages/check_shapes/decorator.py", line 120, in wrapped_function  *
#         return func(*args, **kwargs)
#     File "/Users/yuliya/opt/anaconda3/envs/gpflow/lib/python3.10/site-packages/gpflow/models/gpr.py", line 100, in log_marginal_likelihood  *
#         K = self.kernel(X)
#     File "/Users/yuliya/opt/anaconda3/envs/gpflow/lib/python3.10/site-packages/check_shapes/integration/tf.py", line 57, in wrapped_method  *
#         return wrapped_function(self, *args, **kwargs)
#     File "/Users/yuliya/opt/anaconda3/envs/gpflow/lib/python3.10/site-packages/check_shapes/decorator.py", line 120, in wrapped_function  *
#         return func(*args, **kwargs)
#     File "/Users/yuliya/opt/anaconda3/envs/gpflow/lib/python3.10/site-packages/gpflow/kernels/base.py", line 214, in __call__  *
#         return self.K(X, X2)
#     File "/Users/yuliya/Dropbox/Research/VU/MixToxOmics/MixToxOmics_prep/new/block_cov_utils_rbf_2d.py", line 1631, in K  *
#         K_dcdc_exp2 = self.variance_23*tf.exp(-0.5*(diff_X_dc_exp2/self.lengthscale_23)**2)
#
#     AttributeError: 'K_full_model_11' object has no attribute 'variance_23'

# %%
m
