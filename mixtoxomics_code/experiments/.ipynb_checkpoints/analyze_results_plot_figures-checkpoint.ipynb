# %%
import numpy as np
import tensorflow_probability as tfp
import pandas as pd
from bisect import bisect_left
from scipy import special
from scipy.special import erf
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from numpy.linalg import inv
import tensorflow as tf
import scipy.linalg
import gpflow
from scipy.stats.distributions import chi2
import pandas as pd
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from gpflow.utilities import print_summary, positive
np.set_printoptions(suppress=True)
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from gpflow import set_trainable
import tensorflow_probability as tfp
from tensorflow_probability import distributions as tfd
f64 = gpflow.utilities.to_default_float
import sys
sys.path.append('..')

from gpflow.config import default_float
#f64 = gpflow.utilities.to_default_float
def dfloat(value):  # default float
    return tf.cast(value, default_float())

def dint(value):  # default float
    return tf.cast(value, gpflow.default_int())

def likelihood_ratio(lik_reduced, lik_full):
    return(-np.asarray(lik_full)-(-np.asarray(lik_reduced)))

from mpl_toolkits.mplot3d import Axes3D
# Axes3D import has side effects, it enables using projection='3d' in add_subplot
import random
from scipy.stats.distributions import chi2

from utils.block_cov_utils_rbf_2d import (K_full_model_1, K_full_model_2, K_full_model_3, K_full_model_4, K_full_model_5, K_full_model_6,
                            K_full_model_7, K_full_model_8, K_full_model_9, K_full_model_10, K_full_model_11)

# %%
def load_data1(data, gene_id, samples_exp1, samples_exp2):

    y_exp1 = data[data['Unnamed: 0'] == gene_id][samples_exp1].to_numpy().reshape(-1,1)
    y_exp2 = data[data['Unnamed: 0'] == gene_id][samples_exp2].to_numpy().reshape(-1,1)

    TU_IMI_exp1 = metadata[metadata['experiment']==1]['conc_IMI'].to_numpy().reshape(-1,1)
    TU_IMI_exp2 = metadata[metadata['experiment']==2]['conc_IMI'].to_numpy().reshape(-1,1)

    TU_CLO_exp1 = metadata[metadata['experiment']==1]['conc_CLO'].to_numpy().reshape(-1,1)
    TU_CLO_exp2 = metadata[metadata['experiment']==2]['conc_CLO'].to_numpy().reshape(-1,1)

    TU_CYPRO_exp1 = metadata[metadata['experiment']==1]['conc_CYPRO'].to_numpy().reshape(-1,1)
    TU_CYPRO_exp2 = metadata[metadata['experiment']==2]['conc_CYPRO'].to_numpy().reshape(-1,1)

    df_exp1 = pd.concat([pd.DataFrame(TU_IMI_exp1), pd.DataFrame(TU_CLO_exp1), pd.DataFrame(y_exp1)], axis=1)
    df_exp2 = pd.concat([pd.DataFrame(TU_IMI_exp2), pd.DataFrame(TU_CYPRO_exp2), pd.DataFrame(y_exp2)], axis=1)

    df_exp1.columns = ['conc_IMI', 'conc_CLO', 'y_exp1']
    df_exp2.columns = ['conc_IMI', 'conc_CYPRO', 'y_exp2']
    df_exp1['exp'] = 'exp1'
    df_exp2['exp'] = 'exp2'
    df_exp1.columns = ['', '', '', '']
    df_exp2.columns = ['', '', '', '']

    df = pd.concat([df_exp1, df_exp2], axis=0)
    df.columns = ['X1', 'X2', 'Y', 'exp']
    df['Y'] = (df['Y'] - np.min(df['Y']))/(np.max(df['Y'])-np.min(df['Y']))
    #df.columns = ['conc_drug1', 'conc_drug2', 'y']
    #df['conc_drug12'] = df['conc_drug1']*df['conc_drug2']
    #df_X = pd.concat([df['conc_drug1'], df['conc_drug2'], df['conc_drug12']], axis=1)
    #df_X.columns = ['','','']
    #X_full = df[[]].to_numpy()
    #Y_full = df['y'].to_numpy().reshape(-1,1)
    #Y_full = (Y_full - np.min(Y_full))/(np.max(Y_full)-np.min(Y_full))

    return df

# %%
# Set seed
np.random.seed(1000)

# %%
data_full_exp1 = pd.read_csv('../data/raw_exp1.csv')
data_full_exp2 = pd.read_csv('../data/raw_exp2.csv')
data_full_exp2 = data_full_exp2.drop(columns=['Unnamed: 0'])
metadata = pd.read_csv('../data/metadata.csv')

data_full = pd.concat([data_full_exp1, data_full_exp2], axis=1)

genes = data_full['Unnamed: 0'].to_numpy()
subset = data_full[data_full['Unnamed: 0'].isin(genes)]

samples_exp1 = metadata[metadata['experiment']==1]['sample']
samples_exp1 = samples_exp1.to_numpy().astype(str).tolist()

samples_exp2 = metadata[metadata['experiment']==2]['sample']
samples_exp2 = samples_exp2.to_numpy().astype(str).tolist()

string = 'Sample_'
samples_exp1 = [string + x for x in samples_exp1]
samples_exp2 = [string + x for x in samples_exp2]

# %%
results = pd.read_csv('output/model_fit_all_genes_25000_28617.csv')
results = pd.read_csv('output/model_fit_all_genes_20000_25000.csv')

# %%
results['p_val_9_11'] = chi2.sf(likelihood_ratio(results['model_11'], results['model_9']), 2)

# %%
threshold = 0.1

# %%
results_reduced = results[results['p_val_21']<threshold]
results_reduced = results_reduced[results['p_val_31']<threshold]
# Out:
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_10746/3325925239.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   results_reduced = results_reduced[results['p_val_31']<threshold]

# %%
results_reduced = results_reduced[results['p_val_42']<threshold]
# Out:
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_10746/1544903403.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   results_reduced = results_reduced[results['p_val_42']<threshold]

# %%
#results_reduced = results_reduced[results['p_val_9_11']<threshold]

# %%
loglik_model_1_list = []
loglik_model_2_list = []
loglik_model_3_list = []
loglik_model_4_list = []
loglik_model_5_list = []
loglik_model_6_list = []
loglik_model_7_list = []
loglik_model_8_list = []
loglik_model_9_list = []
loglik_model_10_list = []
loglik_model_11_list = []
genes_list = []

# %%
#for i in range(300,400):
# Load the data to extract input points
# gene_id = 'Fcan01_06830'
# gene_id = 'Fcan01_13627'
# gene_id = 'Fcan01_01431'
# gene_id = 'Fcan01_08638'
# gene_id = 'Fcan01_13564'
# gene_id = 'Fcan01_20262'
# gene_id = 'Fcan01_17454'
# gene_id = 'Fcan01_18435'

gene_id_list = ['Fcan01_13564', 'Fcan01_01431', 'Fcan01_08638', 
                'Fcan01_18435', 'Fcan01_20262', 'Fcan01_17454']

gene_names_list = ['ARRD', 'nAchR', 'SMCT', 'ABC', 'CYP', 'SMPD']

# 0, 2, 4

best_model_list = [2, 2, 2, 3, 3, 2, 2, 2]
for i in range(0,6):

    best_model = best_model_list[i]
    gene_id = gene_id_list[i]
    gene_name = gene_names_list[i]

    data = load_data1(data_full, gene_id, samples_exp1, samples_exp2)
    data = (data[['X1', 'X2']].to_numpy(), data['Y'].to_numpy().reshape(-1,1))

    ## Pick which model to fit 

    # model 1
    if(best_model == 1):
        k = K_full_model_1()

        m = gpflow.models.GPR(data, kernel=k, mean_function=None)
        m.likelihood.variance.assign(0.001)

        opt = gpflow.optimizers.Scipy()
        opt_logs = opt.minimize(m.training_loss, m.trainable_variables, options=dict(maxiter=100))

        loglik_model_1 = np.asarray(m.training_loss())

        print('loglik_model_1', loglik_model_1)

        loglik_model_1_list.append(loglik_model_1)

    # model 2
    if(best_model == 2):

        k = K_full_model_2()
        m = gpflow.models.GPR(data, kernel=k, mean_function=None)
        m.likelihood.variance.assign(0.001)

        opt = gpflow.optimizers.Scipy()
        opt_logs = opt.minimize(m.training_loss, m.trainable_variables, options=dict(maxiter=100))

        loglik_model_2 = np.asarray(m.training_loss())

        print('loglik_model_2', loglik_model_2)

        loglik_model_2_list.append(loglik_model_2)

    # model 3
    if(best_model == 3):
        k = K_full_model_3()
        m = gpflow.models.GPR(data, kernel=k, mean_function=None)
        m.likelihood.variance.assign(0.001)

        opt = gpflow.optimizers.Scipy()
        opt_logs = opt.minimize(m.training_loss, m.trainable_variables, options=dict(maxiter=100))

        loglik_model_3 = np.asarray(m.training_loss())

        loglik_model_3_list.append(loglik_model_3)

    # model 4
    if(best_model == 4):
        k = K_full_model_4()
        m = gpflow.models.GPR(data, kernel=k, mean_function=None)
        m.likelihood.variance.assign(0.001)

        opt = gpflow.optimizers.Scipy()
        opt_logs = opt.minimize(m.training_loss, m.trainable_variables, options=dict(maxiter=100))

        loglik_model_4 = np.asarray(m.training_loss())

        loglik_model_4_list.append(loglik_model_4)

    # model 5
    if(best_model == 5):
        k = K_full_model_5()
        m = gpflow.models.GPR(data, kernel=k, mean_function=None)
        m.likelihood.variance.assign(0.001)

        opt = gpflow.optimizers.Scipy()
        opt_logs = opt.minimize(m.training_loss, m.trainable_variables, options=dict(maxiter=100))

        loglik_model_5 = np.asarray(m.training_loss())

        loglik_model_5_list.append(loglik_model_5)


    # model 6
    if(best_model == 6):
        k = K_full_model_6()
        m = gpflow.models.GPR(data, kernel=k, mean_function=None)
        m.likelihood.variance.assign(0.001)

        opt = gpflow.optimizers.Scipy()
        opt_logs = opt.minimize(m.training_loss, m.trainable_variables, options=dict(maxiter=100))

        loglik_model_6 = np.asarray(m.training_loss())

        loglik_model_6_list.append(loglik_model_6)


    # model 7
    if(best_model == 7):
        k = K_full_model_7()
        m = gpflow.models.GPR(data, kernel=k, mean_function=None)
        m.likelihood.variance.assign(0.001)

        opt = gpflow.optimizers.Scipy()
        opt_logs = opt.minimize(m.training_loss, m.trainable_variables, options=dict(maxiter=100))

        loglik_model_7 = np.asarray(m.training_loss())

        loglik_model_7_list.append(loglik_model_7)

    # model 8
    if(best_model == 8):
        k = K_full_model_8()
        m = gpflow.models.GPR(data, kernel=k, mean_function=None)
        m.likelihood.variance.assign(0.001)

        opt = gpflow.optimizers.Scipy()
        opt_logs = opt.minimize(m.training_loss, m.trainable_variables, options=dict(maxiter=100))

        loglik_model_8 = np.asarray(m.training_loss())

        loglik_model_8_list.append(loglik_model_8)

    # model 9
    if(best_model == 9):
        k = K_full_model_9()
        m = gpflow.models.GPR(data, kernel=k, mean_function=None)
        m.likelihood.variance.assign(0.001)

        opt = gpflow.optimizers.Scipy()
        opt_logs = opt.minimize(m.training_loss, m.trainable_variables, options=dict(maxiter=100))

        loglik_model_9 = np.asarray(m.training_loss())

        loglik_model_9_list.append(loglik_model_9)

    # model 10
    if(best_model == 10):
        k = K_full_model_10()
        m = gpflow.models.GPR(data, kernel=k, mean_function=None)
        m.likelihood.variance.assign(0.001)

        opt = gpflow.optimizers.Scipy()
        opt_logs = opt.minimize(m.training_loss, m.trainable_variables, options=dict(maxiter=100))   

        loglik_model_10 = np.asarray(m.training_loss())

        loglik_model_10_list.append(loglik_model_10)

    # model 11
    if(best_model == 11):
        k = K_full_model_11()
        m = gpflow.models.GPR(data, kernel=k, mean_function=None)
        m.likelihood.variance.assign(0.001)

        opt = gpflow.optimizers.Scipy()
        opt_logs = opt.minimize(m.training_loss, m.trainable_variables, options=dict(maxiter=100))

        loglik_model_11 = np.asarray(m.training_loss())

        loglik_model_11_list.append(loglik_model_11)

    print_summary(m)

    num_predict = 100

    X = data[0]
    Y = data[1]

    n_shape = X.shape[0]
    n_half_shape = int(X.shape[0]/2)

    # [Xi, Xj] = np.meshgrid(np.linspace(np.min(X[:,0]), np.max(X[:,0]), num_predict), np.linspace(np.min(X[:,1]), np.max(X[:,1]), num_predict))
    # X2 = X[:,0:1].copy()

    # # We need to augument our test space to be a list of coordinates for input to the GP
    # Xnew2 = np.vstack((Xi.ravel(), Xj.ravel())).T # Change our input grid to list of coordinates

    [exp1_mesh1, exp1_mesh2] = np.meshgrid(np.linspace(np.min(X[0:n_half_shape,0]), np.max(X[0:n_half_shape,0]), num_predict), np.linspace(np.min(X[0:n_half_shape,1]), np.max(X[0:n_half_shape,1]), num_predict))
    [exp2_mesh1, exp2_mesh2] = np.meshgrid(np.linspace(np.min(X[n_half_shape:n_shape,0]), np.max(X[n_half_shape:n_shape,0]), num_predict), np.linspace(np.min(X[n_half_shape:n_shape,1]), np.max(X[n_half_shape:n_shape,1]), num_predict))
    Xnew2 = np.concatenate([np.vstack((exp1_mesh1.ravel(), exp1_mesh2.ravel())).T, np.vstack((exp2_mesh1.ravel(), exp2_mesh2.ravel())).T], axis=0)

    # Predict the mean and covariance of the GP fit at the test locations
    mean2, Cov2 = m.predict_f(Xnew2)

    mean2 = np.asarray(mean2)
    Cov2 = np.asarray(Cov2)

    mean_shape = mean2.shape[0]
    half_mean_shape = int(mean2.shape[0]/2)

    mean_est1 = pd.DataFrame(mean2[0:half_mean_shape].reshape(exp1_mesh1.shape))
    Cov_est1 = pd.DataFrame(Cov2[0:half_mean_shape].reshape(exp1_mesh1.shape))

    mean_est2 = pd.DataFrame(mean2[half_mean_shape:mean_shape].reshape(exp2_mesh1.shape))
    Cov_est2 = pd.DataFrame(Cov2[half_mean_shape:mean_shape].reshape(exp2_mesh1.shape))

    # set up a figure twice as wide as it is tall
    #fig = plt.figure(figsize=plt.figaspect(0.5))
    fig = plt.figure(figsize=(25,10))
    #plt.title('Gene name')
    plt.suptitle(str(gene_name), fontsize=45)
    #plt.subplots_adjust(wspace=0, hspace=0)

    Z1 = mean2[0:half_mean_shape].reshape(exp1_mesh1.shape)
    Z2 = mean2[half_mean_shape:mean_shape].reshape(exp2_mesh2.shape)

    Cov_est1 = np.asarray(Cov_est1)
    Cov_est2 = np.asarray(Cov_est2)

    Z1_cov = Cov_est1.reshape(exp1_mesh1.shape)
    Z2_cov = Cov_est2.reshape(exp2_mesh2.shape)

    Z2_95_l_exp2 = Z2 - 1.96*np.sqrt(Z2_cov)
    Z2_95_u_exp2 = Z2 + 1.96*np.sqrt(Z2_cov)

    Z1_95_l_exp1 = Z1 - 1.96*np.sqrt(Z1_cov)
    Z1_95_u_exp1 = Z1 + 1.96*np.sqrt(Z1_cov)

    #===============
    #  First subplot
    #===============
    # set up the axes for the first plot
    ax = fig.add_subplot(1, 2, 1, projection='3d')

    # plot a 3D surface like in the example mplot3d/surface3d_demo
    surf = ax.plot_surface(exp1_mesh1, exp1_mesh2, Z1, rstride=1, cstride=1, cmap=cm.viridis,
                           linewidth=0, antialiased=False,vmin=0,vmax=0.6)

    ax.plot_surface(exp1_mesh1, exp1_mesh2, Z1_95_l_exp1, rstride=10, cstride=10, cmap='gray',
                           linewidth=0, antialiased=False, alpha=0.3)

    ax.plot_surface(exp1_mesh1, exp1_mesh2, Z1_95_u_exp1, rstride=10, cstride=10, cmap='gray',
                           linewidth=0, antialiased=False, alpha=0.3)


    cbar = fig.colorbar(surf, shrink=0.5, aspect=10)
    for t in cbar.ax.get_yticklabels():
                 t.set_fontsize(25)
    cbar.set_label('Scaled Expression', fontsize=32)

    ax.scatter(X[0:n_half_shape,0], X[0:n_half_shape,1], Y[0:n_half_shape], s=100)

    ax.set_xticks(np.linspace(0.0,0.4,6))
    ax.set_yticks(np.linspace(0.0,0.25,6))
    plt.tick_params(axis='x', labelsize=25)
    plt.tick_params(axis='y', labelsize=25)
    plt.tick_params(axis='z', labelsize=25)

    ax.set_xlabel('IMI (mg/kg)', fontsize=30, labelpad=15)
    ax.set_ylabel('CLO (mg/kg)', fontsize=30, labelpad=15)
    #ax.set_zlabel('Scaled Expression', fontsize=22, labelpad=15)

    #ax.set_zlim(np.min(Y),np.max(Y))

    #ax.set_title('Experiment 1  ' + '('+str(gene_id)+ ')', fontsize=25)
    #ax.set_title('Neonicotinoid exposure' + '('+str(gene_id)+ ')', fontsize=35)
    #if(i==0):
    ax.set_title('Neonicotinoid exposure', fontsize=45)

    #plt.tick_params(left = False, right = False , labelleft = False , 
    #                labelbottom = False, bottom = False)

    #plt.subplots_adjust(wspace=0.0, hspace=0.0)  
    ax.set_zlim(0,0.7)
    #ax.view_init(15)
    ax.view_init(-140, 30)
    ax.view_init( 20, -120)
    plt.locator_params(nbins=4)
    plt.subplots_adjust(wspace=None, hspace=None)

    #===============
    # Second subplot
    #===============
    # set up the axes for the second plot
    ax = fig.add_subplot(1, 2, 2, projection='3d')

    surf = ax.plot_surface(exp2_mesh1, exp2_mesh2, Z2, rstride=10, cstride=10, cmap=cm.viridis,
                           linewidth=0, antialiased=False,vmin=0,vmax=0.6)

    ax.plot_surface(exp2_mesh1, exp2_mesh2, Z2_95_l_exp2, rstride=10, cstride=10, cmap='gray',
                           linewidth=0, antialiased=False, alpha=0.3)

    ax.plot_surface(exp2_mesh1, exp2_mesh2, Z2_95_u_exp2, rstride=10, cstride=10, cmap='gray',
                           linewidth=0, antialiased=False, alpha=0.3)


    # 0, 2, 4

    cbar = fig.colorbar(surf, shrink=0.5, aspect=10)
    for t in cbar.ax.get_yticklabels():
                 t.set_fontsize(25)

    cbar.set_label('Scaled Expression', fontsize=32)

    ax.scatter(X[n_half_shape:n_shape,0], X[n_half_shape:n_shape,1], Y[n_half_shape:n_shape], s=100)


    plt.tick_params(axis='x', labelsize=25)
    plt.tick_params(axis='y', labelsize=25)
    plt.tick_params(axis='z', labelsize=25)

    ax.set_xticks(np.linspace(0.0,0.4,6))
    ax.set_yticks(np.linspace(0.0,250,6))
    ax.set_xlabel('IMI (mg/kg)', fontsize=30, labelpad=15)
    ax.set_ylabel('CYPRO (mg/kg)', fontsize=30, labelpad=15)
    #ax.set_zlabel('Scaled Expression', fontsize=22, labelpad=15)

    #ax.set_zlim(np.min(Y),np.max(Y))
    #ax.set_title('Cyproconazole exposure' + '('+str(gene_id)+ ')', fontsize=35)
    #if(i==0):
    ax.set_title('Cyproconazole exposure', fontsize=45)

    ax.dist = 10
    #ax.view_init(15)
    ax.view_init(-140, 30)
    ax.view_init( 20, -120)

    plt.tight_layout(rect=[0.2, 0.5, 0.1, 1.0])
    plt.tight_layout()

    #plt.subplots_adjust(wspace=0.0, hspace=0.0)  
    #fig.subplots_adjust(left=0.2)
    #plt.tick_params(left = False, right = False , labelleft = False , 
    #                labelbottom = False, bottom = False)
    ax.set_zlim(0,0.7)
    plt.locator_params(nbins=4)
    plt.subplots_adjust(wspace=None, hspace=None)
    plt.savefig(str(gene_id)+'_model_'+str(best_model)+'_3d.png', bbox_inches = 'tight',
        pad_inches = 0)
    plt.show()
# Out:
# 2023-10-09 22:04:34.336690: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# loglik_model_2 -38.05037603342166
# ╒═══════════════════════════╤═══════════╤══════════════════╤═════════╤═════════════╤═════════╤═════════╤═════════╕
# │ name                      │ class     │ transform        │ prior   │ trainable   │ shape   │ dtype   │   value │
# ╞═══════════════════════════╪═══════════╪══════════════════╪═════════╪═════════════╪═════════╪═════════╪═════════╡
# │ GPR.kernel.variance_11    │ Parameter │ SoftClip         │         │ True        │ ()      │ float64 │ 0.17747 │
# ├───────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼─────────┤
# │ GPR.kernel.lengthscale_11 │ Parameter │ SoftClip         │         │ True        │ ()      │ float64 │ 1.09734 │
# ├───────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼─────────┤
# │ GPR.kernel.variance_22    │ Parameter │ SoftClip         │         │ True        │ ()      │ float64 │ 0.00226 │
# ├───────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼─────────┤
# │ GPR.kernel.lengthscale_22 │ Parameter │ SoftClip         │         │ True        │ ()      │ float64 │ 8.79801 │
# ├───────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼─────────┤
# │ GPR.likelihood.variance   │ Parameter │ Softplus + Shift │         │ True        │ ()      │ float64 │ 0.03316 │
# ╘═══════════════════════════╧═══════════╧══════════════════╧═════════╧═════════════╧═════════╧═════════╧═════════╛
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_10746/2955603435.py:333: MatplotlibDeprecationWarning: The dist attribute was deprecated in Matplotlib 3.6 and will be removed two minor releases later.
#   ax.dist = 10
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_10746/2955603435.py:338: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout(rect=[0.2, 0.5, 0.1, 1.0])
# 2023-10-09 22:04:36.803231: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# loglik_model_2 -109.5070143867099
# ╒═══════════════════════════╤═══════════╤══════════════════╤═════════╤═════════════╤═════════╤═════════╤══════════╕
# │ name                      │ class     │ transform        │ prior   │ trainable   │ shape   │ dtype   │    value │
# ╞═══════════════════════════╪═══════════╪══════════════════╪═════════╪═════════════╪═════════╪═════════╪══════════╡
# │ GPR.kernel.variance_11    │ Parameter │ SoftClip         │         │ True        │ ()      │ float64 │  0.27964 │
# ├───────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼──────────┤
# │ GPR.kernel.lengthscale_11 │ Parameter │ SoftClip         │         │ True        │ ()      │ float64 │  0.55114 │
# ├───────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼──────────┤
# │ GPR.kernel.variance_22    │ Parameter │ SoftClip         │         │ True        │ ()      │ float64 │  0.0039  │
# ├───────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼──────────┤
# │ GPR.kernel.lengthscale_22 │ Parameter │ SoftClip         │         │ True        │ ()      │ float64 │ 24.714   │
# ├───────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼──────────┤
# │ GPR.likelihood.variance   │ Parameter │ Softplus + Shift │         │ True        │ ()      │ float64 │  0.013   │
# ╘═══════════════════════════╧═══════════╧══════════════════╧═════════╧═════════════╧═════════╧═════════╧══════════╛
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_10746/2955603435.py:333: MatplotlibDeprecationWarning: The dist attribute was deprecated in Matplotlib 3.6 and will be removed two minor releases later.
#   ax.dist = 10
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_10746/2955603435.py:338: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout(rect=[0.2, 0.5, 0.1, 1.0])
# 2023-10-09 22:04:39.160171: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# loglik_model_2 -105.68376770523909
# ╒═══════════════════════════╤═══════════╤══════════════════╤═════════╤═════════════╤═════════╤═════════╤═══════════╕
# │ name                      │ class     │ transform        │ prior   │ trainable   │ shape   │ dtype   │     value │
# ╞═══════════════════════════╪═══════════╪══════════════════╪═════════╪═════════════╪═════════╪═════════╪═══════════╡
# │ GPR.kernel.variance_11    │ Parameter │ SoftClip         │         │ True        │ ()      │ float64 │   0.22531 │
# ├───────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼───────────┤
# │ GPR.kernel.lengthscale_11 │ Parameter │ SoftClip         │         │ True        │ ()      │ float64 │   0.52584 │
# ├───────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼───────────┤
# │ GPR.kernel.variance_22    │ Parameter │ SoftClip         │         │ True        │ ()      │ float64 │   0.02353 │
# ├───────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼───────────┤
# │ GPR.kernel.lengthscale_22 │ Parameter │ SoftClip         │         │ True        │ ()      │ float64 │ 391.422   │
# ├───────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼───────────┤
# │ GPR.likelihood.variance   │ Parameter │ Softplus + Shift │         │ True        │ ()      │ float64 │   0.01417 │
# ╘═══════════════════════════╧═══════════╧══════════════════╧═════════╧═════════════╧═════════╧═════════╧═══════════╛
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_10746/2955603435.py:333: MatplotlibDeprecationWarning: The dist attribute was deprecated in Matplotlib 3.6 and will be removed two minor releases later.
#   ax.dist = 10
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_10746/2955603435.py:338: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout(rect=[0.2, 0.5, 0.1, 1.0])
# 2023-10-09 22:04:41.404433: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# ╒═══════════════════════════╤═══════════╤══════════════════╤═════════╤═════════════╤═════════╤═════════╤════════════╕
# │ name                      │ class     │ transform        │ prior   │ trainable   │ shape   │ dtype   │      value │
# ╞═══════════════════════════╪═══════════╪══════════════════╪═════════╪═════════════╪═════════╪═════════╪════════════╡
# │ GPR.kernel.variance_11    │ Parameter │ SoftClip         │         │ True        │ ()      │ float64 │    0.04902 │
# ├───────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼────────────┤
# │ GPR.kernel.lengthscale_11 │ Parameter │ SoftClip         │         │ True        │ ()      │ float64 │ 1000       │
# ├───────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼────────────┤
# │ GPR.kernel.variance_12    │ Parameter │ SoftClip         │         │ True        │ ()      │ float64 │    1e-05   │
# ├───────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼────────────┤
# │ GPR.kernel.lengthscale_12 │ Parameter │ SoftClip         │         │ True        │ ()      │ float64 │ 1000       │
# ├───────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼────────────┤
# │ GPR.likelihood.variance   │ Parameter │ Softplus + Shift │         │ True        │ ()      │ float64 │    0.0255  │
# ╘═══════════════════════════╧═══════════╧══════════════════╧═════════╧═════════════╧═════════╧═════════╧════════════╛
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_10746/2955603435.py:333: MatplotlibDeprecationWarning: The dist attribute was deprecated in Matplotlib 3.6 and will be removed two minor releases later.
#   ax.dist = 10
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_10746/2955603435.py:338: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout(rect=[0.2, 0.5, 0.1, 1.0])
# 2023-10-09 22:04:43.902552: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# ╒═══════════════════════════╤═══════════╤══════════════════╤═════════╤═════════════╤═════════╤═════════╤═══════════╕
# │ name                      │ class     │ transform        │ prior   │ trainable   │ shape   │ dtype   │     value │
# ╞═══════════════════════════╪═══════════╪══════════════════╪═════════╪═════════════╪═════════╪═════════╪═══════════╡
# │ GPR.kernel.variance_11    │ Parameter │ SoftClip         │         │ True        │ ()      │ float64 │   0.03886 │
# ├───────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼───────────┤
# │ GPR.kernel.lengthscale_11 │ Parameter │ SoftClip         │         │ True        │ ()      │ float64 │ 129.482   │
# ├───────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼───────────┤
# │ GPR.kernel.variance_12    │ Parameter │ SoftClip         │         │ True        │ ()      │ float64 │   1e-05   │
# ├───────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼───────────┤
# │ GPR.kernel.lengthscale_12 │ Parameter │ SoftClip         │         │ True        │ ()      │ float64 │ 101.413   │
# ├───────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼───────────┤
# │ GPR.likelihood.variance   │ Parameter │ Softplus + Shift │         │ True        │ ()      │ float64 │   0.02618 │
# ╘═══════════════════════════╧═══════════╧══════════════════╧═════════╧═════════════╧═════════╧═════════╧═══════════╛
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_10746/2955603435.py:333: MatplotlibDeprecationWarning: The dist attribute was deprecated in Matplotlib 3.6 and will be removed two minor releases later.
#   ax.dist = 10
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_10746/2955603435.py:338: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout(rect=[0.2, 0.5, 0.1, 1.0])
# 2023-10-09 22:04:46.215301: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# loglik_model_2 -44.43939956489345
# ╒═══════════════════════════╤═══════════╤══════════════════╤═════════╤═════════════╤═════════╤═════════╤══════════╕
# │ name                      │ class     │ transform        │ prior   │ trainable   │ shape   │ dtype   │    value │
# ╞═══════════════════════════╪═══════════╪══════════════════╪═════════╪═════════════╪═════════╪═════════╪══════════╡
# │ GPR.kernel.variance_11    │ Parameter │ SoftClip         │         │ True        │ ()      │ float64 │  0.20308 │
# ├───────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼──────────┤
# │ GPR.kernel.lengthscale_11 │ Parameter │ SoftClip         │         │ True        │ ()      │ float64 │  1.75014 │
# ├───────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼──────────┤
# │ GPR.kernel.variance_22    │ Parameter │ SoftClip         │         │ True        │ ()      │ float64 │  0.0116  │
# ├───────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼──────────┤
# │ GPR.kernel.lengthscale_22 │ Parameter │ SoftClip         │         │ True        │ ()      │ float64 │ 45.3627  │
# ├───────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼──────────┤
# │ GPR.likelihood.variance   │ Parameter │ Softplus + Shift │         │ True        │ ()      │ float64 │  0.03015 │
# ╘═══════════════════════════╧═══════════╧══════════════════╧═════════╧═════════════╧═════════╧═════════╧══════════╛
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_10746/2955603435.py:333: MatplotlibDeprecationWarning: The dist attribute was deprecated in Matplotlib 3.6 and will be removed two minor releases later.
#   ax.dist = 10
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_10746/2955603435.py:338: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout(rect=[0.2, 0.5, 0.1, 1.0])

# %%
loglik_model_1 -103.37199651918846
loglik_model_2 -109.5070143867099

# %%
chi2.sf(likelihood_ratio(-103.37199651918846, -109.5070143867099), 2)
# Out:
# 0.046536937179929246

# %%
loglik_results = pd.DataFrame([np.asarray(loglik_model_1_list), np.asarray(loglik_model_2_list),
             np.asarray(loglik_model_3_list), np.asarray(loglik_model_4_list),
             np.asarray(loglik_model_5_list), np.asarray(loglik_model_6_list),
             np.asarray(loglik_model_7_list), np.asarray(loglik_model_8_list),
             np.asarray(loglik_model_9_list), np.asarray(loglik_model_10_list),
                              np.asarray(loglik_model_11_list)])

loglik_results.index = ['model_1', 'model_2', 'model_3',
                         'model_4', 'model_5', 'model_6',
                         'model_7', 'model_8', 'model_9', 'model_10', 'model_11']


loglik_results = loglik_results.T

loglik_results['p_val_21'] = chi2.sf(likelihood_ratio(loglik_results['model_1'], loglik_results['model_2']), 2)
loglik_results['p_val_31'] = chi2.sf(likelihood_ratio(loglik_results['model_1'], loglik_results['model_3']), 2)
loglik_results['p_val_41'] = chi2.sf(likelihood_ratio(loglik_results['model_1'], loglik_results['model_4']), 4)
loglik_results['p_val_42'] = chi2.sf(likelihood_ratio(loglik_results['model_2'], loglik_results['model_4']), 2)
loglik_results['p_val_43'] = chi2.sf(likelihood_ratio(loglik_results['model_3'], loglik_results['model_3']), 2)
loglik_results['p_val_51'] = chi2.sf(likelihood_ratio(loglik_results['model_1'], loglik_results['model_5']), 2)
loglik_results['p_val_52'] = chi2.sf(likelihood_ratio(loglik_results['model_2'], loglik_results['model_5']), 2)
loglik_results['p_val_61'] = chi2.sf(likelihood_ratio(loglik_results['model_1'], loglik_results['model_6']), 2)
loglik_results['p_val_62'] = chi2.sf(likelihood_ratio(loglik_results['model_2'], loglik_results['model_6']), 2)
loglik_results['p_val_63'] = chi2.sf(likelihood_ratio(loglik_results['model_3'], loglik_results['model_6']), 2)
loglik_results['p_val_64'] = chi2.sf(likelihood_ratio(loglik_results['model_4'], loglik_results['model_6']), 2)
loglik_results['p_val_71'] = chi2.sf(likelihood_ratio(loglik_results['model_1'], loglik_results['model_7']), 2) #???
loglik_results['p_val_73'] = chi2.sf(likelihood_ratio(loglik_results['model_3'], loglik_results['model_7']), 2) #???
loglik_results['p_val_87'] = chi2.sf(likelihood_ratio(loglik_results['model_7'], loglik_results['model_8']), 2) #???
loglik_results['p_val_97'] = chi2.sf(likelihood_ratio(loglik_results['model_7'], loglik_results['model_9']), 2) #???
loglik_results['p_val_98'] = chi2.sf(likelihood_ratio(loglik_results['model_8'], loglik_results['model_9']), 2) #???
loglik_results['p_val_82'] = chi2.sf(likelihood_ratio(loglik_results['model_2'], loglik_results['model_8']), 2) #???
loglik_results['p_val_53'] = chi2.sf(likelihood_ratio(loglik_results['model_3'], loglik_results['model_5']), 2) #???
loglik_results['p_val_31'] = chi2.sf(likelihood_ratio(loglik_results['model_1'], loglik_results['model_3']), 2) #???
loglik_results['p_val_21'] = chi2.sf(likelihood_ratio(loglik_results['model_1'], loglik_results['model_2']), 2) #???
loglik_results['p_val_41'] = chi2.sf(likelihood_ratio(loglik_results['model_1'], loglik_results['model_4']), 2) #???
loglik_results['p_val_87'] = chi2.sf(likelihood_ratio(loglik_results['model_7'], loglik_results['model_8']), 2) #???
loglik_results['p_val_95'] = chi2.sf(likelihood_ratio(loglik_results['model_5'], loglik_results['model_9']), 2) #???

# %%
loglik_results['p_val_9_10'] = chi2.sf(likelihood_ratio(loglik_results['model_10'], loglik_results['model_9']), 2)

# %%
loglik_results['p_val_83'] = chi2.sf(likelihood_ratio(loglik_results['model_3'], loglik_results['model_8']), 2)

# %%
loglik_results['p_val_9_11'] = chi2.sf(likelihood_ratio(loglik_results['model_11'], loglik_results['model_9']), 2)

# %%
loglik_results['p_val_9_11'] = chi2.sf(likelihood_ratio(loglik_results['model_10'], loglik_results['model_9']), 2)

# %%
loglik_results['p_val_31']
# Out:
# 0    0.876887
# Name: p_val_31, dtype: float64

# %%
m
# Out:
# <gpflow.models.gpr.GPR object at 0x2dff21a00>
# ╒═══════════════════════════╤═══════════╤══════════════════╤═════════╤═════════════╤═════════╤═════════╤═══════════╕
# │ name                      │ class     │ transform        │ prior   │ trainable   │ shape   │ dtype   │     value │
# ╞═══════════════════════════╪═══════════╪══════════════════╪═════════╪═════════════╪═════════╪═════════╪═══════════╡
# │ GPR.kernel.variance_11    │ Parameter │ SoftClip         │         │ False       │ ()      │ float64 │   0.08923 │
# ├───────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼───────────┤
# │ GPR.kernel.lengthscale_11 │ Parameter │ SoftClip         │         │ True        │ ()      │ float64 │ 999       │
# ├───────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼───────────┤
# │ GPR.kernel.variance_22    │ Parameter │ SoftClip         │         │ True        │ ()      │ float64 │   0.02079 │
# ├───────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼───────────┤
# │ GPR.kernel.lengthscale_22 │ Parameter │ SoftClip         │         │ True        │ ()      │ float64 │  41.8193  │
# ├───────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼───────────┤
# │ GPR.likelihood.variance   │ Parameter │ Softplus + Shift │         │ True        │ ()      │ float64 │   0.02073 │
# ╘═══════════════════════════╧═══════════╧══════════════════╧═════════╧═════════════╧═════════╧═════════╧═══════════╛

# %%
m.kernel.lengthscale_11.assign(999.0)
# Out:
# <tf.Variable 'UnreadVariable' shape=() dtype=float64, numpy=999.4586751453871>
