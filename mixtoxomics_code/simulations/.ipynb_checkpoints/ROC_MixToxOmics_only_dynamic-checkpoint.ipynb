# %%
from sklearn.metrics import roc_curve, auc
from sklearn import datasets
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import LinearSVC
from sklearn.preprocessing import label_binarize
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd
from scipy.stats.distributions import chi2
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
#import seaborn as sns
import sys
sys.path.append('..')
np.set_printoptions(suppress=True)

# %%
plt.style.use('ggplot')
#plt.rcParams['axes.facecolor']='w'

# %%
def likelihood_ratio(lik_reduced, lik_full):
    return(-np.asarray(lik_full)-(-np.asarray(lik_reduced)))

# %%
data = pd.read_csv('df_dynamics.csv')

# %%
data2 = pd.read_csv('df_flat.csv')

# %%
loglik_results = pd.read_csv('output/loglik_results_simulated_data.csv')
#loglik_results = pd.read_csv('output/loglik_results_simulated_data_noise_sd_01.csv')
loglik_results = pd.read_csv('output/loglik_results_simulated_data_noise_sd_03.csv')

# %%
loglik_results['model'] = data['model']

# %%
#model2 = loglik_results[loglik_results['p_val_21']<0.15]

# %%
loglik_results['inferred_label_2'] = 0
loglik_results['true_label_2'] = 0

loglik_results['inferred_label_3'] = 0
loglik_results['true_label_3'] = 0

loglik_results['inferred_label_4'] = 0
loglik_results['true_label_4'] = 0

loglik_results['inferred_label_5'] = 0
loglik_results['true_label_5'] = 0

loglik_results['inferred_label_6'] = 0
loglik_results['true_label_6'] = 0

loglik_results['inferred_label_7'] = 0
loglik_results['true_label_7'] = 0

loglik_results['inferred_label_8'] = 0
loglik_results['true_label_8'] = 0

loglik_results['inferred_label_9'] = 0
loglik_results['true_label_9'] = 0

loglik_results['inferred_label_10'] = 0
loglik_results['true_label_10'] = 0

loglik_results['inferred_label_11'] = 0
loglik_results['true_label_11'] = 0

# %%
# Do we need to compute p_val_81?

# %%
threshold = 0.15

# %%
for i in range(0,2200):
    if(loglik_results.iloc[i]['p_val_21']<threshold and loglik_results.iloc[i]['p_val_31']>threshold and 
       loglik_results.iloc[i]['p_val_82']>threshold and loglik_results.iloc[i]['p_val_42']>threshold and 
       loglik_results.iloc[i]['p_val_43']>threshold):
        loglik_results['inferred_label_2'].iloc[i] = 1
    if(loglik_results.iloc[i]['model']==2):  
        loglik_results['true_label_2'].iloc[i] = 1
# Out:
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_49759/3392119199.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loglik_results['inferred_label_2'].iloc[i] = 1
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_49759/3392119199.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loglik_results['true_label_2'].iloc[i] = 1

# %%
#loglik_results = loglik_results[loglik_results['model'].isin([1,2])]

# %%
#loglik_results[loglik_results['model']==2]['p_val_82']

# %%
# # Compute ROC curve and ROC area for each class
# #fpr = dict()
# #tpr = dict()
# #roc_auc = dict()
# #for i in range(n_classes):
# fpr, tpr, _ = roc_curve(loglik_results['inferred_label_2'].to_numpy(), loglik_results['true_label_2'].to_numpy())
# roc_auc = auc(fpr, tpr)

# %%
# plt.figure()
# plt.plot(fpr, tpr, '--', label='ROC curve (area = %0.2f)' % roc_auc)
# plt.plot([0, 1], [0, 1], 'k--')
# plt.xlim([0.0, 1.0])
# plt.ylim([0.0, 1.05])
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('Receiver operating characteristic example')
# plt.legend(loc="lower right")
# plt.show()

# %%
#sum(loglik_results['true_label'])

# %% [markdown]
# ### Model 3

# %%
loglik_results['p_val_11_3'] = chi2.sf(likelihood_ratio(loglik_results['model_8'], loglik_results['model_11']), 2) #???

# %%
loglik_results['p_val_9_11'] = chi2.sf(likelihood_ratio(loglik_results['model_11'], loglik_results['model_9']), 2) #???

# %%
loglik_results['p_val_10_5'] = chi2.sf(likelihood_ratio(loglik_results['model_5'], loglik_results['model_10']), 2) #???

# %%
loglik_results['p_val_11_4'] = chi2.sf(likelihood_ratio(loglik_results['model_4'], loglik_results['model_11']), 2) #???

# %%
for i in range(0,2200):
    #if(loglik_results.iloc[i]['p_val_31']<threshold and loglik_results.iloc[i]['p_val_21']>threshold and 
    #   loglik_results.iloc[i]['p_val_53']>threshold and loglik_results.iloc[i]['p_val_43']>threshold and 
    #   loglik_results.iloc[i]['p_val_42']>threshold):
    if(loglik_results.iloc[i]['p_val_31']<threshold and loglik_results.iloc[i]['p_val_21']>threshold and 
      loglik_results.iloc[i]['p_val_63']>threshold and loglik_results.iloc[i]['p_val_9_11']>threshold and 
      loglik_results.iloc[i]['p_val_43']>threshold and loglik_results.iloc[i]['p_val_10_5']>threshold and 
      loglik_results.iloc[i]['p_val_11_4']>threshold):
        loglik_results['inferred_label_3'].iloc[i] = 1
    if(loglik_results.iloc[i]['model']==3):  
        loglik_results['true_label_3'].iloc[i] = 1
# Out:
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_49759/3782403986.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loglik_results['inferred_label_3'].iloc[i] = 1
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_49759/3782403986.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loglik_results['true_label_3'].iloc[i] = 1

# %%
#loglik_results[loglik_results['model']==1]

# %%
# # Compute ROC curve and ROC area for each class
# #fpr = dict()
# #tpr = dict()
# #roc_auc = dict()
# #for i in range(n_classes):
# fpr, tpr, _ = roc_curve(loglik_results['inferred_label'].to_numpy(), loglik_results['true_label'].to_numpy())
# roc_auc = auc(fpr, tpr)

# %%
# plt.figure()
# plt.plot(fpr, tpr, '--', label='ROC curve (area = %0.2f)' % roc_auc)
# plt.plot([0, 1], [0, 1], 'k--')
# plt.xlim([0.0, 1.0])
# plt.ylim([0.0, 1.05])
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('Receiver operating characteristic example')
# plt.legend(loc="lower right")
# plt.show()

# %%
#sum(loglik_results['true_label']-loglik_results['inferred_label'])

# %%
#np.unique(loglik_results[loglik_results['inferred_label']==1]['model'])

# %% [markdown]
# ### Model 4

# %%
loglik_results['p_val_43'] = chi2.sf(likelihood_ratio(loglik_results['model_3'], loglik_results['model_4']), 2) #???

# %%
loglik_results['p_val_10_4'] = chi2.sf(likelihood_ratio(loglik_results['model_4'], loglik_results['model_10']), 1) #???

# %%
loglik_results['p_val_9_10'] = chi2.sf(likelihood_ratio(loglik_results['model_10'], loglik_results['model_9']), 2) #???

# %%
# loglik_results['inferred_label'] = 0
# loglik_results['true_label'] = 0

# %%
for i in range(0,2200):
    #if(loglik_results.iloc[i]['p_val_31']<threshold and loglik_results.iloc[i]['p_val_21']>threshold and 
    #   loglik_results.iloc[i]['p_val_53']>threshold and loglik_results.iloc[i]['p_val_43']>threshold and 
    #   loglik_results.iloc[i]['p_val_42']>threshold):
    if(loglik_results.iloc[i]['p_val_43']<threshold and loglik_results.iloc[i]['p_val_42']<threshold and 
       loglik_results.iloc[i]['p_val_11_4']>threshold and loglik_results.iloc[i]['p_val_10_4']>threshold and 
       loglik_results.iloc[i]['p_val_9_11']>threshold and loglik_results.iloc[i]['p_val_9_10']>threshold and
       loglik_results.iloc[i]['p_val_53']>threshold and loglik_results.iloc[i]['p_val_82']>threshold):
        loglik_results['inferred_label_4'].iloc[i] = 1
    if(loglik_results.iloc[i]['model']==4):  
        loglik_results['true_label_4'].iloc[i] = 1
# Out:
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_49759/1396202605.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loglik_results['inferred_label_4'].iloc[i] = 1
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_49759/1396202605.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loglik_results['true_label_4'].iloc[i] = 1

# %%
#loglik_results[loglik_results['model']==4]

# %%
# Compute ROC curve and ROC area for each class
#fpr = dict()
#tpr = dict()
#roc_auc = dict()
#for i in range(n_classes):
fpr, tpr, _ = roc_curve(loglik_results['inferred_label_4'].to_numpy(), loglik_results['true_label_4'].to_numpy())
roc_auc = auc(fpr, tpr)

# %%
plt.figure()
plt.plot(fpr, tpr, '--', label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()

# %%
sum(loglik_results['true_label_4']-loglik_results['inferred_label_4'])
# Out:
# -76

# %%
np.unique(loglik_results[loglik_results['inferred_label_4']==1]['model'])
# Out:
# array([ 2,  4,  9, 10, 11])

# %%
test = loglik_results[loglik_results['inferred_label_4']==1]
test[test['model']==10]
# Out:
#       Unnamed: 0     model_1     model_2     model_3    model_4     model_5  \
# 1811        1811   71.234477   62.404660   64.430894  54.263943   64.537438
# 1812        1812  122.029657   72.350443  116.390789  57.573472  117.128111
# 1818        1818  155.790332  117.452710  130.325488  67.936709  131.066161
# 1822        1822  134.497703  126.529426   76.824544  52.837652   77.207327
# 1825        1825   83.835338   62.625220   77.190496  52.494566   77.277960
# 1829        1829  155.602194  155.466820   73.996093  69.476216   74.612258
# 1833        1833  213.731813  178.758001  162.823133  65.373663  163.163023
# 1835        1835  203.870197  203.571616   64.408032  59.037574   65.427984
# 1838        1838   78.434551   69.379055   73.403192  62.933832   72.441163
# 1839        1839  130.659243  127.074494   69.463317  58.740530   71.000940
# 1842        1842  117.645580   99.506505   91.303760  60.858639   90.934396
# 1851        1851   97.685369   91.228983   70.374302  58.265923   69.728720
# 1852        1852  225.071600  225.058544   65.733174  53.193273   67.437705
# 1853        1853  133.068872  132.811001   63.663129  59.640711   63.304106
# 1856        1856  184.538169   82.613008  181.870350  66.399531  182.049749
# 1858        1858  139.904391  125.515101   91.516655  55.869424   91.823233
# 1860        1860  162.809846  108.132860  146.973009  66.408279  147.819892
# 1863        1863  180.758543  170.483483  106.034985  64.332717  107.897021
# 1875        1875  175.401146  171.579917   82.172732  62.104993   82.439034
# 1877        1877  156.941518  153.059078   84.123888  67.814232   84.777945
# 1879        1879  221.896140  213.367976  118.642620  54.232899  118.476736
# 1885        1885  139.871077   90.994402  135.362880  77.564140  135.940149
# 1895        1895  121.085455  112.916497   76.460433  56.432781   76.470123
# 1902        1902  178.855133  174.444730   90.453200  66.886932   91.185933
# 1903        1903  115.487378  103.430272   78.755564  55.441790   79.997892
# 1910        1910  116.481842   69.633510  115.153082  65.164080  114.713196
# 1917        1917   99.529419   95.854672   65.928178  57.524318   65.851652
# 1939        1939  152.551056  148.670850   75.841349  62.774994   76.705265
# 1941        1941  240.719659  130.941447  231.836615  69.913865  232.058250
# 1948        1948  227.870438  173.525210  196.924320  70.450079  198.060988
# 1958        1958  225.787357  196.310513  173.774722  79.337805  174.543605
# 1959        1959  127.447535   92.510866  114.324641  67.388843  114.724384
# 1963        1963  103.278771   75.274036   98.606725  66.418859   98.693455
# 1976        1976  187.323026  181.943935   98.732220  65.765910  100.128450
# 1998        1998  122.101089  106.633014   87.654198  56.912238   87.416219
#
#          model_6     model_7     model_8    model_9  ...  inferred_label_10  \
# 1811   64.817060   62.457751   62.370110  54.104563  ...                  0
# 1812  117.234480   71.321978   72.630791  57.053886  ...                  0
# 1818  133.262991  117.891334  118.087298  69.060233  ...                  0
# 1822   79.815588  126.335662  126.935154  52.888765  ...                  0
# 1825   77.350228   64.787321   63.038954  53.050476  ...                  0
# 1829   77.718692  153.530280  155.520519  68.860605  ...                  0
# 1833  163.243201  179.939610  180.274406  66.707021  ...                  0
# 1835   65.485566  203.760835  203.580481  60.203400  ...                  0
# 1838   72.074717   69.287429   69.770097  62.066368  ...                  0
# 1839   72.544620  127.680451  127.327070  60.170319  ...                  0
# 1842   91.037845   99.048812  100.062210  62.642392  ...                  0
# 1851   69.765641   91.321898   91.403678  57.294305  ...                  0
# 1852   68.357035  225.400853  225.069724  54.811652  ...                  0
# 1853   63.604870  133.012177  132.860402  59.368961  ...                  0
# 1856  182.139122   84.459902   84.981376  67.595332  ...                  0
# 1858   93.194197  127.274944  126.361772  56.187330  ...                  0
# 1860  148.633408  109.828056  109.685493  64.099008  ...                  0
# 1863  109.902083  172.325439  171.073751  66.637106  ...                  0
# 1875   82.540337  171.211818  171.668950  61.851218  ...                  0
# 1877   86.035151  154.667128  153.830528  69.045473  ...                  0
# 1879  118.744795  213.587726  213.603111  55.035652  ...                  0
# 1885  136.052277   92.654395   93.162665  80.992822  ...                  0
# 1895   76.610589  115.868955  113.924620  57.136805  ...                  0
# 1902   92.886135  175.142067  174.432325  67.024228  ...                  0
# 1903   80.715399  102.224778  103.997586  57.110863  ...                  0
# 1910  114.353071   71.793361   71.605772  66.272728  ...                  0
# 1917   66.101789   95.575740   96.144025  57.645781  ...                  0
# 1939   77.012911  149.147778  149.278104  63.647923  ...                  0
# 1941  232.129756  132.221336  133.251062  72.038123  ...                  0
# 1948  198.945608  174.413352  175.733937  70.223941  ...                  0
# 1958  174.845338  196.227986  196.177202  80.622432  ...                  0
# 1959  115.358816   92.692678   93.194455  68.275688  ...                  0
# 1963   98.829529   76.783117   76.276086  67.012555  ...                  0
# 1976  101.088266  184.557265  182.779609  68.318308  ...                  0
# 1998   88.851982  108.701109  107.703232  55.948245  ...                  0
#
#       true_label_10  inferred_label_11  true_label_11    p_val_11_3  \
# 1811              0                  0              0  1.600347e-02
# 1812              0                  0              0  5.888923e-04
# 1818              0                  0              0  1.703560e-11
# 1822              0                  0              0  8.659731e-17
# 1825              0                  0              0  6.462001e-03
# 1829              0                  0              0  2.396069e-19
# 1833              0                  0              0  2.201829e-25
# 1835              0                  0              0  4.725271e-32
# 1838              0                  0              0  3.957733e-02
# 1839              0                  0              0  1.352080e-15
# 1842              0                  0              0  1.375830e-08
# 1851              0                  0              0  7.285227e-08
# 1852              0                  0              0  6.681160e-38
# 1853              0                  0              0  1.241631e-16
# 1856              0                  0              0  3.051871e-04
# 1858              0                  0              0  8.742354e-16
# 1860              0                  0              0  2.780304e-10
# 1863              0                  0              0  1.497601e-23
# 1875              0                  0              0  1.645038e-24
# 1877              0                  0              0  4.374699e-19
# 1879              0                  0              0  4.414318e-35
# 1885              0                  0              0  1.456481e-03
# 1895              0                  0              0  5.643100e-13
# 1902              0                  0              0  3.736891e-24
# 1903              0                  0              0  3.706381e-11
# 1910              0                  0              0  1.127203e-01
# 1917              0                  0              0  5.077051e-09
# 1939              0                  0              0  1.865165e-19
# 1941              0                  0              0  6.359206e-14
# 1948              0                  0              0  1.294395e-23
# 1958              0                  0              0  6.775914e-26
# 1959              0                  0              0  4.100297e-06
# 1963              0                  0              0  1.098741e-02
# 1976              0                  0              0  8.457261e-26
# 1998              0                  0              0  1.558083e-11
#
#       p_val_9_11    p_val_10_5  p_val_11_4  p_val_10_4  p_val_9_10
# 1811    1.000000  6.029982e-03    0.921395    1.000000    0.899941
# 1812    0.703853  8.220118e-14    1.000000    0.401251    1.000000
# 1818    1.000000  3.022943e-14    1.000000    1.000000    1.000000
# 1822    0.962779  4.875288e-06    1.000000    0.760412    1.000000
# 1825    1.000000  4.379278e-06    1.000000    1.000000    1.000000
# 1829    0.634658  5.258469e-02    1.000000    0.385018    1.000000
# 1833    0.991681  6.433135e-22    1.000000    1.000000    1.000000
# 1835    1.000000  6.417474e-02    1.000000    1.000000    1.000000
# 1838    0.536673  4.489880e-03    1.000000    0.253388    1.000000
# 1839    1.000000  4.321078e-03    1.000000    1.000000    1.000000
# 1842    0.544283  1.764561e-07    1.000000    0.311423    1.000000
# 1851    0.538023  2.046096e-03    1.000000    0.337253    0.974934
# 1852    1.000000  1.341160e-03    1.000000    1.000000    1.000000
# 1853    0.886225  1.469788e-01    0.985023    0.678748    0.951129
# 1856    0.549670  5.559320e-26    1.000000    0.418951    1.000000
# 1858    0.660975  1.101036e-08    1.000000    0.404452    1.000000
# 1860    0.453867  1.198056e-18    0.694416    0.289908    0.551777
# 1863    1.000000  5.580070e-10    1.000000    1.000000    1.000000
# 1875    0.865379  3.389589e-05    1.000000    0.616799    0.998310
# 1877    0.887587  2.062018e-04    1.000000    0.921961    1.000000
# 1879    0.836855  2.233027e-14    1.000000    1.000000    0.749980
# 1885    1.000000  3.529557e-13    1.000000    1.000000    1.000000
# 1895    0.826352  4.087503e-05    1.000000    0.677775    1.000000
# 1902    1.000000  7.147233e-06    0.842744    1.000000    0.792893
# 1903    1.000000  9.626475e-06    1.000000    1.000000    1.000000
# 1910    0.616513  8.183253e-12    1.000000    0.219330    1.000000
# 1917    0.860203  1.371437e-02    1.000000    0.616169    1.000000
# 1939    1.000000  1.287849e-03    1.000000    1.000000    1.000000
# 1941    0.802373  9.775019e-36    1.000000    1.000000    1.000000
# 1948    0.947826  2.202025e-28    0.942250    1.000000    0.790161
# 1958    1.000000  9.429677e-21    1.000000    1.000000    0.427346
# 1959    0.946549  5.153351e-11    1.000000    0.837551    1.000000
# 1963    0.886246  8.939686e-08    1.000000    0.666465    1.000000
# 1976    1.000000  6.062503e-08    1.000000    1.000000    1.000000
# 1998    0.370644  9.175052e-08    1.000000    0.167586    1.000000
#
# [35 rows x 58 columns]

# %% [markdown]
# ### Model 5

# %%
loglik_results['p_val_56'] = chi2.sf(likelihood_ratio(loglik_results['model_6'], loglik_results['model_5']), 2) #???

# %%
# loglik_results['inferred_label'] = 0
# loglik_results['true_label'] = 0

# %%
for i in range(0,2200):
    #if(loglik_results.iloc[i]['p_val_31']<threshold and loglik_results.iloc[i]['p_val_21']>threshold and 
    #   loglik_results.iloc[i]['p_val_53']>threshold and loglik_results.iloc[i]['p_val_43']>threshold and 
    #   loglik_results.iloc[i]['p_val_42']>threshold):
    if(loglik_results.iloc[i]['p_val_53']<threshold and loglik_results.iloc[i]['p_val_56']<threshold):
        loglik_results['inferred_label_5'].iloc[i] = 1
    if(loglik_results.iloc[i]['model']==5):  
        loglik_results['true_label_5'].iloc[i] = 1
# Out:
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_49759/3884813799.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loglik_results['true_label_5'].iloc[i] = 1
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_49759/3884813799.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loglik_results['inferred_label_5'].iloc[i] = 1

# %%
#loglik_results[loglik_results['model']==5]

# %%
# # Compute ROC curve and ROC area for each class
# #fpr = dict()
# #tpr = dict()
# #roc_auc = dict()
# #for i in range(n_classes):
# fpr, tpr, _ = roc_curve(loglik_results['inferred_label'].to_numpy(), loglik_results['true_label'].to_numpy())
# roc_auc = auc(fpr, tpr)

# %%
# plt.figure()
# plt.plot(fpr, tpr, '--', label='ROC curve (area = %0.2f)' % roc_auc)
# plt.plot([0, 1], [0, 1], 'k--')
# plt.xlim([0.0, 1.0])
# plt.ylim([0.0, 1.05])
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('Receiver operating characteristic example')
# plt.legend(loc="lower right")
# plt.show()

# %%
# sum(loglik_results['true_label']-loglik_results['inferred_label'])

# %%
# np.unique(loglik_results[loglik_results['inferred_label']==1]['model'])

# %%
# test = loglik_results[loglik_results['inferred_label']==1]
# test[test['model']==5]

# %% [markdown]
# ### Model 6

# %%
loglik_results['p_val_96'] = chi2.sf(likelihood_ratio(loglik_results['model_6'], loglik_results['model_9']), 2) #???

# %%
for i in range(0,2200):
    #if(loglik_results.iloc[i]['p_val_31']<threshold and loglik_results.iloc[i]['p_val_21']>threshold and 
    #   loglik_results.iloc[i]['p_val_53']>threshold and loglik_results.iloc[i]['p_val_43']>threshold and 
    #   loglik_results.iloc[i]['p_val_42']>threshold):
    if(loglik_results.iloc[i]['p_val_61']<threshold and loglik_results.iloc[i]['p_val_63']<threshold and 
       loglik_results.iloc[i]['p_val_56']>threshold and 
       loglik_results.iloc[i]['p_val_21']>threshold and loglik_results.iloc[i]['p_val_96']>threshold):
        # loglik_results.iloc[i]['p_val_63']<threshold and
        loglik_results['inferred_label_6'].iloc[i] = 1
    if(loglik_results.iloc[i]['model']==6):  
        loglik_results['true_label_6'].iloc[i] = 1
# Out:
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_49759/3568077552.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loglik_results['inferred_label_6'].iloc[i] = 1
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_49759/3568077552.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loglik_results['true_label_6'].iloc[i] = 1

# %%
# # Compute ROC curve and ROC area for each class
# #fpr = dict()
# #tpr = dict()
# #roc_auc = dict()
# #for i in range(n_classes):
# fpr, tpr, _ = roc_curve(loglik_results['inferred_label'].to_numpy(), loglik_results['true_label'].to_numpy())
# roc_auc = auc(fpr, tpr)

# %%
# plt.figure()
# plt.plot(fpr, tpr, '--', label='ROC curve (area = %0.2f)' % roc_auc)
# plt.plot([0, 1], [0, 1], 'k--')
# plt.xlim([0.0, 1.0])
# plt.ylim([0.0, 1.05])
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('Receiver operating characteristic example')
# plt.legend(loc="lower right")
# plt.show()

# %%
# sum(loglik_results['true_label']-loglik_results['inferred_label'])

# %%
# np.unique(loglik_results[loglik_results['inferred_label']==1]['model'])

# %%
# test = loglik_results[loglik_results['inferred_label']==1]
# test[test['model']==6]

# %%
# test = loglik_results[loglik_results['p_val_9_11']<0.15]
# test[test['model']==6]

# %% [markdown]
# ### Model 7

# %%
loglik_results['p_val_72'] = chi2.sf(likelihood_ratio(loglik_results['model_2'], loglik_results['model_7']), 2) #???

# %%
loglik_results['p_val_87'] = chi2.sf(likelihood_ratio(loglik_results['model_7'], loglik_results['model_8']), 2) #???

# %%
loglik_results['p_val_11_8'] = chi2.sf(likelihood_ratio(loglik_results['model_8'], loglik_results['model_11']), 2) #???

# %%
# loglik_results['inferred_label'] = 0
# loglik_results['true_label'] = 0

# %%
for i in range(0,2200):
    #if(loglik_results.iloc[i]['p_val_31']<threshold and loglik_results.iloc[i]['p_val_21']>threshold and 
    #   loglik_results.iloc[i]['p_val_53']>threshold and loglik_results.iloc[i]['p_val_43']>threshold and 
    #   loglik_results.iloc[i]['p_val_42']>threshold):
    if(loglik_results.iloc[i]['p_val_71']<threshold and loglik_results.iloc[i]['p_val_72']<threshold and 
       loglik_results.iloc[i]['p_val_87']>threshold and 
       loglik_results.iloc[i]['p_val_31']>threshold and loglik_results.iloc[i]['p_val_11_8']>threshold):
        # loglik_results.iloc[i]['p_val_63']<threshold and
        loglik_results['inferred_label_7'].iloc[i] = 1
    if(loglik_results.iloc[i]['model']==7):  
        loglik_results['true_label_7'].iloc[i] = 1
# Out:
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_49759/3557923384.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loglik_results['inferred_label_7'].iloc[i] = 1
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_49759/3557923384.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loglik_results['true_label_7'].iloc[i] = 1

# %%
# # Compute ROC curve and ROC area for each class
# #fpr = dict()
# #tpr = dict()
# #roc_auc = dict()
# #for i in range(n_classes):
# fpr, tpr, _ = roc_curve(loglik_results['inferred_label'].to_numpy(), loglik_results['true_label'].to_numpy())
# roc_auc = auc(fpr, tpr)

# %%
# plt.figure()
# plt.plot(fpr, tpr, '--', label='ROC curve (area = %0.2f)' % roc_auc)
# plt.plot([0, 1], [0, 1], 'k--')
# plt.xlim([0.0, 1.0])
# plt.ylim([0.0, 1.05])
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('Receiver operating characteristic example')
# plt.legend(loc="lower right")
# plt.show()

# %%
# sum(loglik_results['true_label']-loglik_results['inferred_label'])

# %%
np.unique(loglik_results[loglik_results['inferred_label_7']==1]['model'])
# Out:
# array([ 1,  2,  7,  8,  9, 11])

# %%
test = loglik_results[loglik_results['inferred_label_7']==1]
test[test['model']==8]
# Out:
#       Unnamed: 0     model_1    model_2     model_3    model_4     model_5  \
# 1400        1400  145.708059  72.525560  145.708062  72.525567  145.708072
# 1401        1401  211.227066  62.779617  211.227074  62.779625  211.227084
# 1402        1402  141.183353  81.990133  141.183264  81.990133  141.183356
# 1403        1403  176.781669  75.349443  176.740647  75.349429  176.781078
# 1407        1407   82.424874  75.559635   82.424877  75.559660   82.424894
# ...          ...         ...        ...         ...        ...         ...
# 1591        1591  122.755211  62.892598  122.713617  62.892595  122.755226
# 1592        1592  209.715186  77.892448  209.715192  77.892463  209.715197
# 1593        1593  178.154197  69.964262  178.154212  69.964280  178.154222
# 1595        1595  211.821470  67.590330  211.821502  67.590333  211.821477
# 1599        1599  124.429709  93.025338  124.418950  93.025332  124.429723
#
#          model_6    model_7    model_8    model_9  ...  p_val_11_3  \
# 1400  145.708071  65.019643  65.105064  65.105070  ...    1.000000
# 1401  211.227080  58.455873  57.929914  57.929940  ...    1.000000
# 1402  141.183356  47.724680  47.817278  47.817316  ...    1.000000
# 1403  176.781676  64.247478  64.396577  64.396574  ...    0.999998
# 1407   82.424891  58.098531  58.723822  58.723843  ...    1.000000
# ...          ...        ...        ...        ...  ...         ...
# 1591  122.755221  53.222064  53.285591  53.285582  ...    0.999992
# 1592  209.715192  73.663697  73.741081  73.741095  ...    1.000000
# 1593  178.154208  65.790428  65.392612  65.392648  ...    1.000000
# 1595  211.821476  62.839489  62.828225  62.828228  ...    1.000000
# 1599  124.429723  66.705020  67.085394  66.756479  ...    0.832913
#
#       p_val_9_11    p_val_10_5    p_val_11_4  p_val_10_4    p_val_9_10  \
# 1400    0.999998  1.284167e-16  2.447149e-02         1.0  2.447141e-02
# 1401    1.000000  5.821642e-33  8.849180e-02         1.0  8.849172e-02
# 1402    1.000000  1.400732e-13  3.797162e-08         1.0  3.797229e-08
# 1403    1.000000  9.427531e-23  4.184250e-03         1.0  4.184243e-03
# 1407    1.000000  3.230260e-02  2.208743e-04         1.0  2.208741e-04
# ...          ...           ...           ...         ...           ...
# 1591    1.000000  1.002294e-13  8.200915e-03         1.0  8.200937e-03
# 1592    0.999997  2.371689e-29  1.254710e-01         1.0  1.254704e-01
# 1593    1.000000  3.212590e-24  1.016909e-01         1.0  1.016904e-01
# 1595    1.000000  4.792990e-32  9.245321e-02         1.0  9.245290e-02
# 1599    1.000000  1.515740e-07  1.940053e-06         1.0  1.976012e-06
#
#       p_val_56      p_val_96      p_val_72  p_val_11_8
# 1400  1.000000  3.142539e-18  2.344828e-02    1.000000
# 1401  1.000000  5.151682e-34  1.151094e-01    1.000000
# 1402  1.000000  5.318900e-21  3.625363e-08    1.000000
# 1403  0.999701  3.943529e-25  3.883641e-03    0.999998
# 1407  1.000000  7.134817e-06  1.615732e-04    1.000000
# ...        ...           ...           ...         ...
# 1591  1.000000  8.219769e-16  7.944567e-03    0.999992
# 1592  1.000000  2.975776e-30  1.207087e-01    1.000000
# 1593  1.000000  3.266918e-25  1.240691e-01    1.000000
# 1595  1.000000  4.431261e-33  9.297541e-02    1.000000
# 1599  1.000000  2.995120e-13  1.925820e-06    0.832913
#
# [112 rows x 62 columns]

# %% [markdown]
# ### Model 8

# %%
loglik_results['p_val_9_11'] = chi2.sf(likelihood_ratio(loglik_results['model_11'], loglik_results['model_9']), 2) #???

# %%
loglik_results['p_val_87'] = chi2.sf(likelihood_ratio(loglik_results['model_7'], loglik_results['model_8']), 2) #???

# %%
# loglik_results['inferred_label'] = 0
# loglik_results['true_label'] = 0

# %%
for i in range(0,2200):
    #if(loglik_results.iloc[i]['p_val_31']<threshold and loglik_results.iloc[i]['p_val_21']>threshold and 
    #   loglik_results.iloc[i]['p_val_53']>threshold and loglik_results.iloc[i]['p_val_43']>threshold and 
    #   loglik_results.iloc[i]['p_val_42']>threshold):
    if(loglik_results.iloc[i]['p_val_82']<threshold and loglik_results.iloc[i]['p_val_11_8']>threshold and 
      loglik_results.iloc[i]['p_val_9_11']>threshold and loglik_results.iloc[i]['p_val_87']<threshold):
        # loglik_results.iloc[i]['p_val_63']<threshold and
        loglik_results['inferred_label_8'].iloc[i] = 1
    if(loglik_results.iloc[i]['model']==8):  
        loglik_results['true_label_8'].iloc[i] = 1
# Out:
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_49759/745375270.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loglik_results['true_label_8'].iloc[i] = 1
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_49759/745375270.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loglik_results['inferred_label_8'].iloc[i] = 1

# %%
# # Compute ROC curve and ROC area for each class
# #fpr = dict()
# #tpr = dict()
# #roc_auc = dict()
# #for i in range(n_classes):
# fpr, tpr, _ = roc_curve(loglik_results['inferred_label'].to_numpy(), loglik_results['true_label'].to_numpy())
# roc_auc = auc(fpr, tpr)

# %%
# plt.figure()
# plt.plot(fpr, tpr, '--', label='ROC curve (area = %0.2f)' % roc_auc)
# plt.plot([0, 1], [0, 1], 'k--')
# plt.xlim([0.0, 1.0])
# plt.ylim([0.0, 1.05])
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('Receiver operating characteristic example')
# plt.legend(loc="lower right")
# plt.show()

# %%
# sum(loglik_results['true_label']-loglik_results['inferred_label'])

# %%
# sum(loglik_results['inferred_label'])

# %%
np.unique(loglik_results[loglik_results['inferred_label_8']==1]['model'])
# Out:
# array([8])

# %%
test = loglik_results[loglik_results['inferred_label_8']==1]
test[test['model']==7]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, model_1, model_2, model_3, model_4, model_5, model_6, model_7, model_8, model_9, model_10, model_11, p_val_21, p_val_31, p_val_41, p_val_42, p_val_43, p_val_51, p_val_52, p_val_61, p_val_62, p_val_63, p_val_64, p_val_71, p_val_73, p_val_87, p_val_97, p_val_98, p_val_82, p_val_53, p_val_95, model, inferred_label_2, true_label_2, inferred_label_3, true_label_3, inferred_label_4, true_label_4, inferred_label_5, true_label_5, inferred_label_6, true_label_6, inferred_label_7, true_label_7, inferred_label_8, true_label_8, inferred_label_9, true_label_9, inferred_label_10, true_label_10, inferred_label_11, true_label_11, p_val_11_3, p_val_9_11, p_val_10_5, p_val_11_4, p_val_10_4, p_val_9_10, p_val_56, p_val_96, p_val_72, p_val_11_8]
# Index: []
#
# [0 rows x 62 columns]

# %% [markdown]
# ### Model 9

# %%
loglik_results['p_val_96'] = chi2.sf(likelihood_ratio(loglik_results['model_6'], loglik_results['model_9']), 2) #???

# %%
# loglik_results['inferred_label'] = 0
# loglik_results['true_label'] = 0

# %%
for i in range(0,2200):
    #if(loglik_results.iloc[i]['p_val_31']<threshold and loglik_results.iloc[i]['p_val_21']>threshold and 
    #   loglik_results.iloc[i]['p_val_53']>threshold and loglik_results.iloc[i]['p_val_43']>threshold and 
    #   loglik_results.iloc[i]['p_val_42']>threshold):
    if(loglik_results.iloc[i]['p_val_9_11']<threshold and loglik_results.iloc[i]['p_val_9_10']<threshold and 
        loglik_results.iloc[i]['p_val_97']<threshold and loglik_results.iloc[i]['p_val_96']<threshold):
        # loglik_results.iloc[i]['p_val_63']<threshold and
        loglik_results['inferred_label_9'].iloc[i] = 1
    if(loglik_results.iloc[i]['model']==9):  
        loglik_results['true_label_9'].iloc[i] = 1
# Out:
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_49759/2339881876.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loglik_results['inferred_label_9'].iloc[i] = 1
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_49759/2339881876.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loglik_results['true_label_9'].iloc[i] = 1

# %%
# # Compute ROC curve and ROC area for each class
# #fpr = dict()
# #tpr = dict()
# #roc_auc = dict()
# #for i in range(n_classes):
# fpr, tpr, _ = roc_curve(loglik_results['inferred_label'].to_numpy(), loglik_results['true_label'].to_numpy())
# roc_auc = auc(fpr, tpr)

# %%
# plt.figure()
# plt.plot(fpr, tpr, '--', label='ROC curve (area = %0.2f)' % roc_auc)
# plt.plot([0, 1], [0, 1], 'k--')
# plt.xlim([0.0, 1.0])
# plt.ylim([0.0, 1.05])
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('Receiver operating characteristic example')
# plt.legend(loc="lower right")
# plt.show()

# %%
# np.unique(loglik_results[loglik_results['inferred_label']==1]['model'])

# %%
# sum(loglik_results['true_label']-loglik_results['inferred_label'])

# %%
# sum(loglik_results['inferred_label'])

# %% [markdown]
# ### Model 10

# %%
loglik_results['p_val_10_5'] = chi2.sf(likelihood_ratio(loglik_results['model_5'], loglik_results['model_10']), 2) #???

# %%
loglik_results['p_val_10_3'] = chi2.sf(likelihood_ratio(loglik_results['model_3'], loglik_results['model_10']), 2) #???

# %%
loglik_results['p_val_10_1'] = chi2.sf(likelihood_ratio(loglik_results['model_1'], loglik_results['model_10']), 2) #???

# %%
loglik_results['p_val_10_2'] = chi2.sf(likelihood_ratio(loglik_results['model_2'], loglik_results['model_10']), 2) #???

# %%
loglik_results['p_val_10_4'] = chi2.sf(likelihood_ratio(loglik_results['model_4'], loglik_results['model_10']), 2) #???

# %%
loglik_results['p_val_11_4'] = chi2.sf(likelihood_ratio(loglik_results['model_4'], loglik_results['model_11']), 2) #???

# %%
# loglik_results['inferred_label'] = 0
# loglik_results['true_label'] = 0

# %%
for i in range(0,2200):
    #if(loglik_results.iloc[i]['p_val_31']<threshold and loglik_results.iloc[i]['p_val_21']>threshold and 
    #   loglik_results.iloc[i]['p_val_53']>threshold and loglik_results.iloc[i]['p_val_43']>threshold and 
    #   loglik_results.iloc[i]['p_val_42']>threshold):
    if(loglik_results.iloc[i]['p_val_10_4']<threshold and loglik_results.iloc[i]['p_val_10_5']<threshold and 
       loglik_results.iloc[i]['p_val_9_10']>threshold and loglik_results.iloc[i]['p_val_11_4']>threshold and
      loglik_results.iloc[i]['p_val_42']<threshold and loglik_results.iloc[i]['p_val_43']<threshold):
        # loglik_results.iloc[i]['p_val_63']<threshold and
        loglik_results['inferred_label_10'].iloc[i] = 1
    if(loglik_results.iloc[i]['model']==10):  
        loglik_results['true_label_10'].iloc[i] = 1
# Out:
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_49759/3950900615.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loglik_results['inferred_label_10'].iloc[i] = 1
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_49759/3950900615.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loglik_results['true_label_10'].iloc[i] = 1

# %%
# # Compute ROC curve and ROC area for each class
# #fpr = dict()
# #tpr = dict()
# #roc_auc = dict()
# #for i in range(n_classes):
# fpr, tpr, _ = roc_curve(loglik_results['inferred_label'].to_numpy(), loglik_results['true_label'].to_numpy())
# roc_auc = auc(fpr, tpr)

# %%
# plt.figure()
# plt.plot(fpr, tpr, '--', label='ROC curve (area = %0.2f)' % roc_auc)
# plt.plot([0, 1], [0, 1], 'k--')
# plt.xlim([0.0, 1.0])
# plt.ylim([0.0, 1.05])
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('Receiver operating characteristic example')
# plt.legend(loc="lower right")
# plt.show()

# %%
# np.unique(loglik_results[loglik_results['inferred_label']==1]['model'])

# %%
# test = loglik_results[loglik_results['inferred_label']==1]
# test[test['model']==4]

# %% [markdown]
# ### Model 11

# %%
loglik_results['p_val_11_8'] = chi2.sf(likelihood_ratio(loglik_results['model_8'], loglik_results['model_11']), 2) #???

# %%
loglik_results['p_val_11_4'] = chi2.sf(likelihood_ratio(loglik_results['model_4'], loglik_results['model_11']), 2) #???

# %%
loglik_results['p_val_9_11'] = chi2.sf(likelihood_ratio(loglik_results['model_11'], loglik_results['model_9']), 2) #???

# %%
# loglik_results['inferred_label'] = 0
# loglik_results['true_label'] = 0

# %%
for i in range(0,2200):
    #if(loglik_results.iloc[i]['p_val_31']<threshold and loglik_results.iloc[i]['p_val_21']>threshold and 
    #   loglik_results.iloc[i]['p_val_53']>threshold and loglik_results.iloc[i]['p_val_43']>threshold and 
    #   loglik_results.iloc[i]['p_val_42']>threshold):
    if(loglik_results.iloc[i]['p_val_11_8']<threshold and loglik_results.iloc[i]['p_val_11_4']<threshold and 
      loglik_results.iloc[i]['p_val_9_11']>threshold and loglik_results.iloc[i]['p_val_43']<threshold):
        # loglik_results.iloc[i]['p_val_63']<threshold and
        loglik_results['inferred_label_11'].iloc[i] = 1
    if(loglik_results.iloc[i]['model']==11):  
        loglik_results['true_label_11'].iloc[i] = 1
# Out:
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_49759/814035546.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loglik_results['inferred_label_11'].iloc[i] = 1
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_49759/814035546.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loglik_results['true_label_11'].iloc[i] = 1

# %%
# # Compute ROC curve and ROC area for each class
# #fpr = dict()
# #tpr = dict()
# #roc_auc = dict()
# #for i in range(n_classes):
# fpr, tpr, _ = roc_curve(loglik_results['inferred_label'].to_numpy(), loglik_results['true_label'].to_numpy())
# roc_auc = auc(fpr, tpr)

# %%
# plt.figure()
# plt.plot(fpr, tpr, '--', label='ROC curve (area = %0.2f)' % roc_auc)
# plt.plot([0, 1], [0, 1], 'k--')
# plt.xlim([0.0, 1.0])
# plt.ylim([0.0, 1.05])
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('Receiver operating characteristic example')
# plt.legend(loc="lower right")
# plt.show()

# %%
# np.unique(loglik_results[loglik_results['inferred_label']==1]['model'])

# %%
# test = loglik_results[loglik_results['inferred_label']==1]
# test[test['model']==3]

# %%
fpr_2, tpr_2, _ = roc_curve(loglik_results['inferred_label_2'].to_numpy(), loglik_results['true_label_2'].to_numpy())
roc_auc_2 = auc(fpr_2, tpr_2)

fpr_3, tpr_3, _ = roc_curve(loglik_results['inferred_label_3'].to_numpy(), loglik_results['true_label_3'].to_numpy())
roc_auc_3 = auc(fpr_3, tpr_3)

fpr_4, tpr_4, _ = roc_curve(loglik_results['inferred_label_4'].to_numpy(), loglik_results['true_label_4'].to_numpy())
roc_auc_4 = auc(fpr_4, tpr_4)

fpr_5, tpr_5, _ = roc_curve(loglik_results['inferred_label_5'].to_numpy(), loglik_results['true_label_5'].to_numpy())
roc_auc_5 = auc(fpr_5, tpr_5)

fpr_6, tpr_6, _ = roc_curve(loglik_results['inferred_label_6'].to_numpy(), loglik_results['true_label_6'].to_numpy())
roc_auc_6 = auc(fpr_6, tpr_6)

fpr_7, tpr_7, _ = roc_curve(loglik_results['inferred_label_7'].to_numpy(), loglik_results['true_label_7'].to_numpy())
roc_auc_7 = auc(fpr_7, tpr_7)

fpr_8, tpr_8, _ = roc_curve(loglik_results['inferred_label_8'].to_numpy(), loglik_results['true_label_8'].to_numpy())
roc_auc_8 = auc(fpr_8, tpr_8)

fpr_9, tpr_9, _ = roc_curve(loglik_results['inferred_label_9'].to_numpy(), loglik_results['true_label_9'].to_numpy())
roc_auc_9 = auc(fpr_9, tpr_9)

fpr_10, tpr_10, _ = roc_curve(loglik_results['inferred_label_10'].to_numpy(), loglik_results['true_label_10'].to_numpy())
roc_auc_10 = auc(fpr_10, tpr_10)

fpr_11, tpr_11, _ = roc_curve(loglik_results['inferred_label_11'].to_numpy(), loglik_results['true_label_11'].to_numpy())
roc_auc_11 = auc(fpr_11, tpr_11)

# %%
plt.figure()
plt.plot(fpr_2, tpr_2, '--', label='ROC M2 (%0.2f)' % roc_auc_2)
plt.plot(fpr_3, tpr_3, '--', label='ROC M3 (%0.2f)' % roc_auc_3)
plt.plot(fpr_4, tpr_4, '--', label='ROC M4 (%0.2f)' % roc_auc_4)
plt.plot(fpr_5, tpr_5, '--', label='ROC M5 (%0.2f)' % roc_auc_5)
plt.plot(fpr_6, tpr_6, '--', label='ROC M6 (%0.2f)' % roc_auc_6)
plt.plot(fpr_7, tpr_7, '--', label='ROC M7 (%0.2f)' % roc_auc_7)
plt.plot(fpr_8, tpr_8, '--', label='ROC M8 (%0.2f)' % roc_auc_8)
plt.plot(fpr_9, tpr_9, '--', label='ROC M9 (%0.2f)' % roc_auc_9)
plt.plot(fpr_10, tpr_10, '--', label='ROC M10 (%0.2f)' % roc_auc_10)
plt.plot(fpr_11, tpr_11, '--', label='ROC M11 (%0.2f)' % roc_auc_11)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('ROC_dynamic_data.png', dpi=300)
plt.show()
