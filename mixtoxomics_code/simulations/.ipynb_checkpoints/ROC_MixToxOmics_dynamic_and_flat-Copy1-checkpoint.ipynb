# %%
from sklearn.metrics import roc_curve, auc
from sklearn import datasets
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import LinearSVC
from sklearn.preprocessing import label_binarize
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd
from scipy.stats.distributions import chi2
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
#import seaborn as sns
import sys
sys.path.append('..')
np.set_printoptions(suppress=True)

# %%
plt.style.use('ggplot')
#plt.rcParams['axes.facecolor']='w'

# %%
def likelihood_ratio(lik_reduced, lik_full):
    return(-np.asarray(lik_full)-(-np.asarray(lik_reduced)))

# %%
data = pd.read_csv('df_dynamics.csv')

# %%
data2 = pd.read_csv('df_flat.csv')

# %%
data2['model'] = 1000 # noise model

# %%
data = pd.concat([data, data2])

# %%
loglik_results = pd.read_csv('output/loglik_results_simulated_data.csv')
loglik_results = pd.read_csv('output/loglik_results_simulated_data_noise_sd_01.csv')
loglik_results2 = pd.read_csv('output/loglik_results_simulated_data_flat.csv')

# %%
loglik_results = pd.concat([loglik_results, loglik_results2])

# %%
loglik_results['model'] = data['model']

# %%
chi2.sf(2*(np.array(-df['model_5']) - (-df['model_2'])),2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[613], line 1
# ----> 1 chi2.sf(2*(np.array(-df['model_5']) - (-df['model_2'])),2)
#
# NameError: name 'df' is not defined

# %%
loglik_results['p_val_21'] = chi2.sf(2*(np.array(-loglik_results['model_2']) - (-loglik_results['model_1'])),2)
loglik_results['p_val_31'] = chi2.sf(2*(np.array(-loglik_results['model_3']) - (-loglik_results['model_1'])),2)
loglik_results['p_val_41'] = chi2.sf(2*(np.array(-loglik_results['model_4']) - (-loglik_results['model_1'])),2)
loglik_results['p_val_42'] = chi2.sf(2*(np.array(-loglik_results['model_4']) - (-loglik_results['model_2'])),2)
loglik_results['p_val_43'] = chi2.sf(2*(np.array(-loglik_results['model_4']) - (-loglik_results['model_3'])),2)
loglik_results['p_val_51'] = chi2.sf(2*(np.array(-loglik_results['model_5']) - (-loglik_results['model_1'])),2)
loglik_results['p_val_52'] = chi2.sf(2*(np.array(-loglik_results['model_5']) - (-loglik_results['model_2'])),2)
loglik_results['p_val_61'] = chi2.sf(2*(np.array(-loglik_results['model_6']) - (-loglik_results['model_1'])),2)
loglik_results['p_val_62'] = chi2.sf(2*(np.array(-loglik_results['model_6']) - (-loglik_results['model_2'])),2)
loglik_results['p_val_63'] = chi2.sf(2*(np.array(-loglik_results['model_6']) - (-loglik_results['model_3'])),2)
loglik_results['p_val_64'] = chi2.sf(2*(np.array(-loglik_results['model_6']) - (-loglik_results['model_4'])),2)
loglik_results['p_val_71'] = chi2.sf(2*(np.array(-loglik_results['model_7']) - (-loglik_results['model_1'])),2)
loglik_results['p_val_73'] = chi2.sf(2*(np.array(-loglik_results['model_7']) - (-loglik_results['model_3'])),2)
loglik_results['p_val_87'] = chi2.sf(2*(np.array(-loglik_results['model_8']) - (-loglik_results['model_7'])),2)
loglik_results['p_val_97'] = chi2.sf(2*(np.array(-loglik_results['model_9']) - (-loglik_results['model_7'])),2)
loglik_results['p_val_98'] = chi2.sf(2*(np.array(-loglik_results['model_9']) - (-loglik_results['model_8'])),2)
loglik_results['p_val_82'] = chi2.sf(2*(np.array(-loglik_results['model_8']) - (-loglik_results['model_2'])),2)
loglik_results['p_val_53'] = chi2.sf(2*(np.array(-loglik_results['model_5']) - (-loglik_results['model_3'])),2)
loglik_results['p_val_31'] = chi2.sf(2*(np.array(-loglik_results['model_3']) - (-loglik_results['model_1'])),2)
loglik_results['p_val_21'] = chi2.sf(2*(np.array(-loglik_results['model_2']) - (-loglik_results['model_1'])),2)
loglik_results['p_val_41'] = chi2.sf(2*(np.array(-loglik_results['model_4']) - (-loglik_results['model_1'])),2)
loglik_results['p_val_87'] = chi2.sf(2*(np.array(-loglik_results['model_8']) - (-loglik_results['model_7'])),2)
loglik_results['p_val_95'] = chi2.sf(2*(np.array(-loglik_results['model_9']) - (-loglik_results['model_5'])),2)

#loglik_results['gene_id'] = genes_list

# %%
loglik_results
# Out:
#       Unnamed: 0     model_1     model_2     model_3     model_4     model_5  \
# 0              0 -126.303179 -126.302939 -126.362600 -126.362362 -126.335678
# 1              1 -115.207600 -118.047608 -115.382688 -118.226696 -115.475174
# 2              2 -134.930710 -135.010940 -134.930703 -135.010934 -134.930689
# 3              3 -119.303698 -119.300245 -119.496485 -119.492560 -119.325424
# 4              4 -126.670936 -126.679982 -126.670932 -126.679979 -126.670919
# ...          ...         ...         ...         ...         ...         ...
# 2195        2195  -38.556972 -303.371056  -38.556971 -303.371056  -38.556970
# 2196        2196  -81.921678 -308.794374  -81.921676 -308.780458  -81.921671
# 2197        2197 -130.816470 -305.983834 -130.816473 -305.965282 -130.816474
# 2198        2198 -133.572584 -307.522338 -133.572580 -307.522351 -133.572580
# 2199        2199 -143.897347 -307.792352 -143.897344 -307.792346 -143.894375
#
#          model_6     model_7     model_8     model_9  ...  p_val_64  \
# 0    -126.303177 -123.861900 -126.302823 -126.303870  ...       1.0
# 1    -115.438162 -115.983275 -118.311477 -118.549761  ...       1.0
# 2    -134.930697 -131.696391 -134.991283 -134.922331  ...       1.0
# 3    -119.303689 -116.622314 -119.299164 -119.413371  ...       1.0
# 4    -126.670922 -125.128360 -126.696970 -126.835723  ...       1.0
# ...          ...         ...         ...         ...  ...       ...
# 2195  -38.556970 -302.951647 -303.252009 -303.259889  ...       1.0
# 2196  -81.921672 -308.806608 -308.816736 -295.945256  ...       1.0
# 2197 -130.816472 -306.797728 -305.963643 -302.433502  ...       1.0
# 2198 -133.572583 -307.856472 -307.519373 -303.706727  ...       1.0
# 2199 -143.897343 -307.673366 -307.786593 -304.663518  ...       1.0
#
#            p_val_71       p_val_73  p_val_87  p_val_97  p_val_98  p_val_82  \
# 0      1.000000e+00   1.000000e+00  0.087080  0.086989  0.998954  1.000000
# 1      4.603928e-01   5.484896e-01  0.097471  0.076805  0.787978  0.768074
# 2      1.000000e+00   1.000000e+00  0.037072  0.039718  1.000000  1.000000
# 3      1.000000e+00   1.000000e+00  0.068779  0.061356  0.892073  1.000000
# 4      1.000000e+00   1.000000e+00  0.208334  0.181343  0.870444  0.983156
# ...             ...            ...       ...       ...       ...       ...
# 2195  1.495724e-115  1.495723e-115  0.740550  0.734738  0.992151  1.000000
# 2196   2.918279e-99   2.918276e-99  0.989923  1.000000  1.000000  0.977886
# 2197   3.735175e-77   3.735184e-77  1.000000  1.000000  1.000000  1.000000
# 2198   2.039243e-76   2.039237e-76  1.000000  1.000000  1.000000  1.000000
# 2199   7.464123e-72   7.464095e-72  0.892948  1.000000  1.000000  1.000000
#
#       p_val_53       p_val_95  model
# 0     1.000000   1.000000e+00      1
# 1     0.911662   4.620872e-02      1
# 2     1.000000   1.000000e+00      1
# 3     1.000000   9.158089e-01      1
# 4     1.000000   8.480599e-01      1
# ...        ...            ...    ...
# 2195  1.000000  1.098962e-115   1000
# 2196  1.000000   1.123928e-93   1000
# 2197  0.999999   2.935429e-75   1000
# 2198  1.000000   1.293238e-74   1000
# 2199  1.000000   1.509552e-70   1000
#
# [4400 rows x 32 columns]

# %%
#model2 = loglik_results[loglik_results['p_val_21']<0.15]

# %%
loglik_results['inferred_label_2'] = 0
loglik_results['true_label_2'] = 0

loglik_results['inferred_label_3'] = 0
loglik_results['true_label_3'] = 0

loglik_results['inferred_label_4'] = 0
loglik_results['true_label_4'] = 0

loglik_results['inferred_label_5'] = 0
loglik_results['true_label_5'] = 0

loglik_results['inferred_label_6'] = 0
loglik_results['true_label_6'] = 0

loglik_results['inferred_label_7'] = 0
loglik_results['true_label_7'] = 0

loglik_results['inferred_label_8'] = 0
loglik_results['true_label_8'] = 0

loglik_results['inferred_label_9'] = 0
loglik_results['true_label_9'] = 0

loglik_results['inferred_label_10'] = 0
loglik_results['true_label_10'] = 0

loglik_results['inferred_label_11'] = 0
loglik_results['true_label_11'] = 0

# %%
# Do we need to compute p_val_81?

# %%
threshold = 0.05

# %%
for i in range(0,2200):
    if(loglik_results.iloc[i]['p_val_21']<threshold and loglik_results.iloc[i]['p_val_31']>threshold and 
       loglik_results.iloc[i]['p_val_82']>threshold and loglik_results.iloc[i]['p_val_42']>threshold and 
       loglik_results.iloc[i]['p_val_43']>threshold):
        loglik_results['inferred_label_2'].iloc[i] = 1
    if(loglik_results.iloc[i]['model']==2):  
        loglik_results['true_label_2'].iloc[i] = 1
# Out:
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_48336/3392119199.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loglik_results['true_label_2'].iloc[i] = 1

# %%
#loglik_results = loglik_results[loglik_results['model'].isin([1,2])]

# %%
#loglik_results[loglik_results['model']==2]['p_val_82']

# %%
# # Compute ROC curve and ROC area for each class
# #fpr = dict()
# #tpr = dict()
# #roc_auc = dict()
# #for i in range(n_classes):
# fpr, tpr, _ = roc_curve(loglik_results['inferred_label_2'].to_numpy(), loglik_results['true_label_2'].to_numpy())
# roc_auc = auc(fpr, tpr)

# %%
# plt.figure()
# plt.plot(fpr, tpr, '--', label='ROC curve (area = %0.2f)' % roc_auc)
# plt.plot([0, 1], [0, 1], 'k--')
# plt.xlim([0.0, 1.0])
# plt.ylim([0.0, 1.05])
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('Receiver operating characteristic example')
# plt.legend(loc="lower right")
# plt.show()

# %%
#sum(loglik_results['true_label'])

# %% [markdown]
# ### Model 3

# %%
loglik_results['p_val_11_3'] = chi2.sf(likelihood_ratio(loglik_results['model_8'], loglik_results['model_11']), 2) #???

# %%
loglik_results['p_val_9_11'] = chi2.sf(likelihood_ratio(loglik_results['model_11'], loglik_results['model_9']), 2) #???

# %%
loglik_results['p_val_10_5'] = chi2.sf(likelihood_ratio(loglik_results['model_5'], loglik_results['model_10']), 2) #???

# %%
loglik_results['p_val_11_4'] = chi2.sf(likelihood_ratio(loglik_results['model_4'], loglik_results['model_11']), 2) #???

# %%
for i in range(0,2200):
    #if(loglik_results.iloc[i]['p_val_31']<threshold and loglik_results.iloc[i]['p_val_21']>threshold and 
    #   loglik_results.iloc[i]['p_val_53']>threshold and loglik_results.iloc[i]['p_val_43']>threshold and 
    #   loglik_results.iloc[i]['p_val_42']>threshold):
    if(loglik_results.iloc[i]['p_val_31']<threshold and loglik_results.iloc[i]['p_val_21']>threshold and 
      loglik_results.iloc[i]['p_val_63']>threshold and loglik_results.iloc[i]['p_val_9_11']>threshold and 
      loglik_results.iloc[i]['p_val_43']>threshold and loglik_results.iloc[i]['p_val_10_5']>threshold and 
      loglik_results.iloc[i]['p_val_11_4']>threshold):
        loglik_results['inferred_label_3'].iloc[i] = 1
    if(loglik_results.iloc[i]['model']==3):  
        loglik_results['true_label_3'].iloc[i] = 1
# Out:
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_48336/3782403986.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loglik_results['inferred_label_3'].iloc[i] = 1
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_48336/3782403986.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loglik_results['true_label_3'].iloc[i] = 1

# %%
#loglik_results[loglik_results['model']==1]

# %%
# # Compute ROC curve and ROC area for each class
# #fpr = dict()
# #tpr = dict()
# #roc_auc = dict()
# #for i in range(n_classes):
# fpr, tpr, _ = roc_curve(loglik_results['inferred_label'].to_numpy(), loglik_results['true_label'].to_numpy())
# roc_auc = auc(fpr, tpr)

# %%
# plt.figure()
# plt.plot(fpr, tpr, '--', label='ROC curve (area = %0.2f)' % roc_auc)
# plt.plot([0, 1], [0, 1], 'k--')
# plt.xlim([0.0, 1.0])
# plt.ylim([0.0, 1.05])
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('Receiver operating characteristic example')
# plt.legend(loc="lower right")
# plt.show()

# %%
#sum(loglik_results['true_label']-loglik_results['inferred_label'])

# %%
#np.unique(loglik_results[loglik_results['inferred_label']==1]['model'])

# %% [markdown]
# ### Model 4

# %%
loglik_results['p_val_43'] = chi2.sf(likelihood_ratio(loglik_results['model_3'], loglik_results['model_4']), 2) #???

# %%
loglik_results['p_val_10_4'] = chi2.sf(likelihood_ratio(loglik_results['model_4'], loglik_results['model_10']), 2) #???

# %%
loglik_results['p_val_9_10'] = chi2.sf(likelihood_ratio(loglik_results['model_10'], loglik_results['model_9']), 2) #???

# %%
loglik_results['p_val_43'] = chi2.sf(2*(np.array(-loglik_results['model_4']) - (-loglik_results['model_3'])),2)
loglik_results['p_val_42'] = chi2.sf(2*(np.array(-loglik_results['model_4']) - (-loglik_results['model_2'])),2)
loglik_results['p_val_10_4'] = chi2.sf(2*(np.array(-loglik_results['model_10']) - (-loglik_results['model_4'])),2)
loglik_results['p_val_9_10'] = chi2.sf(2*(np.array(-loglik_results['model_9']) - (-loglik_results['model_10'])),2)

# %%
# loglik_results['inferred_label'] = 0
# loglik_results['true_label'] = 0

# %%
for i in range(0,2200):
    #if(loglik_results.iloc[i]['p_val_31']<threshold and loglik_results.iloc[i]['p_val_21']>threshold and 
    #   loglik_results.iloc[i]['p_val_53']>threshold and loglik_results.iloc[i]['p_val_43']>threshold and 
    #   loglik_results.iloc[i]['p_val_42']>threshold):
    if(loglik_results.iloc[i]['p_val_43']<threshold and loglik_results.iloc[i]['p_val_42']<threshold and 
       loglik_results.iloc[i]['p_val_11_4']>threshold and loglik_results.iloc[i]['p_val_10_4']>threshold and 
       loglik_results.iloc[i]['p_val_9_11']>threshold and loglik_results.iloc[i]['p_val_9_10']>threshold and
       loglik_results.iloc[i]['p_val_53']>threshold and loglik_results.iloc[i]['p_val_82']>threshold):
        loglik_results['inferred_label_4'].iloc[i] = 1
    if(loglik_results.iloc[i]['model']==4):  
        loglik_results['true_label_4'].iloc[i] = 1
# Out:
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_48336/1396202605.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loglik_results['inferred_label_4'].iloc[i] = 1
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_48336/1396202605.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loglik_results['true_label_4'].iloc[i] = 1

# %%
for i in range(0,2200):
    #if(loglik_results.iloc[i]['p_val_31']<threshold and loglik_results.iloc[i]['p_val_21']>threshold and 
    #   loglik_results.iloc[i]['p_val_53']>threshold and loglik_results.iloc[i]['p_val_43']>threshold and 
    #   loglik_results.iloc[i]['p_val_42']>threshold):
    if(loglik_results.iloc[i]['p_val_43']<threshold and loglik_results.iloc[i]['p_val_42']<threshold and 
       loglik_results.iloc[i]['p_val_11_4']>threshold and loglik_results.iloc[i]['p_val_10_4']>threshold ):
        loglik_results['inferred_label_4'].iloc[i] = 1
    if(loglik_results.iloc[i]['model']==4):  
        loglik_results['true_label_4'].iloc[i] = 1
# Out:
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_48336/2542812846.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loglik_results['inferred_label_4'].iloc[i] = 1
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_48336/2542812846.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loglik_results['true_label_4'].iloc[i] = 1

# %%
#loglik_results[loglik_results['model']==4]

# %%
# # Compute ROC curve and ROC area for each class
# #fpr = dict()
# #tpr = dict()
# #roc_auc = dict()
# #for i in range(n_classes):
# fpr, tpr, _ = roc_curve(loglik_results['inferred_label'].to_numpy(), loglik_results['true_label'].to_numpy())
# roc_auc = auc(fpr, tpr)

# %%
# plt.figure()
# plt.plot(fpr, tpr, '--', label='ROC curve (area = %0.2f)' % roc_auc)
# plt.plot([0, 1], [0, 1], 'k--')
# plt.xlim([0.0, 1.0])
# plt.ylim([0.0, 1.05])
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('Receiver operating characteristic example')
# plt.legend(loc="lower right")
# plt.show()

# %%
# sum(loglik_results['true_label']-loglik_results['inferred_label'])

# %%
# np.unique(loglik_results[loglik_results['inferred_label']==1]['model'])

# %%
# test = loglik_results[loglik_results['inferred_label']==1]
# test[test['model']==3]

# %% [markdown]
# ### Model 5

# %%
loglik_results['p_val_56'] = chi2.sf(likelihood_ratio(loglik_results['model_6'], loglik_results['model_5']), 2) #???

# %%
loglik_results['p_val_56'] = chi2.sf(likelihood_ratio(loglik_results['model_6'], loglik_results['model_5']), 2) #???

# %%
loglik_results['p_val_56'] = chi2.sf(2*(np.array(-loglik_results['model_6']) - (-loglik_results['model_5'])),2)

# %%
# loglik_results['inferred_label'] = 0
# loglik_results['true_label'] = 0

# %%
for i in range(0,2200):
    #if(loglik_results.iloc[i]['p_val_31']<threshold and loglik_results.iloc[i]['p_val_21']>threshold and 
    #   loglik_results.iloc[i]['p_val_53']>threshold and loglik_results.iloc[i]['p_val_43']>threshold and 
    #   loglik_results.iloc[i]['p_val_42']>threshold):
    if(loglik_results.iloc[i]['p_val_53']<threshold and loglik_results.iloc[i]['p_val_56']<threshold):
        loglik_results['inferred_label_5'].iloc[i] = 1
    if(loglik_results.iloc[i]['model']==5):  
        loglik_results['true_label_5'].iloc[i] = 1
# Out:
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_48336/3884813799.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loglik_results['true_label_5'].iloc[i] = 1
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_48336/3884813799.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loglik_results['inferred_label_5'].iloc[i] = 1

# %%
#loglik_results[loglik_results['model']==5]

# %%
# # Compute ROC curve and ROC area for each class
# #fpr = dict()
# #tpr = dict()
# #roc_auc = dict()
# #for i in range(n_classes):
# fpr, tpr, _ = roc_curve(loglik_results['inferred_label'].to_numpy(), loglik_results['true_label'].to_numpy())
# roc_auc = auc(fpr, tpr)

# %%
# plt.figure()
# plt.plot(fpr, tpr, '--', label='ROC curve (area = %0.2f)' % roc_auc)
# plt.plot([0, 1], [0, 1], 'k--')
# plt.xlim([0.0, 1.0])
# plt.ylim([0.0, 1.05])
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('Receiver operating characteristic example')
# plt.legend(loc="lower right")
# plt.show()

# %%
# sum(loglik_results['true_label']-loglik_results['inferred_label'])

# %%
# np.unique(loglik_results[loglik_results['inferred_label']==1]['model'])

# %%
# test = loglik_results[loglik_results['inferred_label']==1]
# test[test['model']==5]

# %% [markdown]
# ### Model 6

# %%
loglik_results['p_val_96'] = chi2.sf(likelihood_ratio(loglik_results['model_6'], loglik_results['model_9']), 2) #???

# %%
loglik_results['p_val_96'] = chi2.sf(2*(np.array(-loglik_results['model_9']) - (-loglik_results['model_6'])),2)

# %%
for i in range(0,2200):
    #if(loglik_results.iloc[i]['p_val_31']<threshold and loglik_results.iloc[i]['p_val_21']>threshold and 
    #   loglik_results.iloc[i]['p_val_53']>threshold and loglik_results.iloc[i]['p_val_43']>threshold and 
    #   loglik_results.iloc[i]['p_val_42']>threshold):
    if(loglik_results.iloc[i]['p_val_61']<threshold and loglik_results.iloc[i]['p_val_63']<threshold and 
       loglik_results.iloc[i]['p_val_56']>threshold and 
       loglik_results.iloc[i]['p_val_21']>threshold and loglik_results.iloc[i]['p_val_96']>threshold):
        # loglik_results.iloc[i]['p_val_63']<threshold and
        loglik_results['inferred_label_6'].iloc[i] = 1
    if(loglik_results.iloc[i]['model']==6):  
        loglik_results['true_label_6'].iloc[i] = 1
# Out:
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_48336/3568077552.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loglik_results['inferred_label_6'].iloc[i] = 1
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_48336/3568077552.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loglik_results['true_label_6'].iloc[i] = 1

# %%
# # Compute ROC curve and ROC area for each class
# #fpr = dict()
# #tpr = dict()
# #roc_auc = dict()
# #for i in range(n_classes):
# fpr, tpr, _ = roc_curve(loglik_results['inferred_label'].to_numpy(), loglik_results['true_label'].to_numpy())
# roc_auc = auc(fpr, tpr)

# %%
# plt.figure()
# plt.plot(fpr, tpr, '--', label='ROC curve (area = %0.2f)' % roc_auc)
# plt.plot([0, 1], [0, 1], 'k--')
# plt.xlim([0.0, 1.0])
# plt.ylim([0.0, 1.05])
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('Receiver operating characteristic example')
# plt.legend(loc="lower right")
# plt.show()

# %%
# sum(loglik_results['true_label']-loglik_results['inferred_label'])

# %%
# np.unique(loglik_results[loglik_results['inferred_label']==1]['model'])

# %%
# test = loglik_results[loglik_results['inferred_label']==1]
# test[test['model']==6]

# %%
# test = loglik_results[loglik_results['p_val_9_11']<0.15]
# test[test['model']==6]

# %% [markdown]
# ### Model 7

# %%
loglik_results['p_val_72'] = chi2.sf(likelihood_ratio(loglik_results['model_2'], loglik_results['model_7']), 2) #???

# %%
loglik_results['p_val_87'] = chi2.sf(likelihood_ratio(loglik_results['model_7'], loglik_results['model_8']), 2) #???

# %%
loglik_results['p_val_11_8'] = chi2.sf(likelihood_ratio(loglik_results['model_8'], loglik_results['model_11']), 2) #???

# %%
loglik_results['p_val_11_8'] = chi2.sf(2*(np.array(-loglik_results['model_11']) - (-loglik_results['model_8'])),2)
loglik_results['p_val_87'] = chi2.sf(2*(np.array(-loglik_results['model_8']) - (-loglik_results['model_7'])),2)
loglik_results['p_val_72'] = chi2.sf(2*(np.array(-loglik_results['model_7']) - (-loglik_results['model_2'])),2)

# %%
# loglik_results['inferred_label'] = 0
# loglik_results['true_label'] = 0

# %%
for i in range(0,2200):
    #if(loglik_results.iloc[i]['p_val_31']<threshold and loglik_results.iloc[i]['p_val_21']>threshold and 
    #   loglik_results.iloc[i]['p_val_53']>threshold and loglik_results.iloc[i]['p_val_43']>threshold and 
    #   loglik_results.iloc[i]['p_val_42']>threshold):
    if(loglik_results.iloc[i]['p_val_71']<threshold and loglik_results.iloc[i]['p_val_72']<threshold and 
       loglik_results.iloc[i]['p_val_87']>threshold and 
       loglik_results.iloc[i]['p_val_31']>threshold and loglik_results.iloc[i]['p_val_11_8']>threshold):
        # loglik_results.iloc[i]['p_val_63']<threshold and
        loglik_results['inferred_label_7'].iloc[i] = 1
    if(loglik_results.iloc[i]['model']==7):  
        loglik_results['true_label_7'].iloc[i] = 1
# Out:
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_48336/3557923384.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loglik_results['inferred_label_7'].iloc[i] = 1
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_48336/3557923384.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loglik_results['true_label_7'].iloc[i] = 1

# %%
# # Compute ROC curve and ROC area for each class
# #fpr = dict()
# #tpr = dict()
# #roc_auc = dict()
# #for i in range(n_classes):
# fpr, tpr, _ = roc_curve(loglik_results['inferred_label'].to_numpy(), loglik_results['true_label'].to_numpy())
# roc_auc = auc(fpr, tpr)

# %%
# plt.figure()
# plt.plot(fpr, tpr, '--', label='ROC curve (area = %0.2f)' % roc_auc)
# plt.plot([0, 1], [0, 1], 'k--')
# plt.xlim([0.0, 1.0])
# plt.ylim([0.0, 1.05])
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('Receiver operating characteristic example')
# plt.legend(loc="lower right")
# plt.show()

# %%
# sum(loglik_results['true_label']-loglik_results['inferred_label'])

# %%
# np.unique(loglik_results[loglik_results['inferred_label']==1]['model'])

# %%
# test = loglik_results[loglik_results['inferred_label']==1]
# test[test['model']==9]

# %% [markdown]
# ### Model 8

# %%
loglik_results['p_val_9_11'] = chi2.sf(likelihood_ratio(loglik_results['model_11'], loglik_results['model_9']), 2) #???

# %%
loglik_results['p_val_9_11'] = chi2.sf(likelihood_ratio(loglik_results['model_11'], loglik_results['model_9']), 2) #???

# %%
# loglik_results['inferred_label'] = 0
# loglik_results['true_label'] = 0

# %%
for i in range(0,2200):
    #if(loglik_results.iloc[i]['p_val_31']<threshold and loglik_results.iloc[i]['p_val_21']>threshold and 
    #   loglik_results.iloc[i]['p_val_53']>threshold and loglik_results.iloc[i]['p_val_43']>threshold and 
    #   loglik_results.iloc[i]['p_val_42']>threshold):
    if(loglik_results.iloc[i]['p_val_82']<threshold and loglik_results.iloc[i]['p_val_11_8']>threshold and 
      loglik_results.iloc[i]['p_val_9_11']>threshold):
        # loglik_results.iloc[i]['p_val_63']<threshold and
        loglik_results['inferred_label_8'].iloc[i] = 1
    if(loglik_results.iloc[i]['model']==8):  
        loglik_results['true_label_8'].iloc[i] = 1
# Out:
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_48336/2813945058.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loglik_results['inferred_label_8'].iloc[i] = 1
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_48336/2813945058.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loglik_results['true_label_8'].iloc[i] = 1

# %%
# # Compute ROC curve and ROC area for each class
# #fpr = dict()
# #tpr = dict()
# #roc_auc = dict()
# #for i in range(n_classes):
# fpr, tpr, _ = roc_curve(loglik_results['inferred_label'].to_numpy(), loglik_results['true_label'].to_numpy())
# roc_auc = auc(fpr, tpr)

# %%
# plt.figure()
# plt.plot(fpr, tpr, '--', label='ROC curve (area = %0.2f)' % roc_auc)
# plt.plot([0, 1], [0, 1], 'k--')
# plt.xlim([0.0, 1.0])
# plt.ylim([0.0, 1.05])
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('Receiver operating characteristic example')
# plt.legend(loc="lower right")
# plt.show()

# %%
# sum(loglik_results['true_label']-loglik_results['inferred_label'])

# %%
# sum(loglik_results['inferred_label'])

# %%
# np.unique(loglik_results[loglik_results['inferred_label']==1]['model'])

# %%
# test = loglik_results[loglik_results['inferred_label']==1]
# test[test['model']==1]

# %% [markdown]
# ### Model 9

# %%
loglik_results['p_val_96'] = chi2.sf(likelihood_ratio(loglik_results['model_6'], loglik_results['model_9']), 2) #???

# %%
# loglik_results['inferred_label'] = 0
# loglik_results['true_label'] = 0

# %%
for i in range(0,2200):
    #if(loglik_results.iloc[i]['p_val_31']<threshold and loglik_results.iloc[i]['p_val_21']>threshold and 
    #   loglik_results.iloc[i]['p_val_53']>threshold and loglik_results.iloc[i]['p_val_43']>threshold and 
    #   loglik_results.iloc[i]['p_val_42']>threshold):
    if(loglik_results.iloc[i]['p_val_9_11']<threshold and loglik_results.iloc[i]['p_val_9_10']<threshold and 
        loglik_results.iloc[i]['p_val_97']<threshold and loglik_results.iloc[i]['p_val_96']<threshold):
        # loglik_results.iloc[i]['p_val_63']<threshold and
        loglik_results['inferred_label_9'].iloc[i] = 1
    if(loglik_results.iloc[i]['model']==9):  
        loglik_results['true_label_9'].iloc[i] = 1
# Out:
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_48336/2339881876.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loglik_results['inferred_label_9'].iloc[i] = 1
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_48336/2339881876.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loglik_results['true_label_9'].iloc[i] = 1

# %%
# # Compute ROC curve and ROC area for each class
# #fpr = dict()
# #tpr = dict()
# #roc_auc = dict()
# #for i in range(n_classes):
# fpr, tpr, _ = roc_curve(loglik_results['inferred_label'].to_numpy(), loglik_results['true_label'].to_numpy())
# roc_auc = auc(fpr, tpr)

# %%
# plt.figure()
# plt.plot(fpr, tpr, '--', label='ROC curve (area = %0.2f)' % roc_auc)
# plt.plot([0, 1], [0, 1], 'k--')
# plt.xlim([0.0, 1.0])
# plt.ylim([0.0, 1.05])
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('Receiver operating characteristic example')
# plt.legend(loc="lower right")
# plt.show()

# %%
# np.unique(loglik_results[loglik_results['inferred_label']==1]['model'])

# %%
# sum(loglik_results['true_label']-loglik_results['inferred_label'])

# %%
# sum(loglik_results['inferred_label'])

# %% [markdown]
# ### Model 10

# %%
loglik_results['p_val_10_5'] = chi2.sf(likelihood_ratio(loglik_results['model_5'], loglik_results['model_10']), 2) #???
loglik_results['p_val_10_3'] = chi2.sf(likelihood_ratio(loglik_results['model_3'], loglik_results['model_10']), 2) #???
loglik_results['p_val_10_1'] = chi2.sf(likelihood_ratio(loglik_results['model_1'], loglik_results['model_10']), 2) #???
loglik_results['p_val_10_2'] = chi2.sf(likelihood_ratio(loglik_results['model_2'], loglik_results['model_10']), 2) #???
loglik_results['p_val_10_4'] = chi2.sf(likelihood_ratio(loglik_results['model_4'], loglik_results['model_10']), 2) #???
loglik_results['p_val_11_4'] = chi2.sf(likelihood_ratio(loglik_results['model_4'], loglik_results['model_11']), 2) #???

# %%
# loglik_results['inferred_label'] = 0
# loglik_results['true_label'] = 0

# %%
for i in range(0,2200):
    #if(loglik_results.iloc[i]['p_val_31']<threshold and loglik_results.iloc[i]['p_val_21']>threshold and 
    #   loglik_results.iloc[i]['p_val_53']>threshold and loglik_results.iloc[i]['p_val_43']>threshold and 
    #   loglik_results.iloc[i]['p_val_42']>threshold):
    if(loglik_results.iloc[i]['p_val_10_4']<threshold and loglik_results.iloc[i]['p_val_10_5']<threshold and 
       loglik_results.iloc[i]['p_val_9_10']>threshold and loglik_results.iloc[i]['p_val_11_4']>threshold and
      loglik_results.iloc[i]['p_val_42']<threshold and loglik_results.iloc[i]['p_val_43']<threshold):
        # loglik_results.iloc[i]['p_val_63']<threshold and
        loglik_results['inferred_label_10'].iloc[i] = 1
    if(loglik_results.iloc[i]['model']==10):  
        loglik_results['true_label_10'].iloc[i] = 1
# Out:
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_48336/3950900615.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loglik_results['inferred_label_10'].iloc[i] = 1
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_48336/3950900615.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loglik_results['true_label_10'].iloc[i] = 1

# %%
# # Compute ROC curve and ROC area for each class
# #fpr = dict()
# #tpr = dict()
# #roc_auc = dict()
# #for i in range(n_classes):
# fpr, tpr, _ = roc_curve(loglik_results['inferred_label'].to_numpy(), loglik_results['true_label'].to_numpy())
# roc_auc = auc(fpr, tpr)

# %%
# plt.figure()
# plt.plot(fpr, tpr, '--', label='ROC curve (area = %0.2f)' % roc_auc)
# plt.plot([0, 1], [0, 1], 'k--')
# plt.xlim([0.0, 1.0])
# plt.ylim([0.0, 1.05])
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('Receiver operating characteristic example')
# plt.legend(loc="lower right")
# plt.show()

# %%
# np.unique(loglik_results[loglik_results['inferred_label']==1]['model'])

# %%
# test = loglik_results[loglik_results['inferred_label']==1]
# test[test['model']==4]

# %% [markdown]
# ### Model 11

# %%
loglik_results['p_val_11_8'] = chi2.sf(likelihood_ratio(loglik_results['model_8'], loglik_results['model_11']), 2) #???

# %%
loglik_results['p_val_11_4'] = chi2.sf(likelihood_ratio(loglik_results['model_4'], loglik_results['model_11']), 2) #???

# %%
loglik_results['p_val_9_11'] = chi2.sf(likelihood_ratio(loglik_results['model_11'], loglik_results['model_9']), 2) #???

# %%
# loglik_results['inferred_label'] = 0
# loglik_results['true_label'] = 0

# %%
for i in range(0,2200):
    #if(loglik_results.iloc[i]['p_val_31']<threshold and loglik_results.iloc[i]['p_val_21']>threshold and 
    #   loglik_results.iloc[i]['p_val_53']>threshold and loglik_results.iloc[i]['p_val_43']>threshold and 
    #   loglik_results.iloc[i]['p_val_42']>threshold):
    if(loglik_results.iloc[i]['p_val_11_8']<threshold and loglik_results.iloc[i]['p_val_11_4']<threshold and 
      loglik_results.iloc[i]['p_val_9_11']>threshold and loglik_results.iloc[i]['p_val_43']<threshold):
        # loglik_results.iloc[i]['p_val_63']<threshold and
        loglik_results['inferred_label_11'].iloc[i] = 1
    if(loglik_results.iloc[i]['model']==11):  
        loglik_results['true_label_11'].iloc[i] = 1
# Out:
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_48336/814035546.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loglik_results['inferred_label_11'].iloc[i] = 1
# /var/folders/pn/vpqz4z_53xl4fpq_28c5mx700000gn/T/ipykernel_48336/814035546.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loglik_results['true_label_11'].iloc[i] = 1

# %%
# # Compute ROC curve and ROC area for each class
# #fpr = dict()
# #tpr = dict()
# #roc_auc = dict()
# #for i in range(n_classes):
# fpr, tpr, _ = roc_curve(loglik_results['inferred_label'].to_numpy(), loglik_results['true_label'].to_numpy())
# roc_auc = auc(fpr, tpr)

# %%
# plt.figure()
# plt.plot(fpr, tpr, '--', label='ROC curve (area = %0.2f)' % roc_auc)
# plt.plot([0, 1], [0, 1], 'k--')
# plt.xlim([0.0, 1.0])
# plt.ylim([0.0, 1.05])
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('Receiver operating characteristic example')
# plt.legend(loc="lower right")
# plt.show()

# %%
# np.unique(loglik_results[loglik_results['inferred_label']==1]['model'])

# %%
# test = loglik_results[loglik_results['inferred_label']==1]
# test[test['model']==3]

# %%
fpr_2, tpr_2, _ = roc_curve(loglik_results['inferred_label_2'].to_numpy(), loglik_results['true_label_2'].to_numpy())
roc_auc_2 = auc(fpr_2, tpr_2)

fpr_3, tpr_3, _ = roc_curve(loglik_results['inferred_label_3'].to_numpy(), loglik_results['true_label_3'].to_numpy())
roc_auc_3 = auc(fpr_3, tpr_3)

fpr_4, tpr_4, _ = roc_curve(loglik_results['inferred_label_4'].to_numpy(), loglik_results['true_label_4'].to_numpy())
roc_auc_4 = auc(fpr_4, tpr_4)

fpr_5, tpr_5, _ = roc_curve(loglik_results['inferred_label_5'].to_numpy(), loglik_results['true_label_5'].to_numpy())
roc_auc_5 = auc(fpr_5, tpr_5)

fpr_6, tpr_6, _ = roc_curve(loglik_results['inferred_label_6'].to_numpy(), loglik_results['true_label_6'].to_numpy())
roc_auc_6 = auc(fpr_6, tpr_6)

fpr_7, tpr_7, _ = roc_curve(loglik_results['inferred_label_7'].to_numpy(), loglik_results['true_label_7'].to_numpy())
roc_auc_7 = auc(fpr_7, tpr_7)

fpr_8, tpr_8, _ = roc_curve(loglik_results['inferred_label_8'].to_numpy(), loglik_results['true_label_8'].to_numpy())
roc_auc_8 = auc(fpr_8, tpr_8)

fpr_9, tpr_9, _ = roc_curve(loglik_results['inferred_label_9'].to_numpy(), loglik_results['true_label_9'].to_numpy())
roc_auc_9 = auc(fpr_9, tpr_9)

fpr_10, tpr_10, _ = roc_curve(loglik_results['inferred_label_10'].to_numpy(), loglik_results['true_label_10'].to_numpy())
roc_auc_10 = auc(fpr_10, tpr_10)

fpr_11, tpr_11, _ = roc_curve(loglik_results['inferred_label_11'].to_numpy(), loglik_results['true_label_11'].to_numpy())
roc_auc_11 = auc(fpr_11, tpr_11)
# Out:
# /Users/yuliya/opt/anaconda3/envs/gpflow/lib/python3.9/site-packages/sklearn/metrics/_ranking.py:1029: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(

# %%
plt.figure()
plt.plot(fpr_2, tpr_2, '--', label='ROC M1 (%0.2f)' % roc_auc_2)
plt.plot(fpr_3, tpr_3, '--', label='ROC M2 (%0.2f)' % roc_auc_3)
plt.plot(fpr_4, tpr_4, '--', label='ROC M3 (%0.2f)' % roc_auc_4)
plt.plot(fpr_5, tpr_5, '--', label='ROC M4 (%0.2f)' % roc_auc_5)
plt.plot(fpr_6, tpr_6, '--', label='ROC M5 (%0.2f)' % roc_auc_6)
plt.plot(fpr_7, tpr_7, '--', label='ROC M6 (%0.2f)' % roc_auc_7)
plt.plot(fpr_8, tpr_8, '--', label='ROC M7 (%0.2f)' % roc_auc_8)
plt.plot(fpr_9, tpr_9, '--', label='ROC M8 (%0.2f)' % roc_auc_9)
plt.plot(fpr_10, tpr_10, '--', label='ROC M9 (%0.2f)' % roc_auc_10)
plt.plot(fpr_11, tpr_11, '--', label='ROC M11 (%0.2f)' % roc_auc_11)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()
