# %% [markdown]
# Wine: The dataset is about wine quality including red
# and white wine samples. The features include objective tests
# (e.g. PH values) and the output is based on sensory data.
# The labels are given by experts with grades between 0 (very
# bad) and 10 (very excellent). There are 1599 records for the
# red wine and 4898 for the white wine. We use the quality
# prediction problem for the white wine as the source task and
# the quality prediction problem for red wine as the target task

# %%
from ucimlrepo import fetch_ucirepo 
import matplotlib.pyplot as plt
import gpflow as gpf
import sys
import tensorflow as tf
import numpy as np
sys.path.append("..")
from atmodel import AdaptiveTransferGPR
from atkernel import TransferKernel
  
# fetch dataset 
wine_quality = fetch_ucirepo(id=186)

# %%
from sklearn.model_selection import train_test_split
# data (as pandas dataframes) 
Xc = wine_quality.data.original 
X = wine_quality.data.features
y = wine_quality.data.targets

# Take a random sample
inds = np.random.choice(np.arange(0, len(X)), replace=False, size=2000)
print("Features", [f for f in X])
X = X.to_numpy()[inds]
y = y.to_numpy()[inds]
Xc = Xc.iloc[inds]
filter_target = Xc["color"] == "red"
filter_source = Xc["color"] == "white"
Sx, Sy = X[filter_source], y[filter_source].reshape(-1, 1).astype(float)
Tx, Ty = X[filter_target], y[filter_target].reshape(-1, 1).astype(float)

Tx_train, Tx_test, Ty_train, Ty_test = train_test_split(Tx, Ty, test_size=0.95)   # no sequence right?

print("train", len(Sx), "train_target", len(Tx_train))
print("test", len(Tx))
# Out:
# Features ['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar', 'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density', 'pH', 'sulphates', 'alcohol']
# train 1500 train_target 25
# test 500

# %%
at_gpr = AdaptiveTransferGPR((Sx, Sy), (Tx_train, Ty_train), TransferKernel(lmb=0.5, kernel=gpf.kernels.RBF(), source_length=len(Sx)))

print("Training loss value before training:", at_gpr.training_loss().numpy())
opt = gpf.optimizers.Scipy()
opt.minimize(at_gpr.training_loss, at_gpr.trainable_variables)
gpf.utilities.print_summary(at_gpr)
print("Training loss value after training:", at_gpr.training_loss().numpy())
# Out:
# Training loss value before training: 234.765212055198
# 2025-10-23 12:39:25.336885: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-10-23 12:39:26.006134: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-10-23 12:39:26.659894: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-10-23 12:39:27.198673: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-10-23 12:39:27.754075: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-10-23 12:39:28.614524: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-10-23 12:39:29.234109: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-10-23 12:39:29.774665: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-10-23 12:39:30.545870: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-10-23 12:39:31.285852: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-10-23 12:39:31.945873: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-10-23 12:39:32.381687: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-10-23 12:39:33.031745: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-10-23 12:39:33.564146: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-10-23 12:39:34.268616: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-10-23 12:39:34.710623: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-10-23 12:39:35.208613: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-10-23 12:39:35.727746: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-10-23 12:39:36.245178: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-10-23 12:39:36.940260: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-10-23 12:39:37.518600: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-10-23 12:39:38.247885: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-10-23 12:39:38.877239: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-10-23 12:39:39.421398: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-10-23 12:39:40.127502: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-10-23 12:39:40.585508: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-10-23 12:39:41.106947: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-10-23 12:39:41.653216: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-10-23 12:39:42.317479: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-10-23 12:39:43.178878: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-10-23 12:39:43.631832: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-10-23 12:39:44.196050: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-10-23 12:39:44.715560: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-10-23 12:39:45.410055: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-10-23 12:39:45.904086: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-10-23 12:39:46.486589: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# ╒════════════════════════════════════════════════════════╤═══════════╤══════════════════╤═════════╤═════════════╤═════════╤═════════╤══════════╕
# │ name                                                   │ class     │ transform        │ prior   │ trainable   │ shape   │ dtype   │    value │
# ╞════════════════════════════════════════════════════════╪═══════════╪══════════════════╪═════════╪═════════════╪═════════╪═════════╪══════════╡
# │ AdaptiveTransferGPR.kernel.lmb                         │ Parameter │ SoftClip         │         │ True        │ ()      │ float64 │ 0.567052 │
# ├────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼──────────┤
# │ AdaptiveTransferGPR.kernel.kernel.variance             │ Parameter │ Softplus         │         │ True        │ ()      │ float64 │ 3.23003  │
# ├────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼──────────┤
# │ AdaptiveTransferGPR.kernel.kernel.lengthscales         │ Parameter │ Softplus         │         │ True        │ ()      │ float64 │ 2.10519  │
# ├────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼──────────┤
# │ AdaptiveTransferGPR.likelihood.source.variance         │ Parameter │ Softplus + Shift │         │ True        │ ()      │ float64 │ 0.965759 │
# │ AdaptiveTransferGPR.likelihood.likelihoods[0].variance │           │                  │         │             │         │         │          │
# ├────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼──────────┤
# │ AdaptiveTransferGPR.likelihood.target.variance         │ Parameter │ Softplus + Shift │         │ True        │ ()      │ float64 │ 2.99054  │
# │ AdaptiveTransferGPR.likelihood.likelihoods[1].variance │           │                  │         │             │         │         │          │
# ╘════════════════════════════════════════════════════════╧═══════════╧══════════════════╧═════════╧═════════════╧═════════╧═════════╧══════════╛
# Training loss value after training: 85.70566409700999
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 10
#       6 gpf.utilities.print_summary(at_gpr)
#       7 print("Training loss value after training:", at_gpr.training_loss().numpy())
# ---> 10 gpr = gpflow.models.GPR((Tx_train, Ty_train), gpf.kernels.RBF())
#      12 print("Training loss value before training:", gpr.training_loss().numpy())
#      13 opt = gpf.optimizers.Scipy()
#
# NameError: name 'gpflow' is not defined

# %% [markdown]
# plt.plot(Ty_test)

# %%
gpr = gpf.models.GPR((Tx_train, Ty_train), gpf.kernels.RBF())

print("Training loss value before training:", gpr.training_loss().numpy())
opt = gpf.optimizers.Scipy()
opt.minimize(gpr.training_loss, gpr.trainable_variables)
gpf.utilities.print_summary(gpr)
print("Training loss value after training:", gpr.training_loss().numpy())
# Out:
# Training loss value before training: 240.7247220154378
# ╒═════════════════════════╤═══════════╤══════════════════╤═════════╤═════════════╤═════════╤═════════╤═════════════╕
# │ name                    │ class     │ transform        │ prior   │ trainable   │ shape   │ dtype   │       value │
# ╞═════════════════════════╪═══════════╪══════════════════╪═════════╪═════════════╪═════════╪═════════╪═════════════╡
# │ GPR.kernel.variance     │ Parameter │ Softplus         │         │ True        │ ()      │ float64 │   41.5742   │
# ├─────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼─────────────┤
# │ GPR.kernel.lengthscales │ Parameter │ Softplus         │         │ True        │ ()      │ float64 │ 1006.98     │
# ├─────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼─────────────┤
# │ GPR.likelihood.variance │ Parameter │ Softplus + Shift │         │ True        │ ()      │ float64 │    0.680306 │
# ╘═════════════════════════╧═══════════╧══════════════════╧═════════╧═════════════╧═════════╧═════════╧═════════════╛
# Training loss value after training: 34.835491035881354

# %%
Ty_test_std = (Ty_test - Ty_test.mean()) / Ty_test.std()

# %%
fmean, fvar = at_gpr.predict_f(Tx_test[:100])
print(np.mean((Ty_test_std[:100] - fmean) ** 2) / np.var(Ty_test_std))
plt.plot(fmean - fmean.numpy().mean())
plt.plot(Ty_test_std[:100])
plt.ylabel("normalized score")
plt.xlabel("index")
plt.show()
plt.scatter(fmean - fmean.numpy().mean(), Ty_test_std[:100])
# Out:
# 4.869348794598061

# %%
for feature in wine_quality.data.targets:
    data = wine_quality.data.targets[feature]
    plt.hist(data)
    plt.show()

# %%
fmean, fvar = gpr.predict_f(Tx_test[:100])
fmean = fmean - fmean.numpy().mean()
print(np.mean((Ty_test_std[:100] - fmean) ** 2) / np.var(Ty_test_std))
plt.plot(fmean - fmean.numpy().mean())
plt.plot(Ty_test_std[:100])
plt.ylabel("normalized score")
plt.xlabel("index")
plt.show()
plt.scatter(fmean - fmean.numpy().mean(), Ty_test_std[:100])
# Out:
# 1.1801303244835264
