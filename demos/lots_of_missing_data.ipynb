# %%
import numpy as np  
import gpflow
import matplotlib.pyplot as plt 
import scipy.stats as ss
import tqdm as tqdm

import sys
sys.path.append("..")

from atmodel import AdaptiveTransferGPR, ConditionalMOGP
from atkernel import TransferKernel, TransferCoregion
from atlikelihood import TransferLikelihood

np.random.seed(124)
ndp = 200
# Out:
# 2025-11-11 10:01:37.941595: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-11 10:01:38.071280: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-11 10:01:38.286185: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-11 10:01:38.287499: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-11 10:01:39.715048: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/janneke/miniforge3/envs/dev/lib/python3.11/site-packages/gpflow/versions.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %% [markdown]
# ## Demonstration of transfer coregionalization
# I am using "transfer" to indicate that the training procedure is conditional.
# The AT-GP or "adaptive transfer model/GP" is the one in Cao.
# With "coregionalization GP"/ICM I mean the one found in GPFlow by default, which is the one described in Bonilla's paper.
#
# The difference between the "adaptive transfer model" and the "transfer coregionalization model" is that in the adaptive transfer model, the weight matrix is $$B = \begin{bmatrix} 1 & \lambda \\ \lambda & 1 \end{bmatrix},$$
# while in the ICM it's
# $$W = \begin{bmatrix} a & b \\ c & d \end{bmatrix}, B = WW^{T} + \begin{bmatrix} \kappa & 1 \\ 1 & \kappa \end{bmatrix}$$
# So $\kappa$ scales the variance in this, while $\lambda$ in the transfer kernel scales the covariance/captures the correlation between the source and target tasks. The nice thing about the ICM implementation is that everything is nice and PSD.

# %%
def plot_gp(x, mu, var, color, label):
    plt.plot(x, mu, color=color, lw=2, label=label)
    plt.fill_between(
        x[:, 0],
        (mu - 2 * np.sqrt(var))[:, 0],
        (mu + 2 * np.sqrt(var))[:, 0],
        color=color,
        alpha=0.4,
    )


def plot(m):
    plt.figure(figsize=(16, 4))
    Xtest = np.linspace(0, ndp, ndp)[:, None]
    (line,) = plt.plot(X1, Y1, "x", mew=2)
    mu, var = m.predict_f(np.hstack((Xtest, np.zeros_like(Xtest))))
    plot_gp(Xtest, mu, var, line.get_color(), "Y1")
    (line,) = plt.plot(X2_full, Y2_full, "x", mew=2, alpha=0.5, color="orange")
    (line,) = plt.plot(X2, Y2, "x", mew=2, color="black")
    mu, var = m.predict_f(np.hstack((Xtest, np.ones_like(Xtest))))
    plot_gp(Xtest, mu, var, line.get_color(), "Y2")

    plt.legend()


def plot_gpr(m):
    plt.figure(figsize=(16, 4))
    Xtest = np.linspace(0, ndp, ndp)[:, None]
    (line,) = plt.plot(X1, Y1, "x", mew=2, label="source data")
    mu, var = m.predict_f(Xtest)
    (line,) = plt.plot(X2_full, Y2_full, "x", mew=2, alpha=0.5, color="orange", label="all target data")
    (line,) = plt.plot(X2, Y2, "x", mew=2, color="black", label ="available target data")
    plot_gp(Xtest, mu, var, line.get_color(), "Y2")

    plt.legend()

# %% [markdown]
# We generate a sine wave and a version we shift by $\pi$/2, then use 10% of that data to fit and predict.

# %%
X1 = np.linspace(0, ndp, ndp)[:,None]  # Observed locations for first output
X2_full = np.linspace(0, ndp, ndp)[:,None]  # Observed locations for second output

Xall = np.linspace(0, ndp+10, ndp+10).reshape(-1, 1)
k = gpflow.kernels.RBF(active_dims=[0], lengthscales=5, variance=5)
Yall  = np.random.multivariate_normal(np.zeros_like(Xall[:,0]), k(Xall))
Y1 = Yall[3:ndp+3][:,None] + np.random.normal(0, 0.1, size=len(X1))[:,None]
Y2_full = Y1 * -1

ind = np.sort(np.random.choice(np.arange(ndp), int(ndp/10)))
plt.figure(figsize=(16, 4))
X2 = X2_full[ind]
Y2 = Y2_full[ind]
plt.figure(figsize=(16, 4))
plt.plot(X1, Y1, "kx", mew=2, label="source")
plt.plot(X2_full, Y2_full, "bx", alpha=0.1, mew=2, label="target (all)")
plt.plot(X2, Y2, "bx", mew=2, label="target (training)")
plt.xlabel("X")
plt.xlabel("y")
plt.title("Source and target tasks")
plt.legend()

# %%
ss.pearsonr(Y2_full, Y1)
# Out:
# PearsonRResult(statistic=array([0.86744673]), pvalue=array([6.08602142e-62]))

# %% [markdown]
# ### Adaptive Transfer model

# %%
# Interpolation with AT-GP
at_gpr = AdaptiveTransferGPR(data_source=(X1, Y1), 
                            data_target=(X2, Y2), 
                            kernel=TransferKernel(
                                lmb=-0.3, 
                                kernel=gpflow.kernels.RBF(), 
                                source_length=len(X1)), 
                            )

res = gpflow.optimizers.Scipy().minimize(
    at_gpr.training_loss,
    at_gpr.trainable_variables,
    method="L-BFGS-B",
    track_loss_history=True
)
print(res["loss_history"])
plot_gpr(at_gpr)
mu = at_gpr.get_mean_function()
gpflow.utilities.print_summary(at_gpr)

gpr = gpflow.models.GPR((X2, Y2), kernel=gpflow.kernels.RBF())
res = gpflow.optimizers.Scipy().minimize(
    gpr.training_loss,
    gpr.trainable_variables,
    method="L-BFGS-B",
    track_loss_history=True
)

at_logdet, at_square, at_rest = at_gpr.adaptive_log_marginal_likelihood(decompose=True)
at_logdet, at_square, at_rest = at_logdet.numpy(), at_square.numpy(), at_rest.numpy()
at_total = at_gpr.adaptive_log_marginal_likelihood()

lml_src =  gpr.log_marginal_likelihood(custom_X=X1, custom_Y=Y1)
lml_tgt =  gpr.log_marginal_likelihood(custom_X=X2, custom_Y=Y2)
lml_tot = gpr.log_marginal_likelihood()

print("likelihood of source data", lml_src, "likelihood of target data", lml_tgt, "likelihood total", lml_tot)
# Out:
# [46.05805261380533, 36.30904782640673, 33.45442491044278, 32.68675203638776, 31.017726930320634, 29.227777400243387, 29.028248932519777, 28.42142330685909, 28.341166670183345, 28.27145617367741, 28.233981049728285, 28.18897874760691, 28.171045730411123, 28.154310233421803, 28.14215855890012, 28.137118512168232, 28.13425732286028, 28.13280125284427, 28.13207106148635, 28.131780768929445, 28.13157216822296, 28.131441158570755, 28.13139919557903, 28.13136570439873, 28.131352749167043, 28.131344870284657, 28.131341615276487, 28.131341515566728, 28.13133991235206, 28.13133919482258, 28.131338817923915, 28.13133859272785, 28.131338424451286, 28.13133818380114, 28.13133708884991, 28.131337039213832]
# ╒════════════════════════════════════════════════════════╤═══════════╤══════════════════╤═════════╤═════════════╤═════════╤═════════╤═════════════╕
# │ name                                                   │ class     │ transform        │ prior   │ trainable   │ shape   │ dtype   │       value │
# ╞════════════════════════════════════════════════════════╪═══════════╪══════════════════╪═════════╪═════════════╪═════════╪═════════╪═════════════╡
# │ AdaptiveTransferGPR.kernel.lmb                         │ Parameter │ SoftClip         │         │ True        │ ()      │ float64 │ 1           │
# ├────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼─────────────┤
# │ AdaptiveTransferGPR.kernel.kernel.variance             │ Parameter │ Softplus         │         │ True        │ ()      │ float64 │ 0.499157    │
# ├────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼─────────────┤
# │ AdaptiveTransferGPR.kernel.kernel.lengthscales         │ Parameter │ Softplus         │         │ True        │ ()      │ float64 │ 6.53017e-05 │
# ├────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼─────────────┤
# │ AdaptiveTransferGPR.likelihood.source.variance         │ Parameter │ Softplus + Shift │         │ True        │ ()      │ float64 │ 1.0007e-06  │
# │ AdaptiveTransferGPR.likelihood.likelihoods[0].variance │           │                  │         │             │         │         │             │
# ├────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼─────────────┤
# │ AdaptiveTransferGPR.likelihood.target.variance         │ Parameter │ Softplus + Shift │         │ True        │ ()      │ float64 │ 2.43989     │
# │ AdaptiveTransferGPR.likelihood.likelihoods[1].variance │           │                  │         │             │         │         │             │
# ╘════════════════════════════════════════════════════════╧═══════════╧══════════════════╧═════════╧═════════════╧═════════╧═════════╧═════════════╛
# likelihood of source data tf.Tensor(-577948.5332361363, shape=(), dtype=float64) likelihood of target data tf.Tensor(-34.69517224216553, shape=(), dtype=float64) likelihood total tf.Tensor(-34.69517224216553, shape=(), dtype=float64)

# %% [markdown]
# This training procedure is extremely unstable, and while we do get a somewhat decent mean interpolation in low-data areas, the variance is a bit wonky. In the following cell, we can examine the model and see that the two tasks have a correlation of -0.4, approximately.

# %%
components = np.zeros((100, 3))

for i, l in tqdm.tqdm(enumerate(np.linspace(-0.99, 0.99, 100))):
    # for j, v in enumerate(np.linspace(1, 20, 20)):
    #     for k, w in enumerate(np.linspace(1, 20, 20)):
    at_gpr = AdaptiveTransferGPR(data_source=(X1, Y1), 
                                data_target=(X2, Y2), 
                                kernel=TransferKernel(
                                    lmb=l,
                                    kernel=gpflow.kernels.RBF(10, 10), 
                                    source_length=len(X1)), 
                                )

    at_logdet, at_square, at_rest = at_gpr.adaptive_log_marginal_likelihood(decompose=True)
    at_logdet, at_square, at_rest = at_logdet.numpy(), at_square.numpy(), at_rest.numpy()
    at_total = at_gpr.adaptive_log_marginal_likelihood()

    components[i] = (at_logdet, at_square, at_total)
# Out:
# 0it [00:00, ?it/s]2025-11-06 16:37:31.199954: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:31.215983: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:31.251755: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:31.267218: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2it [00:00, 18.81it/s]2025-11-06 16:37:31.310170: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:31.325154: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:31.366279: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:31.382086: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 4it [00:00, 17.97it/s]2025-11-06 16:37:31.417132: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:31.433591: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:31.469642: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:31.485702: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 6it [00:00, 18.53it/s]2025-11-06 16:37:31.532908: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:31.548391: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:31.584959: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:31.598889: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 8it [00:00, 18.20it/s]2025-11-06 16:37:31.636671: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:31.651644: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:31.692558: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:31.707317: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 10it [00:00, 18.28it/s]2025-11-06 16:37:31.743452: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:31.757592: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:31.794940: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:31.809689: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 12it [00:00, 18.69it/s]2025-11-06 16:37:31.843754: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:31.858922: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:31.893174: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:31.907289: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:31.948264: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:31.963825: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 15it [00:00, 19.00it/s]2025-11-06 16:37:31.996744: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:32.009637: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:32.039721: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:32.053119: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:32.084086: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:32.096781: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 18it [00:00, 20.21it/s]2025-11-06 16:37:32.138614: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:32.157623: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:32.195183: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:32.211618: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:32.245243: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:32.259532: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 21it [00:01, 19.54it/s]2025-11-06 16:37:32.293495: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:32.306569: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:32.342830: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:32.356944: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:32.389855: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:32.402372: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 24it [00:01, 20.02it/s]2025-11-06 16:37:32.433866: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:32.448142: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:32.482750: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:32.497361: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:32.536432: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:32.550352: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 27it [00:01, 20.09it/s]2025-11-06 16:37:32.585399: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:32.598566: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:32.628730: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:32.641809: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:32.672622: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:32.686029: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 30it [00:01, 20.69it/s]2025-11-06 16:37:32.716896: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:32.729854: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:32.759715: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:32.772791: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:32.803824: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:32.816505: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 33it [00:01, 21.36it/s]2025-11-06 16:37:32.848647: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:32.861264: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:32.891515: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:32.904496: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:32.936789: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:32.950568: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 36it [00:01, 21.66it/s]2025-11-06 16:37:32.982206: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:32.994702: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:33.026094: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:33.039007: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:33.071570: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:33.084967: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 39it [00:01, 21.85it/s]2025-11-06 16:37:33.117796: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:33.131279: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 60it [00:02, 21.76it/s]2025-11-06 16:37:34.098455: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:34.112795: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:34.144232: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:34.157498: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:34.187100: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:34.199797: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 63it [00:03, 21.97it/s]2025-11-06 16:37:34.231449: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:34.244320: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:34.274467: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:34.287241: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:34.318843: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:34.334237: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 66it [00:03, 21.97it/s]2025-11-06 16:37:34.370860: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:34.384767: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:34.414679: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:34.427875: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:34.459009: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:34.471518: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 69it [00:03, 22.04it/s]2025-11-06 16:37:34.502591: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:34.522999: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:34.557555: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:34.571082: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:34.602402: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:34.615279: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 72it [00:03, 21.68it/s]2025-11-06 16:37:34.646174: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:34.658874: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:34.689309: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:34.702147: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:34.732682: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:34.745916: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 75it [00:03, 22.04it/s]2025-11-06 16:37:34.776766: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:34.789480: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:34.819629: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:34.832576: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:34.863206: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:34.876079: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 78it [00:03, 22.34it/s]2025-11-06 16:37:34.907249: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:34.919920: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:34.950916: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:34.963632: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:34.993868: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:35.006859: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 81it [00:03, 22.52it/s]2025-11-06 16:37:35.038142: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:35.050744: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:35.081119: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:35.094254: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:35.124836: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:35.138709: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 84it [00:03, 22.58it/s]2025-11-06 16:37:35.169873: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:35.185185: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:35.216179: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:35.229583: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:35.261928: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:35.274513: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 87it [00:04, 22.44it/s]2025-11-06 16:37:35.306591: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:35.319491: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:35.362009: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:35.379228: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:35.409744: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:35.423071: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 90it [00:04, 21.70it/s]2025-11-06 16:37:35.454798: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:35.468607: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:35.498905: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:35.517289: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:35.553558: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:35.567105: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 93it [00:04, 21.44it/s]2025-11-06 16:37:35.600053: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:35.613467: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:35.644891: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:35.658008: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:35.689738: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:35.702318: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 96it [00:04, 21.66it/s]2025-11-06 16:37:35.733314: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:35.746346: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:35.777246: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:35.790181: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:35.822454: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:35.836952: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 99it [00:04, 21.84it/s]2025-11-06 16:37:35.868437: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:37:35.881509: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 100it [00:04, 21.18it/s]

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D


lambdas = np.linspace(-1, 1, 100)
plt.xlabel('lambda')
plt.plot(lambdas, components, label=["complexity penalty", "data fit", "total"])
plt.legend()

# %%
at_gpr
# Out:
# <atmodel.AdaptiveTransferGPR object at 0x7f4d6d781d90>
# ╒════════════════════════════════════════════════════════╤═══════════╤══════════════════╤═════════╤═════════════╤═════════╤═════════╤═════════╕
# │ name                                                   │ class     │ transform        │ prior   │ trainable   │ shape   │ dtype   │   value │
# ╞════════════════════════════════════════════════════════╪═══════════╪══════════════════╪═════════╪═════════════╪═════════╪═════════╪═════════╡
# │ AdaptiveTransferGPR.kernel.lmb                         │ Parameter │ SoftClip         │         │ True        │ ()      │ float64 │    0.99 │
# ├────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼─────────┤
# │ AdaptiveTransferGPR.kernel.kernel.variance             │ Parameter │ Softplus         │         │ True        │ ()      │ float64 │   10    │
# ├────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼─────────┤
# │ AdaptiveTransferGPR.kernel.kernel.lengthscales         │ Parameter │ Softplus         │         │ True        │ ()      │ float64 │   10    │
# ├────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼─────────┤
# │ AdaptiveTransferGPR.likelihood.source.variance         │ Parameter │ Softplus + Shift │         │ True        │ ()      │ float64 │    1    │
# │ AdaptiveTransferGPR.likelihood.likelihoods[0].variance │           │                  │         │             │         │         │         │
# ├────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼─────────┤
# │ AdaptiveTransferGPR.likelihood.target.variance         │ Parameter │ Softplus + Shift │         │ True        │ ()      │ float64 │    1    │
# │ AdaptiveTransferGPR.likelihood.likelihoods[1].variance │           │                  │         │             │         │         │         │
# ╘════════════════════════════════════════════════════════╧═══════════╧══════════════════╧═════════╧═════════════╧═════════╧═════════╧═════════╛

# %% [markdown]
# ### ICM

# %% [markdown]
# The ICM needs tasks indices. In the transfer model, we assume the source and target task to be ordered. We should probably think about whether that's smart.

# %%
# Augment the input with ones or zeros to indicate the required output dimension
X_augmented = np.vstack(
    (np.hstack((X1, np.zeros_like(X1))), np.hstack((X2, np.ones_like(X2))))
)

# Augment the Y data with ones or zeros that specify a likelihood from the list of likelihoods
Y_augmented = np.vstack(
    (np.hstack((Y1, np.zeros_like(Y1))), np.hstack((Y2, np.ones_like(Y2))))
)

# %%
import tensorflow as tf
output_dim = 2  # Number of outputs
rank = 1  # Rank of W

# Base kernel
k = gpflow.kernels.RBF()

# Coregion kernel
coreg = gpflow.kernels.Coregion(
    output_dim=output_dim, rank=rank, active_dims=[1]
)

kern = k * coreg
#kern2 = TransferKernel(0.5, gpflow.kernels.RBF(), source_length=int(len(Y_augmented) - np.sum(Y_augmented[:,1])))

# This likelihood switches between Gaussian noise with different variances for each f_i:
lik = gpflow.likelihoods.SwitchedLikelihood(likelihood_list=[gpflow.likelihoods.Gaussian(), gpflow.likelihoods.Gaussian()])
# now build the GP model as normal
#lik = gpflow.likelihoods.Gaussian()

m = gpflow.models.VGP((X_augmented, Y_augmented), kernel=kern, likelihood=lik)
# fit the covariance function parameters
res = gpflow.optimizers.Scipy().minimize(
    m.training_loss,
    m.trainable_variables,
    method="L-BFGS-B",
    track_loss_history=True
)
res
# Out:
#       message: CONVERGENCE: RELATIVE REDUCTION OF F <= FACTR*EPSMCH
#       success: True
#        status: 0
#           fun: 6.343134698727425
#             x: [-4.079e-01 -7.284e-01 ... -4.805e+00 -5.503e+00]
#           nit: 1943
#           jac: [-6.224e-04 -4.759e-04 ... -2.260e-04  6.835e-04]
#          nfev: 2100
#          njev: 2100
#      hess_inv: <24538x24538 LbfgsInvHessProduct with dtype=float64>
#  loss_history: [732.4542775612053, 646.9885407961323, 577.3048402753248, 541.1162692990847, 520.9195951527508, 508.6801372274882, 492.59655162927186, 485.95008212660565, 478.6208885507674, 464.0076298468084, 438.6169122417359, 423.40782904190405, 402.00624170728145, 377.63203121116004, 335.6631416699873, 309.65026843600293, 299.7541218141265, 292.839282501041, 273.1379260466661, 248.83343385435015, 236.2665648718588, 215.72435606137947, 208.09696545175004, 199.4659246803497, 197.349477697314, 191.4033702476616, 183.46428908910553, 177.9511208081287, 173.00602814932387, 166.09268551379546, 158.98404532471216, 147.14729515163148, 138.16635624424208, 127.6440435847357, 122.33341346675536, 118.72782673430862, 116.98602428365976, 115.07342996652687, 112.56799001201654, 109.69915839386368, 107.62737635851249, 106.50390735019593, 103.16825547829072, 96.7820186773468, 93.05906121636781, 90.47654986930159, 87.77676418864174, 86.84471801209806, 85.02185933877396, 83.69600840456039, 82.25654696156033, 81.58586454237329, 80.74165123147613, 79.10750168956866, 78.40997245022554, 77.39445856791372, 75.9009440716606, 73.55989518486601, 72.17962977301727, 70.90274970335236, 70.21410027420657, 68.45387860633846, 67.7968382634914, 66.47807294473392, 65.3623964018777, 63.77413940005323, 63.04991805150259, 61.7370913275723, 59.99920101774029, 58.608663532752246, 57.71081942989285, 56.225930246721646, 55.73095975416686, 55.143669410908544, 54.595628036147616, 53.32688292196005, 52.62902339964006, 51.404624612927904, 50.975600563401045, 49.756332475996686, 48.91127593850912, 48.19484960239207, 47.55991855800403, 46.816010949082994, 46.31306654797777, 45.801937996995036, 45.46221163408137, 44.62336147038144, 43.7196435541842, 43.5940119053181, 43.37409277176005, 43.13842327224364, 42.68333657836172, 42.049884026251775, 41.73059643913899, 40.8123335029355, 40.494910871949315, 40.04858921240947, 39.495130421642415, 38.77283125345022, 38.36940447044299, 37.796039493389316, 37.63203831552953, 36.96807914018251, 36.50597655241046, 35.969951067579444, 35.69177764537807, 35.53606239516817, 34.940551695373486, 34.59699564843376, 33.94009658786521, 33.069874580979715, 32.869977956922995, 32.47804570685419, 32.20275561358528, 31.987266404500957, 31.60267765632031, 31.43766783471611, 31.105503872845247, 30.979517803555723, 30.68534047105635, 30.289700821098137, 30.075353956116203, 29.68286327275689, 29.410392260892024, 29.18077947536969, 28.96050721303226, 28.676621782876822, 28.162527977586308, 28.03972602697644, 27.747820495031192, 27.52505476831729, 27.216407749656724, 26.859509174741873, 26.504584406792503, 26.193856366525438, 25.955182974614388, 25.823055786999163, 25.491311123280866, 25.116462221632247, 24.773005500542837, 24.565345250087972, 24.391342101223074, 24.29035066050062, 24.037722993749668, 23.634206193946426, 23.527459806184936, 23.292198587644606, 23.100416154971157, 22.889795918408026, 22.531740260935294, 22.340967878748387, 22.0803476219443, 21.937590779552608, 21.84563569507756, 21.73698068522046, 21.45927253384204, 21.258350144552622, 20.843328878416685, 20.64331149639017, 20.32434215269012, 20.1983372016646, 20.05323549666562, 19.899691903669776, 19.789578203882, 19.593877947879605, 19.498426313436823, 19.447402251645286, 19.403926255237906, 19.301354224444083, 19.176523942013546, 19.003626874634335, 18.893601530051228, 18.80575249688883, 18.752578595408124, 18.641778342714645, 18.544271658220225, 18.392377079770142, 18.33455027493693, 18.278527666959604, 18.23177975400381, 18.06891264210242, 17.928679126789746, 17.78937785768545, 17.691492905130758, 17.60171859883107, 17.54047836369341, 17.401734351603494, 17.293651656022263, 17.183974556892963, 17.12803134034911, 17.073300184473965, 17.037596268623645, 16.963579906888924, 16.86636981193942, 16.79988895179946, 16.71199367227311, 16.621332900138412, 16.521553309564695, 16.402207883254874, 16.207018240230838, 16.082109392236703, 15.966873675419748, 15.847073323541622, 15.806168659946678, 1 ...

# %%
# print(X1.shape, Y1.shape, X2.shape, Y2.shape)
# lml_src = m.elbo(custom_X=np.hstack((X1, np.zeros_like(X1))), custom_Y=np.hstack((Y1, np.zeros_like(Y1))))
# lml_tgt = m.elbo(custom_X=np.hstack((X2, np.ones_like(X2))), custom_Y=np.hstack((Y2, np.ones_like(Y2))))
# lml_tot = m.elbo()
# print(lml_src, lml_tgt, lml_tot, lml_src+lml_tgt)

# print("proportion of src", lml_src/lml_tot)
# print("proportion of tgt", lml_tgt/lml_tot)
# print("interaction", 1 - (lml_src+lml_tgt)/lml_tot)

# %% [markdown]
# Training is via a VGP because the likelihood is custom - in this case, it's Gaussian and you can swap it out for the TransferLikelihood and train a GPR instead, as well. Thus far I haven't seen the coregionalization model fit very well, and when it does it virtually ignores the available target data.

# %%
plot(m)

# %%
cov = m.kernel.kernels[1].output_covariance().numpy()
cov / cov.max()
# Out:
# array([[0.81344072, 0.75693895],
#        [0.75693895, 1.        ]])

# %% [markdown]
# ### Combining the two
# Now, I want to know whether the conditioning makes the difference, *and* whether training is more stable if we do not constrain the weights of the adaptive transfer kernel. We have a working implementation of the AT-GP, so I just adapted the weights to work like they do in the coregionalization model. This should ensure they are PSD, and give us some room to play around with constraining the weights in different ways.
#
# I implemented the transfer kernel in such a way that the weights now mimic those of the coregion kernel. I can still use the weights from Caos paper if I want to (use_lmb = True), but now I can compare a conditional ICM and a stable transfer GP.

# %%
output_dim = 2  # Number of outputs
rank = 1  # Rank of W

# Base kernel
k = gpflow.kernels.RBF(active_dims=[0])

# Coregion kernel
coreg = gpflow.kernels.Coregion(
    output_dim=output_dim, rank=rank, active_dims=[1]
)

kern = k * coreg

X_aug = np.concatenate((np.hstack((X1, np.zeros_like(X1))), np.hstack((X2, np.ones_like(X2)))))
Y_aug = np.concatenate((np.hstack((Y1, np.zeros_like(Y1))), np.hstack((Y2, np.ones_like(Y2)))))

# %%
# Unconstrained weights
unconstrained_transfer = AdaptiveTransferGPR(data_source=(X1, Y1), 
                            data_target=(X2, Y2), 
                            kernel=TransferCoregion(
                                lmb=-0.8, 
                                kernel=gpflow.kernels.RBF(), 
                                source_length=len(X1), use_lmb=False), 
                            )

res = gpflow.optimizers.Scipy().minimize(
    unconstrained_transfer.training_loss,
    unconstrained_transfer.trainable_variables,
    method="L-BFGS-B",
    track_loss_history=True
)

plot_gpr(unconstrained_transfer)
print(unconstrained_transfer.adaptive_log_marginal_likelihood(decompose=True))
gpflow.utilities.print_summary(unconstrained_transfer)
#gpflow.utilities.print_summary(stable_transfer)
# Out:
# 2025-11-06 16:38:52.451797: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:38:52.453674: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:38:52.455085: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:38:52.456470: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:38:52.457881: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:38:52.459282: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:38:52.460747: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:38:52.462185: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:38:52.463634: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:38:52.465077: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:38:52.466498: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:38:52.467952: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:38:52.469440: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:38:52.470864: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:38:52.472214: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:38:52.473456: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:38:52.474722: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:38:52.476074: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:38:52.477320: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# 2025-11-06 16:38:52.478599: W tensorflow/core/kernels/linalg/cholesky_op.cc:56] Cholesky decomposition was not successful. Eigen::LLT failed with error code 1. Filling lower-triangular output with NaNs.
# (<tf.Tensor: shape=(), dtype=float64, numpy=-2.065855625938114>, <tf.Tensor: shape=(), dtype=float64, numpy=-18.6970135597298>, <tf.Tensor: shape=(), dtype=float64, numpy=-18.378770351409912>)
# ╒════════════════════════════════════════════════════════╤═══════════╤══════════════════╤═════════╤═════════════╤═════════╤═════════╤═══════════════╕
# │ name                                                   │ class     │ transform        │ prior   │ trainable   │ shape   │ dtype   │ value         │
# ╞════════════════════════════════════════════════════════╪═══════════╪══════════════════╪═════════╪═════════════╪═════════╪═════════╪═══════════════╡
# │ AdaptiveTransferGPR.kernel.W                           │ Parameter │ Identity         │         │ True        │ (2, 2)  │ float64 │ [[0.3, 0.6... │
# ├────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼───────────────┤
# │ AdaptiveTransferGPR.kernel.kernel.variance             │ Parameter │ Softplus         │         │ True        │ ()      │ float64 │ 1.0           │
# ├────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼───────────────┤
# │ AdaptiveTransferGPR.kernel.kernel.lengthscales         │ Parameter │ Softplus         │         │ True        │ ()      │ float64 │ 1.0           │
# ├────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼───────────────┤
# │ AdaptiveTransferGPR.kernel.kappa                       │ Parameter │ Softplus         │         │ True        │ (2,)    │ float64 │ [1. 1.]       │
# ├────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼───────────────┤
# │ AdaptiveTransferGPR.likelihood.source.variance         │ Parameter │ Softplus + Shift │         │ True        │ ()      │ float64 │ 1.0           │
# │ AdaptiveTransferGPR.likelihood.likelihoods[0].variance │           │                  │         │             │         │         │               │
# ├────────────────────────────────────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼───────────────┤
# │ AdaptiveTransferGPR.likelihood.target.variance         │ Parameter │ Softplus + Shift │         │ True        │ ()      │ float64 │ 1.0           │
# │ AdaptiveTransferGPR.likelihood.likelihoods[1].variance │           │                  │         │             │         │         │               │
# ╘════════════════════════════════════════════════════════╧═══════════╧══════════════════╧═════════╧═════════════╧═════════╧═════════╧═══════════════╛

# %% [markdown]
# Now we have smooth predictions with a somewhat reasonable mean and reasonable uncertainties, and the training is somewhat stable. Let's take a look at the weight matrix:

# %%
#print(stable_transfer.kernel.get_B())
print(unconstrained_transfer.kernel.get_B() / unconstrained_transfer.kernel.get_B().numpy().max())
# Out:
# tf.Tensor(
# [[0.7038835  0.33495146]
#  [0.33495146 1.        ]], shape=(2, 2), dtype=float64)

# %% [markdown]
# ### Quantifying performance
#
# Thus far, we just evaluated things based on "do I like the look of this prediction", so time for some quantification:

# %%
from sklearn.metrics import mean_squared_error
X2_filt = X2_full[[i for i in np.arange(100) if i not in ind]]
Y2_filt = Y2_full[[i for i in np.arange(100) if i not in ind]]

for i, model in enumerate([gpr, at_gpr, unconstrained_transfer, m]):
    if i == 3:
        X1_filt = np.hstack((X1, np.zeros_like(X1)))
        Y1_filt = np.hstack((Y1, np.zeros_like(Y1)))
        X2_filt = np.hstack((X2_filt, np.ones_like(X2_filt)))
        Y2_filt = np.hstack((Y2_filt, np.ones_like(Y2_filt)))
        Yhat, Yvar = model.predict_f(X2_filt)
        Yhat = Yhat[:,0]
        Y1hat, Y1var = model.predict_f(X1_filt)
        Y1hat = Y1hat[:,0]
        print(f"{model=}", mean_squared_error(Yhat, Y2_filt[:,0]))
        print(f"{model=} (src)", mean_squared_error(Y1hat, Y1_filt[:,0]))
    else:
        Yhat, Yvar = model.predict_f(X2_filt)
        Y1hat, Y1var = model.predict_f(X1)
        Y1hat = Y1hat[:,0]
        print(f"{model=}", mean_squared_error(Yhat, Y2_filt[:,0]))
        print(f"{model=} (src)", mean_squared_error(Y1hat, Y1[:,0]))
# Out:
# model=<gpflow.models.gpr.GPR object at 0x7f4dd0480910> 1.232429686429717
# model=<gpflow.models.gpr.GPR object at 0x7f4dd0480910> (src) 3.540418123525938
# model=<atmodel.AdaptiveTransferGPR object at 0x7f4d6d781d90> 1.104904529187549
# model=<atmodel.AdaptiveTransferGPR object at 0x7f4d6d781d90> (src) 0.3063508198555517
# model=<atmodel.AdaptiveTransferGPR object at 0x7f4d6c3a7150> 1.5661169275017601
# model=<atmodel.AdaptiveTransferGPR object at 0x7f4d6c3a7150> (src) 1.4228894793439941
# model=<gpflow.models.vgp.VGP object at 0x7f4d6d504190> 1.080221741985749
# model=<gpflow.models.vgp.VGP object at 0x7f4d6d504190> (src) 0.006598436192452923
