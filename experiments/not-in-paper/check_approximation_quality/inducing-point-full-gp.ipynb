# %%
import gpflow as gpf 
import numpy as np
import scipy.stats as ss
from scipy.spatial.distance import cdist
import tensorflow as tf 
from tslearn.metrics import dtw

import matplotlib.pyplot as plt 
import tqdm as tqdm
import os

import sys
sys.path.append("../..")

from atmodel import ConditionalMOGP, SparseCMOGP
from atlikelihood import TransferLikelihood
# Out:
# 2026-09-18 17:53:33.138904: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-18 17:53:33.142589: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-09-18 17:53:33.217973: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-09-18 17:53:33.219419: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-18 17:53:34.769844: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/janneke/miniforge3/envs/dev/lib/python3.11/site-packages/gpflow/versions.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
def optimize(m, plot_res=False):
    opt = gpf.optimizers.Scipy()
    res = opt.minimize(m.training_loss, m.trainable_variables, track_loss_history=True, options={"disp": 50, "maxiter": 250})
    if plot_res:
        plt.plot(res["loss_history"])
        plt.show()

# %%
k = gpf.kernels.RBF(lengthscales=1, variance=1) #+ gpf.kernels.Linear(0.001)
Xall = np.sort(np.random.random(200) * 20)
Yall  = np.random.multivariate_normal(np.zeros_like(Xall), k(Xall.reshape(-1, 1)))
ind_1 = np.arange(0, 200, 1)
ind_2 = np.array([i for i in ind_1 if i % 2 == 0])
ind_1 = ind_1
ind_2 = ind_2
TEST_INDEX = int(0.75*len(ind_2))
ind_train, ind_test = ind_2[:TEST_INDEX], ind_2[TEST_INDEX:]
X1, y1 = Xall[ind_1], Yall[ind_1]
X2, y2 = Xall[ind_train], Yall[ind_train]
X2 = X2
y2 = -1*y2
Xtest, ytest = Xall[ind_test], Yall[ind_test]
ytest = -ytest
noise_variance = 0.1
y1 = y1.reshape(-1, 1) + np.random.normal(0, noise_variance, len(X1)).reshape(-1, 1)
y2 = y2.reshape(-1, 1) + np.random.normal(0, noise_variance, len(X2)).reshape(-1, 1) 
X1 = X1.reshape(-1, 1)
X2 = X2.reshape(-1, 1)
plt.plot(X1, y1, marker=".")
plt.plot(X2, y2, marker=".")
plt.plot(Xtest, ytest, marker=".")
X = np.vstack((np.hstack((X1, np.zeros_like(X1))), np.hstack((X2, np.ones_like(X2)))))
y = np.vstack((np.hstack((y1, np.zeros_like(y1))), np.hstack((y2, np.ones_like(y2)))))
plt.show()
X = tf.cast(X, np.float64)
y = tf.cast(y, np.float64)

# %%
exponents = np.arange(2, 11)
superlmls = []
output_dim = 2  # Number of outputs
rank = 1  # Rank of W
cross_cov = np.arange(-1, 1.25, 0.25)
for i in cross_cov:
    lmls = []
    for exponent in exponents:
        print(2 ** exponent)
        k = gpf.kernels.RBF(lengthscales=1)
        coreg = gpf.kernels.Coregion(
            output_dim=output_dim, rank=rank, active_dims=[1]
        )
        coreg.W = np.array([1., i]).reshape(-1, 1)
        kern = k * coreg
        m2 = ConditionalMOGP((X, y), kernel=kern, likelihood=TransferLikelihood(source=gpf.likelihoods.Gaussian(), target=gpf.likelihoods.Gaussian()))
        k = gpf.kernels.RBF(lengthscales=1)

        # Base kernel
        coreg = gpf.kernels.Coregion(
            output_dim=output_dim, rank=rank, active_dims=[1]
        )
        coreg.W = np.array([1., i]).reshape(-1, 1)

        # Coregion kernel
        ivs = np.linspace(0, max(X[:,0]), 2 ** exponent).reshape(-1, 1)
        iv_ind = np.concatenate((np.zeros((int(len(ivs)/2),1)), np.ones((int(len(ivs)/2),1))))
        shuffle = np.random.permutation(np.arange(len(ivs)))
        iv_ind = iv_ind[shuffle]
        ivs = np.hstack((ivs, iv_ind))
        kern = k * coreg

        minavg_distance_src = cdist(ivs[ivs[:,1] == 0], X[X[:,1] == 0]).min(axis=1).mean()
        minavg_distance_tgt = cdist(ivs[ivs[:,1] == 1], X[X[:,1] == 1]).min(axis=1).mean()

        m = SparseCMOGP((X, y), exact_target=False, kernel=kern, inducing_variable=ivs, jitter=1e-5, likelihood=TransferLikelihood(source=gpf.likelihoods.Gaussian(), target=gpf.likelihoods.Gaussian()))

        lml_sparse = m.conditional_likelihood()
        lml_dense = m2.maximum_log_likelihood_objective().numpy()
        lmls.append((lml_sparse.numpy(), lml_dense))
    print(lmls)
    superlmls.append(lmls)
superlmls = np.array(superlmls)
# Out:
# 4
# 8
# 16
# 32
# 64
# 128
# 256
# 512
# 1024
# [(-114.55135099641097, -83.71336197446054), (-103.26029372378687, -83.71336197446054), (-101.58270080963587, -83.71336197446054), (-85.11642821717685, -83.71336197446054), (-83.97005739451934, -83.71336197446054), (-83.71388477215137, -83.71336197446054), (-83.71340841499195, -83.71336197446054), (-83.71337934060881, -83.71336197446054), (-83.71336991488843, -83.71336197446054)]
# 4
# 8
# 16
# 32
# 64
# 128
# 256
# 512
# 1024
# [(-110.53295207898145, -82.98556692354688), (-108.71571570938363, -82.98556692354688), (-92.59018982535571, -82.98556692354688), (-83.98380098736145, -82.98556692354688), (-82.99404893299385, -82.98556692354688), (-82.98602209147873, -82.98556692354688), (-82.98561382972454, -82.98556692354688), (-82.98558470900784, -82.98556692354688), (-82.98557533330796, -82.98556692354688)]
# 4
# 8
# 16
# 32
# 64
# 128
# 256
# 512
# 1024
# [(-107.06367584499904, -82.57086585224096), (-98.15423024757163, -82.57086585224096), (-91.30229371278891, -82.57086585224096), (-84.72762958106023, -82.57086585224096), (-82.57488475887793, -82.57086585224096), (-82.57097669464002, -82.57086585224096), (-82.57093092100163, -82.57086585224096), (-82.57088484944968, -82.57086585224096), (-82.57087440063864, -82.57086585224096)]
# 4
# 8
# 16
# 32
# 64
# 128
# 256
# 512
# 1024
# [(-107.36520883521253, -82.53280328733548), (-98.8891562478126, -82.53280328733548), (-88.20803233235635, -82.53280328733548), (-85.23220905609915, -82.53280328733548), (-82.5520728442271, -82.53280328733548), (-82.53287905993251, -82.53280328733548), (-82.53284151594988, -82.53280328733548), (-82.53282215365032, -82.53280328733548), (-82.5328128714426, -82.53280328733548)]
# 4
# 8
# 16
# 32
# 64
# 128
# 256
# 512
# 1024
# [(-107.04431889848524, -82.84647822958836), (-98.6830251864826, -82.84647822958836), (-91.70320239382303, -82.84647822958836), (-84.6470963859341, -82.84647822958836), (-83.38874678709941, -82.84647822958836), (-82.84783172858766, -82.84647822958836), (-82.8465246429553, -82.84647822958836), (-82.84649834864312, -82.84647822958836), (-82.84648644688853, -82.84647822958836)]
# 4
# 8
# 16
# 32
# 64
# 128
# 256
# 512
# 1024
# [(-108.9375065333115, -83.41013274360343), (-107.80120061702289, -83.41013274360343), (-99.0506118746498, -83.41013274360343), (-85.39941475138387, -83.41013274360343), (-83.50018642002647, -83.41013274360343), (-83.41035553095567, -83.41013274360343), (-83.41022332660076, -83.41013274360343), (-83.41015562294392, -83.41013274360343), (-83.41014223384786, -83.41013274360343)]
# 4
# 8
# 16
# 32
# 64
# 128
# 256
# 512
# 1024
# [(-110.98121151243784, -84.127031663371), (-106.43198404684216, -84.127031663371), (-102.53067113346404, -84.127031663371), (-88.0276679661925, -84.127031663371), (-84.15391822008418, -84.127031663371), (-84.12712598561343, -84.127031663371), (-84.12707255116914, -84.127031663371), (-84.12705026327414, -84.127031663371), (-84.12704249490194, -84.127031663371)]
# 4
# 8
# 16
# 32
# 64
# 128
# 256
# 512
# 1024
# [(-116.65172298438404, -84.95035198207322), (-112.60664661313777, -84.95035198207322), (-101.91770561670435, -84.95035198207322), (-90.29386028374194, -84.95035198207322), (-84.95209119583997, -84.95035198207322), (-84.95120881529178, -84.95035198207322), (-84.95039988174356, -84.95035198207322), (-84.9503715993108, -84.95035198207322), (-84.950360996715, -84.95035198207322)]
# 4
# 8
# 16
# 32
# 64
# 128
# 256
# 512
# 1024
# [(-121.4779971070134, -85.85909072561756), (-120.5698402502338, -85.85909072561756), (-107.1543819593081, -85.85909072561756), (-91.84872655708631, -85.85909072561756), (-85.94086510027165, -85.85909072561756), (-85.86005228665329, -85.85909072561756), (-85.85913836806094, -85.85909072561756), (-85.85931203892595, -85.85909072561756), (-85.85910103240336, -85.85909072561756)]

# %%
import matplotlib.colors as mcolors
colorlist = list(mcolors.TABLEAU_COLORS.values())
for j, l in enumerate(superlmls):
    fig, ax = plt.subplots(1, 1, figsize=(12, 6))
    ax.plot(exponents, -l[:,0], color=colorlist[j], label=cross_cov[j])
    ax.plot(exponents, -l[:,1], color=colorlist[j])
    plt.xticks(exponents, 2 ** exponents)
    plt.xlabel("Number of inducing points")
    ax.set_ylabel("NLML")
    plt.tight_layout()
    plt.legend()
    plt.show()

# %%
exponents = np.arange(2, 11)
supernoises = []
output_dim = 2  # Number of outputs
rank = 1  # Rank of W
cross_cov = np.arange(-1, 1.25, 0.25)
for i in cross_cov:
    noises = []
    for exponent in exponents:
        print(2 ** exponent)
        k = gpf.kernels.RBF(lengthscales=1)
        coreg = gpf.kernels.Coregion(
            output_dim=output_dim, rank=rank, active_dims=[1]
        )
        coreg.W = np.array([1., i]).reshape(-1, 1)
        kern = k * coreg
        m2 = ConditionalMOGP((X, y), kernel=kern, likelihood=TransferLikelihood(source=gpf.likelihoods.Gaussian(), target=gpf.likelihoods.Gaussian()))
        k = gpf.kernels.RBF(lengthscales=1)

        # Base kernel
        coreg = gpf.kernels.Coregion(
            output_dim=output_dim, rank=rank, active_dims=[1]
        )
        coreg.W = np.array([1., i]).reshape(-1, 1)

        # Coregion kernel
        ivs = np.linspace(0, max(X[:,0]), 2 ** exponent).reshape(-1, 1)
        iv_ind = np.concatenate((np.zeros((int(len(ivs)/2),1)), np.ones((int(len(ivs)/2),1))))
        shuffle = np.random.permutation(np.arange(len(ivs)))
        iv_ind = iv_ind[shuffle]
        ivs = np.hstack((ivs, iv_ind))
        kern = k * coreg
        m = SparseCMOGP((X, y), exact_target=False, kernel=kern, inducing_variable=ivs, jitter=1e-5, likelihood=TransferLikelihood(source=gpf.likelihoods.Gaussian(), target=gpf.likelihoods.Gaussian()))
        optimize(m)
        optimize(m2)
        noise_sparse_source = m.likelihood.source.variance.numpy()
        noise_sparse_target = m.likelihood.target.variance.numpy()
        noise_full_source = m2.likelihood.source.variance.numpy()
        noise_full_target = m2.likelihood.target.variance.numpy()
        noises.append([noise_sparse_source, noise_sparse_target, noise_full_source, noise_full_target])
    print(noises)
    supernoises.append(noises)
supernoises = np.array(supernoises)
# Out:
# 4
# 8
# 16
# 32
# 64
# 128
# 256
# 512
# 1024
#